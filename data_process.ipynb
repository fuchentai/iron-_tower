# %% [markdown]
# # 数据预处理

# %% [markdown]
# ## 去除未标注的图片
# 为了节省时间，往往将图片分发给多个人标注。由于少量图片存在模糊、倾斜、重复等情况而未被标注，所以标签个数小于等于图片个数。当将标注好的图片以及标签汇总的时候，可以用这里的代码将多余的图片移动到其他地方。

# %%
import os, shutil

'''
默认图片名称与标签名称一致。
默认该文件与待处理文件夹处于同一目录下。
'''

base = os.getcwd()
label_file = os.path.join(base, '镀锌数据集标注')#标签所在文件夹
img_file  = os.path.join(base, '镀锌数据集图片')#图片所在文件夹
dstfile = os.path.join(base, '冗余图片与标注')#多余图片输出目标文件夹
if not os.path.exists(dstfile):
    os.mkdir(dstfile)
    
labels = os.listdir(label_file)
imgs = os.listdir(img_file)

labels.sort()
imgs.sort()
print('标签个数：{}个，图片张数：{}张'.format(len(labels), len(imgs)))
diff_list = []

for i in labels:
    for j in imgs:
        if i[:-5] == j[:-4]:#标签后缀为.json，图片后缀为.jpg
            imgs.remove(j)

for i in imgs:
    imgsrc = os.path.join(img_file, i)
    shutil.move(imgsrc, dstfile)#移动文件

print('移动图片张数：{}张'.format(len(imgs)))
# Out:
# 标签个数：548个，图片张数：548张
# 移动图片张数：0张

# %% [markdown]
# ## 绘制字符统计图
# 从标注文件中统计每个字符的个数，并绘制成统计图。

# %%
import json
import os
import matplotlib.pylab as plt

#files = ['角铁数据集标注', '剩余数据集标注', '镀锌数据集标注']
files = [ '镀锌数据集标注']
base = os.getcwd()
char_dic = {}#字符字典
for file in files:
    file_path = os.path.join(base, file)#文件路径
    files_json = os.listdir(file_path)#得到文件中所有json文件的名字
    for json_file in files_json:
        json_full_path = os.path.join(file_path, json_file)#得到每个json文件的完整路径
        with open(json_full_path, 'rb') as json_file:#打开json文件
            json_dic = json.load(json_file)#加载json的内容
            for shape in json_dic['shapes']:#标签块保存在shaps中
                label = shape['label']#取到每个块的内容，方便后续统计。
                if file == '角铁数据集标注':#老的标注
                    char_dic.setdefault(label, 0)#如果键不存在于字典中，将会添加并将值设为默认值
                    char_dic[label] += 1#内容计数
                else:
                    for char in label:
                        char_dic.setdefault(char, 0)
                        char_dic[char] += 1#内容计数

print(char_dic)
# Out:
# {'f': 39, '&': 492, 'm': 380, 'l': 365, '-': 731, 'h': 755, 'v': 394, 'd': 380, 'c': 525, 'z': 160, 'e': 123, '2': 722, '3': 251, '7': 204, '*': 50, '6': 156, 'j': 498, 'p': 328, '4': 162, '1': 634, '0': 137, '5': 326, 'b': 39, '8': 161, 'a': 138, 'n': 8, '9': 110, 'y': 99, 'i': 20, 'x': 32, 's': 46, 'g': 16, 'k': 42, 'r': 7, 'q': 1, 't': 1, "'": 1}

# %%
def visualization(dictionary, save_name='未指定名称',verbose=True):
    """
    visualize：输入待统计的字典，输出直方图并可视化，将得到的直方图保存到同一目录下。
    
    输入：
    -dictionary：字典       -输入需要可视化的字典，键为横坐标字符串，值为纵坐标数值。
    -save_name：字符串      -需要保存的统计图的名称
    -verbose：布尔值        -是否在统计图上显示统计数字，默认为显示
    """
    sorted_list = sorted(dictionary.items(), key=lambda item: item[0]) #sort方法用于对原列表进行排序，key用来进行比较的元素
    x_num = range(len(sorted_list))
    x_label = [x[0] for x in sorted_list]
    y_data = [x[1] for x in sorted_list]
    plt.xticks(x_num, x_label)
    b = plt.bar(x_label, y_data)
    if verbose:
        for rect in b:
            h = rect.get_height()#统计个数
            w = rect.get_width()
            x = rect.get_x()
            plt.text(x+w/2, h, '%d'%int(h), ha='center', va='bottom')

    str_sum = '标签总数：{}个'.format(sum(y_data))
    plt.xlabel('标签名')
    plt.ylabel('标签个数')
    plt.title(str_sum)#设置图表标题
    print(str_sum)#数据总量1371为box个数
    plt.savefig(save_name)
    plt.show()

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (20.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'#最近邻插值：像素为正方形
plt.rcParams['image.cmap'] = 'gray'#使用灰度输出而不是彩色输出
plt.rcParams['font.sans-serif']=['SimHei'] #显示中文标签

visualization(char_dic, save_name='所有类别统计图.png',verbose=True)
# Out:
# 标签总数：8533个

# %% [markdown]
# 合并同类项。其中新标注的数据里用&代替TC。

# %%
merged_dic = char_dic.copy()
if 'ct' in  merged_dic:
    merged_dic['tc'] += merged_dic['ct']#将ct类别合并到tc
    del merged_dic['ct']
for i, j in char_dic.items():
    l_list = i.split('_',1)
    if l_list[0].isupper():#把大写变成小写
        l_list[0] = l_list[0].lower()
        try:
            merged_dic[l_list[0]] += j
        except:
            merged_dic.setdefault(l_list[0], j)
        del merged_dic[i]
    if len(l_list) > 1:#例如c、c_f、c_n会被合并到一起
        merged_dic[l_list[0]] += j
        del merged_dic[i]

merged_dic.setdefault('tc', 0) 
merged_dic['tc'] += merged_dic['&']#将tc与&合并
del merged_dic['&']

visualization(merged_dic, save_name='合并统计图.png')
# Out:
# 标签总数：8533个

# %% [markdown]
# 剔除数目少于50以及标签为box的类别。

# %%
simplified_dic = merged_dic.copy()
if 'box'in simplified_dic: del simplified_dic['box']
new_dic = {}
for i, j in simplified_dic.items():
    if j >= 50:
        new_dic[i] = j

visualization(new_dic, save_name='50阈值统计图.png')
# Out:
# 标签总数：8281个

# %% [markdown]
# ## 转换标注格式
# 处理Labelme得到的json文件，输出单个字符以及字符串图片。

# %%
import json
import json
import os.path

#import cv2#透视变换

from skimage import io
import numpy as np
from labelme import utils

def get_box_with_label(shapes, is_char=True):
    '''
    依据标注块的标签长度，将每个标注块等分，返回每个字符的标签以及字符的坐标。
    
    输入：
    -shapes:字典          -单个json文件里的shapes字典，包括该图片内的所有矩形框。
    
    输出：
    -annotations：字典    -键：表示区域的标号，范围：[0, N)，代表这张图片里有N个字符区域。
                        值：是一个列表list，list[0]为字符标签，list[1]为字符在图像中的左上角与右下角坐标。
    '''
    annotations = {}
    idx = 0
    for i in range(len(shapes)):
        pts = np.array(shapes[i]['points']).astype(np.int32)#坐标
        string = shapes[i]['label'].lower()#标签
        string = string.split('_')[0]#标签，去除类似c_n这种标注
        string = string.replace('*','%') # 将字符串里的*全部替换成%
        string = string.replace(' ','') # 将字符串里的空格删除
        if string == 'box':#跳过老的标注框
            continue
        if string == 'tc' or string == 'ct':#修改老的标注
            string = '&'
        
        if is_char and len(string)>1 or string=='%':
            if len(pts) == 2:
                pts_x = pts[:, 0]#所有点的x坐标
                pts_y = pts[:, 1]#所有点的y坐标
            else:
                pts_x = [min(pts[:, 0]), max(pts[:, 0])]#所有点的x坐标
                pts_y = [min(pts[:, 1]), max(pts[:, 1])]#所有点的y坐标
            img_width = np.abs(pts_x[0] - pts_x[1])#区域宽度
            '''if string == '%':
                img_height = np.abs(pts_y[0] - pts_y[1])#区域高度
                string = '%' * (img_height // img_width * 2)#按照区域长宽比增加标签'''
            box_width = img_width // len(string)  # 分割的单个box的宽度
            pts_label = np.array([[min(pts_x) + box_width, min(pts_y)],
                                 [min(pts_x), max(pts_y)]])#右上角与左下角坐标

            for label in string:
                annotations[idx] = [label, pts_label.copy()]
                idx += 1
                pts_label[:, 0] += box_width  # update box
        else:
            annotations[i] = [string, pts.copy()]#右上角与左下角坐标（或左上角与右下角坐标）。
        
    return annotations

def image_crop(img, annotations):
    '''
    输入图片以及标记信息，返回切割后的图片的集合。
    
    输入：
    -img：图片            -image = utils.img_b64_to_arr(json_data['imageData'])
    -annotations：字典    -键：表示区域的标号，范围：[0, N)，代表这张图片里有N个字符区域。
                        值：是一个列表list，list[0]为字符标签，
                        list[1]为字符在图像中的右上角与左下角坐标（或左上角与右下角坐标）。
    
    输出：
    -img_set：字典        -键：表示图片的标号，范围：[0, N)，代表这张图片里有N个字符区域。
                        值：是一个列表list，list[0]为图片标签，list[1]为裁剪后的图片。
    '''
    img_set = {}
    for idx, values in annotations.items():
        label, pts = values
        points_h = pts[:, 1]
        points_w = pts[:, 0]

        img_cropped = img[np.min(points_h):np.max(points_h), np.min(points_w):np.max(points_w), :]
        img_set[idx] = [label, img_cropped]
    return img_set

def img_generator(json_dir, output_dir, is_char=True, img_try = True, verbose=True, try_num=3):
    '''
    输入json所在文件路径以及输出图片文件路径，返回切割后的图片到输出文件中。
    
    输入：
    -json_dir：字符串     -json所在文件夹的全路径
    -output_dir：字符串   -键：输出文件夹的名称，与该notebook处于同一目录。
    -is_char：布尔值      -True：切割后的图片为单个字符；False：切割后的图片为字符串
    -img_try：布尔值      -True：尝试处理前三张图片方便debug；False：处理所有图片，比较耗时
    -verbose：布尔值      -True：打印输出信息；False：不打印信息
    '''
    json_file_list = os.listdir(json_dir)

    #读取labelme标注
    if img_try:#尝试输出前N张图片的结果
        json_file_list = json_file_list[:try_num]
    for i in range(len(json_file_list)):
        json_filename = json_file_list[i]
        if verbose:
                print('正在处理第{}张图片，文件名为{}'.format(i, json_filename))
        json_file = open(os.path.join(json_dir, json_filename))
        json_data = json.load(json_file)

        image = utils.img_b64_to_arr(json_data['imageData'])#解析原图片数据
        shapes = json_data['shapes']

        json_file.close()

        annotations = get_box_with_label(shapes, is_char=is_char)
        image_set = image_crop(image, annotations)

        for i,(label, img) in image_set.items():
        #for label, img in image_set.values():
            label = label.replace('*','%') # 将字符串里的*全部替换成%
            filename = f'{label}_{json_filename[:-5]}_{i}.jpg'
            if not os.path.exists(os.path.join(output_dir, filename)):
                try:
                    #print(f'Creating {filename}')
                    io.imsave(os.path.join(output_dir, filename), img)
                except:
                    print('创建{}失败，数据来源{}。该标注可能不符合要求！'.format(filename, json_filename))
                    
            else:
                if verbose:
                    print(f'{filename} already existed!')

# %%
base = os.getcwd()
dir_list = [ '镀锌数据集标注/',  '剩余数据集标注/', '角铁数据集标注/']
output_dir = os.path.join(base, 'data_cropped/')#输出图片位置
if not os.path.exists(output_dir):
    os.mkdir(output_dir)

for file in dir_list:
    print('正在处理:{}'.format(file[:-1]))
    json_dir = os.path.join(base, file)#json所在位置
    #先得到单个字符的图片
    #img_generator(json_dir, output_dir, is_char=True, img_try = True, verbose=True, try_num=5)#实验
    img_generator(json_dir, output_dir, is_char=True, img_try = False, verbose=False)

dir_list = [ '镀锌数据集标注/',  '剩余数据集标注/']#当要用这里的方法切取字符串图片时，避免老的数据
for file in dir_list:
    print('正在处理:{}'.format(file[:-1]))
    json_dir = os.path.join(base, file)#json所在位置
    #先得到单个字符的图片
    #img_generator(json_dir, output_dir, is_char=False, img_try = True, verbose=True, try_num=3)#实验
    img_generator(json_dir, output_dir, is_char=False, img_try = False, verbose=False)
# Out:
# 正在处理:镀锌数据集标注
# C:\Users\FCT\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:121: UserWarning: E:\研二\20.19.10.1计算机视觉入门\铁塔项目标注\铁塔项目方案\数据集2020331\data_cropped/m_IMG_20200327_142326_0.jpg is a low contrast image
# C:\Users\FCT\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:121: UserWarning: E:\研二\20.19.10.1计算机视觉入门\铁塔项目标注\铁塔项目方案\数据集2020331\data_cropped/l_IMG_20200327_142326_1.jpg is a low contrast image
# C:\Users\FCT\AppData\Roaming\Python\Python37\site-packages\ipykernel_launcher.py:121: UserWarning: E:\研二\20.19.10.1计算机视觉入门\铁塔项目标注\铁塔项目方案\数据集2020331\data_cropped/-_IMG_20200327_143100_3.jpg is a low contrast image
# 正在处理:剩余数据集标注
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-11-46f8dd6b83a9> in <module>
#      10     #先得到单个字符的图片
#      11     #img_generator(json_dir, output_dir, is_char=True, img_try = True, verbose=True, try_num=5)#实验
# ---> 12     img_generator(json_dir, output_dir, is_char=True, img_try = False, verbose=False)
#      13
#      14 dir_list = [ '镀锌数据集标注/',  '剩余数据集标注/']#当要用这里的方法切取字符串图片时，避免老的数据
#
# <ipython-input-10-552fca34da58> in img_generator(json_dir, output_dir, is_char, img_try, verbose, try_num)
#      92     -verbose：布尔值      -True：打印输出信息；False：不打印信息
#      93     '''
# ---> 94     json_file_list = os.listdir(json_dir)
#      95
#      96     #读取labelme标注
#
# FileNotFoundError: [WinError 3] 系统找不到指定的路径。: 'E:\\研二\\20.19.10.1计算机视觉入门\\铁塔项目标注\\铁塔项目方案\\数据集2020331\\剩余数据集标注/'

# %% [markdown]
# <p>分别生成生成训练集与验证集的<code> groundTruth.txt </code>文件，此时，<code>groundTruth.txt</code> 应该为 <code>{图片路径}/t制表符{标签}/n回车</code> <br>
# 例如：</p>
# <pre><code>test/word_1.png Tiredness
# test/word_2.png kills
# test/word_3.png A
# ...
# </code></pre>

# %%
base = os.getcwd()
imgs_file = 'data_cropped/'
imgs_dir = os.path.join(base, imgs_file)#图片位置
gt_train = 'gt_train.txt'
gt_val = 'gt_val.txt'

imgs_list = os.listdir(imgs_dir)
print('图片张数：{}张'.format(len(imgs_list)))

data_dic = {}#键：标签；值：列表，列表内为属于该标签的所有图片历经，例如：[path/1.jpg,path/2.jpg]
train_dic = {}
val_dic = {}
for img_name in imgs_list:
    label = img_name.split('_')[0]#得到标签
    data_dic.setdefault(label, [])#设定初始值为空列表
    data_dic[label].append(imgs_file + img_name)

for label, x_list in data_dic.items():#将数据随机按0.92:0.08的比例分为训练集与验证集
    num = len(x_list)
    if num < 50:#样本太少的不加入验证集
        train_dic[label] = x_list
        continue
    mask = np.arange(num)
    np.random.shuffle(mask)#打乱数据
    train_idx = mask[:int(num*0.92)]
    val_idx = mask[int(num*0.92):]
    for idx in train_idx:
        train_dic.setdefault(label, [])#设定初始值为空列表
        train_dic[label].append(x_list[idx])
    for idx in val_idx:
        val_dic.setdefault(label, [])#设定初始值为空列表
        val_dic[label].append(x_list[idx])

with open(gt_train, "w") as f:#将train_dic的数据写入到记事本
    for label, train_list in train_dic.items():
        for img_dir in train_list:
            f.write('{}\t{}\n'.format(img_dir, label))

with open(gt_val, "w") as f:#将val_dic的数据写入到记事本
    for label, val_list in val_dic.items():
        for img_dir in val_list:
            f.write('{}\t{}\n'.format(img_dir, label))
# Out:
# 图片张数：28835张

# %% [markdown]
# 将图片与groundTruth.txt文件转换为lmdb格式的训练数据。

# %%
""" a modified version of CRNN torch repository https://github.com/bgshih/crnn/blob/master/tool/create_dataset.py """

import fire
import os
import lmdb
import cv2

import numpy as np


def checkImageIsValid(imageBin):
    if imageBin is None:
        return False
    imageBuf = np.frombuffer(imageBin, dtype=np.uint8)
    img = cv2.imdecode(imageBuf, cv2.IMREAD_GRAYSCALE)
    imgH, imgW = img.shape[0], img.shape[1]
    if imgH * imgW == 0:
        return False
    return True


def writeCache(env, cache):
    with env.begin(write=True) as txn:
        for k, v in cache.items():
            txn.put(k, v)


def createDataset(inputPath, gtFile, outputPath, checkValid=True, map_size=8589934592):
    """
    Create LMDB dataset for training and evaluation.
    ARGS:
        inputPath  : input folder path where starts imagePath
        outputPath : LMDB output path
        gtFile     : list of image path and label
        checkValid : if true, check the validity of every image
    """
    os.makedirs(outputPath, exist_ok=True)
    env = lmdb.open(outputPath, map_size=map_size)#85899345920/8Gb
    cache = {}
    cnt = 1

    with open(gtFile, 'r', encoding='utf-8') as data:
        datalist = data.readlines()

    nSamples = len(datalist)
    for i in range(nSamples):
        print(datalist[i])
        imagePath, label = datalist[i].strip('\n').split('\t')
        imagePath = os.path.join(inputPath, imagePath)

        # # only use alphanumeric data
        # if re.search('[^a-zA-Z0-9]', label):
        #     continue

        if not os.path.exists(imagePath):
            print('%s does not exist' % imagePath)
            continue
        with open(imagePath, 'rb') as f:
            imageBin = f.read()
        if checkValid:
            try:
                if not checkImageIsValid(imageBin):
                    print('%s is not a valid image' % imagePath)
                    continue
            except:
                print('error occured', i)
                with open(outputPath + '/error_image_log.txt', 'a') as log:
                    log.write('%s-th image data occured error\n' % str(i))
                continue

        imageKey = 'image-%09d'.encode() % cnt
        labelKey = 'label-%09d'.encode() % cnt
        cache[imageKey] = imageBin
        cache[labelKey] = label.encode()

        if cnt % 1000 == 0:
            writeCache(env, cache)
            cache = {}
            print('Written %d / %d' % (cnt, nSamples))
        cnt += 1
    nSamples = cnt-1
    cache['num-samples'.encode()] = str(nSamples).encode()
    writeCache(env, cache)
    print('Created dataset with %d samples' % nSamples)

# %% [markdown]
# 生成训练集的lmdb文件。查看训练集图片所在文件夹的大小，将map_size设置一样的大小即可。

# %%
inputPath = ''
gtFile_train = 'gt_train.txt'
outputPath_trainset = 'Lmdb_trainset/'
if not os.path.exists(outputPath_trainset):
    os.mkdir(outputPath_trainset)

map_size = 0.57 * 1e9#1e9为953MB
createDataset(inputPath, gtFile_train, outputPath_trainset, checkValid=True, map_size=map_size)
# Out:
# data_cropped/%%%a%%%%_IMG_20200327_144010_0.jpg	%%%a%%%%
#
# data_cropped/%%%a%_IMG_20200327_144130_2.jpg	%%%a%
#
# data_cropped/%%%a-%%%_IMG_20200327_143948_0.jpg	%%%a-%%%
#
# data_cropped/%%%h_IMG_20200327_144638_2.jpg	%%%h
#
# data_cropped/%%%_IMG_20200327_140725_0.jpg	%%%
#
# data_cropped/%%-hvdc-jp1_IMG_20200327_142846_0.jpg	%%-hvdc-jp1
#
# data_cropped/%%-hvdc-jp1_IMG_20200327_142903_0.jpg	%%-hvdc-jp1
#
# data_cropped/%%l_IMG_20200327_142705_0.jpg	%%l
#
# data_cropped/%%_IMG_20200327_140049_0.jpg	%%
#
# data_cropped/%%_IMG_20200327_142839_0.jpg	%%
#
# data_cropped/%375_IMG_20200327_142431_1.jpg	%375
#
# data_cropped/%vdc-ze2_IMG_20200327_143253_1.jpg	%vdc-ze2
#
# data_cropped/%_IMG_20200327_142431_12.jpg	%
#
# data_cropped/%_IMG_20200327_144007_5.jpg	%
#
# data_cropped/%_IMG_20200327_142705_0.jpg	%
#
# data_cropped/%_IMG_20200327_144007_8.jpg	%
#
# data_cropped/%_IMG_20200327_144010_4.jpg	%
#
# data_cropped/%_IMG_20200327_140304_2.jpg	%
#
# data_cropped/%_IMG_20200327_140542_1.jpg	%
#
# data_cropped/%_IMG_20200327_140049_1.jpg	%
#
# data_cropped/%_IMG_20200327_143001_13.jpg	%
#
# data_cropped/%_IMG_20200327_140725_1.jpg	%
#
# data_cropped/%_IMG_20200327_144130_11.jpg	%
#
# data_cropped/%_IMG_20200327_143149_11.jpg	%
#
# data_cropped/%_IMG_20200327_143948_2.jpg	%
#
# data_cropped/%_IMG_20200327_143253_3.jpg	%
#
# data_cropped/%_IMG_20200327_144007_4.jpg	%
#
# data_cropped/%_IMG_20200327_142839_1.jpg	%
#
# data_cropped/%_IMG_20200327_144007_2.jpg	%
#
# data_cropped/%_IMG_20200327_140049_0.jpg	%
#
# data_cropped/%_IMG_20200327_144326_14.jpg	%
#
# data_cropped/%_IMG_20200327_143948_6.jpg	%
#
# data_cropped/%_IMG_20200327_140303_2.jpg	%
#
# data_cropped/%_IMG_20200327_142350_4.jpg	%
#
# data_cropped/%_IMG_20200327_144010_2.jpg	%
#
# data_cropped/%_IMG_20200327_144010_5.jpg	%
#
# data_cropped/%_IMG_20200327_144007_3.jpg	%
#
# data_cropped/%_IMG_20200327_142903_0.jpg	%
#
# data_cropped/%_IMG_20200327_142846_0.jpg	%
#
# data_cropped/%_IMG_20200327_144010_0.jpg	%
#
# data_cropped/%_IMG_20200327_142705_1.jpg	%
#
# data_cropped/%_IMG_20200327_142846_1.jpg	%
#
# data_cropped/%_IMG_20200327_142839_0.jpg	%
#
# data_cropped/%_IMG_20200327_144130_9.jpg	%
#
# data_cropped/%_IMG_20200327_144638_18.jpg	%
#
# data_cropped/%_IMG_20200327_144010_7.jpg	%
#
# data_cropped/%_IMG_20200327_144130_13.jpg	%
#
# data_cropped/%_IMG_20200327_143948_7.jpg	%
#
# data_cropped/%_IMG_20200327_144130_10.jpg	%
#
# data_cropped/%_IMG_20200327_144007_6.jpg	%
#
# data_cropped/%_IMG_20200327_142903_1.jpg	%
#
# data_cropped/%_IMG_20200327_144010_6.jpg	%
#
# data_cropped/%_IMG_20200327_143948_5.jpg	%
#
# data_cropped/%_IMG_20200327_140725_0.jpg	%
#
# data_cropped/%_IMG_20200327_140420_1.jpg	%
#
# data_cropped/%_IMG_20200327_144007_7.jpg	%
#
# data_cropped/%_IMG_20200327_143948_1.jpg	%
#
# data_cropped/%_IMG_20200327_140932_0.jpg	%
#
# data_cropped/&0h_IMG_20200327_144204_0.jpg	&0h
#
# data_cropped/&0_2019-10-26 121616_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121628_1.jpg	&0
#
# data_cropped/&0_2019-10-26 121635_1.jpg	&0
#
# data_cropped/&0_2019-10-26 121659_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121710_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121719_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121726_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121735_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121745_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121751_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121757_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121812_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121820_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121830_2.jpg	&0
#
# data_cropped/&0_2019-10-26 121838_2.jpg	&0
#
# data_cropped/&0_2019-10-26 122114_2.jpg	&0
#
# data_cropped/&0_2019-10-26 122156_2.jpg	&0
#
# data_cropped/&0_2019-10-26 122302_2.jpg	&0
#
# data_cropped/&0_2019-10-26 122307_2.jpg	&0
#
# data_cropped/&0_2019-10-26 122315_2.jpg	&0
#
# data_cropped/&0_2019-10-26 122323_2.jpg	&0
#
# data_cropped/&0_2019-10-26 122329_2.jpg	&0
#
# data_cropped/&0_2019-10-26 122336_2.jpg	&0
#
# data_cropped/&0_IMG_2616_2.jpg	&0
#
# data_cropped/&0_IMG_2860_2.jpg	&0
#
# data_cropped/&0_IMG_2861_2.jpg	&0
#
# data_cropped/&1a3-zmc2_IMG_20200327_143302_0.jpg	&1a3-zmc2
#
# data_cropped/&1a3-zmc2_IMG_20200327_143332_0.jpg	&1a3-zmc2
#
# data_cropped/&1a3-zmc2_IMG_20200327_144647_0.jpg	&1a3-zmc2
#
# data_cropped/&1a3-zmc2_IMG_20200327_144738_0.jpg	&1a3-zmc2
#
# data_cropped/&1a6-j1_IMG_20200327_144217_0.jpg	&1a6-j1
#
# data_cropped/&226cbssj2_2019-10-26 115136_0.jpg	&226cbssj2
#
# data_cropped/&226cbssj2_2019-10-26 115319_0.jpg	&226cbssj2
#
# data_cropped/&226cbssj2_2019-10-26 115421_0.jpg	&226cbssj2
#
# data_cropped/&226cbssj2_2019-10-26 115642_0.jpg	&226cbssj2
#
# data_cropped/&226cbssj2_2019-10-26 115645_0.jpg	&226cbssj2
#
# data_cropped/&226cbssj2_2019-10-26 115648_0.jpg	&226cbssj2
#
# data_cropped/&226cbssj2_20191026_115027_0.jpg	&226cbssj2
#
# data_cropped/&226cbssj3_2019-10-26 115709_0.jpg	&226cbssj3
#
# data_cropped/&2b5a-jc1_IMG_20200327_143954_1.jpg	&2b5a-jc1
#
# data_cropped/&2b5a-jc1_IMG_20200327_143957_0.jpg	&2b5a-jc1
#
# data_cropped/&2c2-jc1a_2019-10-26 115238_0.jpg	&2c2-jc1a
#
# data_cropped/&2c2-jc1a_2019-10-26 115241_0.jpg	&2c2-jc1a
#
# data_cropped/&2c2-jc1a_2019-10-26 115246_1.jpg	&2c2-jc1a
#
# data_cropped/&2c2jc1a_20191026_115115_0.jpg	&2c2jc1a
#
# data_cropped/&2e3a-szc_IMG_2725_0.jpg	&2e3a-szc
#
# data_cropped/&2e3a-szc_IMG_2730_0.jpg	&2e3a-szc
#
# data_cropped/&2e3a-szc_IMG_2737_0.jpg	&2e3a-szc
#
# data_cropped/&2e3a-szc_IMG_2738_0.jpg	&2e3a-szc
#
# data_cropped/&2e3a-szc_IMG_2739_0.jpg	&2e3a-szc
#
# data_cropped/&2e3a-szc_IMG_2740_0.jpg	&2e3a-szc
#
# data_cropped/&2e3a-szc_IMG_2741_0.jpg	&2e3a-szc
#
# data_cropped/&2e3a-szc_IMG_2743_0.jpg	&2e3a-szc
#
# data_cropped/&2e3a-szc_IMG_2765_2.jpg	&2e3a-szc
#
# data_cropped/&2e3a-szc_IMG_2767_2.jpg	&2e3a-szc
#
# data_cropped/&2e3a-szc_IMG_2768_2.jpg	&2e3a-szc
#
# data_cropped/&2e3a-sz_IMG_2700_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2681_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2694_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2642_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2625_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2650_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2672_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2678_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115402_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2659_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2649_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2710_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2682_2.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2708_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2631_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2620_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2695_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2618_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2623_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2711_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2648_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2626_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2638_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2636_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2652_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2693_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2662_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115338_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2628_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2630_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2653_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2633_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2645_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115119_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2637_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2680_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2629_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2671_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2699_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2707_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2696_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115359_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2643_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2640_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2660_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2712_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2661_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2668_2.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2658_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2701_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2644_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2679_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2663_1.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2632_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2677_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2670_2.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2654_0.jpg	&2e3a-sz
# data_cropped/&2e3a-sz_IMG_2651_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115155_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2627_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2673_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2685_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2666_1.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2667_2.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2687_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2665_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2675_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115103_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115404_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2624_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2704_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2697_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2703_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2684_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2646_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2635_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115110_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115108_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2683_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2676_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2619_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2622_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2686_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115059_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2655_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2705_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2669_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2709_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2688_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2656_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115340_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2698_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2621_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2690_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2647_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2657_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2689_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2692_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a_2019-10-26 115151_3.jpg	&2e3a
#
# data_cropped/&2e3a_IMG_2617_0.jpg	&2e3a
#
# data_cropped/&2e5asjc1_2019-10-26 115131_0.jpg	&2e5asjc1
#
# data_cropped/&2f2-sjzg1_IMG_20200327_140631_0.jpg	&2f2-sjzg1
#
# data_cropped/&2f2-sjzg1_IMG_20200327_140638_0.jpg	&2f2-sjzg1
#
# data_cropped/&2f2-sjzg1_IMG_20200327_140644_0.jpg	&2f2-sjzg1
#
# data_cropped/&2_2019-10-26 114107_2.jpg	&2
#
# data_cropped/&2_2019-10-26 114114_2.jpg	&2
#
# data_cropped/&2_2019-10-26 114137_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114142_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114201_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114208_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114222_2.jpg	&2
#
# data_cropped/&2_2019-10-26 114243_2.jpg	&2
#
# data_cropped/&2_2019-10-26 114255_2.jpg	&2
#
# data_cropped/&2_2019-10-26 114301_2.jpg	&2
#
# data_cropped/&2_2019-10-26 114318_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114321_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114325_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114341_2.jpg	&2
#
# data_cropped/&2_2019-10-26 114418_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114456_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114506_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114518_2.jpg	&2
#
# data_cropped/&2_2019-10-26 114531_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114538_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114543_2.jpg	&2
#
# data_cropped/&2_2019-10-26 114550_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114554_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114603_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114607_2.jpg	&2
#
# data_cropped/&2_2019-10-26 114611_3.jpg	&2
#
# data_cropped/&2_2019-10-26 114638_3.jpg	&2
#
# data_cropped/&2_2019-10-26 120323_1.jpg	&2
#
# data_cropped/&2_2019-10-26 120330_3.jpg	&2
#
# data_cropped/&2_2019-10-26 120336_3.jpg	&2
#
# data_cropped/&2_2019-10-26 120342_3.jpg	&2
#
# data_cropped/&2_2019-10-26 120351_3.jpg	&2
#
# data_cropped/&2_2019-10-26 120415_3.jpg	&2
#
# data_cropped/&2_2019-10-26 120440_3.jpg	&2
#
# data_cropped/&2_2019-10-26 120451_3.jpg	&2
#
# data_cropped/&2_2019-10-26 120503_3.jpg	&2
#
# data_cropped/&2_2019-10-26 120517_3.jpg	&2
#
# data_cropped/&2_20191026_112857_4.jpg	&2
#
# data_cropped/&2_20191026_112906_4.jpg	&2
#
# data_cropped/&2_20191026_112947_2.jpg	&2
#
# data_cropped/&2_20191026_113037_3.jpg	&2
#
# data_cropped/&2_20191026_113055_2.jpg	&2
#
# data_cropped/&2_20191026_113107_2.jpg	&2
#
# data_cropped/&2_20191026_113255_2.jpg	&2
#
# data_cropped/&2_20191026_113302_2.jpg	&2
#
# data_cropped/&3%%%%%%%_IMG_20200327_144007_0.jpg	&3%%%%%%%
#
# data_cropped/&3_IMG_20200327_142457_2.jpg	&3
#
# data_cropped/&566-sz6kx_IMG_20200327_144106_0.jpg	&566-sz6kx
#
# data_cropped/&566_IMG_20200327_144103_0.jpg	&566
#
# data_cropped/&5c3a-sj1_IMG_20200327_142420_0.jpg	&5c3a-sj1
#
# data_cropped/&5c3a-sj1_IMG_20200327_142426_0.jpg	&5c3a-sj1
#
# data_cropped/&5c6-8zck_IMG_20200327_144130_0.jpg	&5c6-8zck
#
# data_cropped/&5c6-szckx_IMG_20200327_143030_0.jpg	&5c6-szckx
#
# data_cropped/&5c6_IMG_20200327_144113_0.jpg	&5c6
#
# data_cropped/&5c6_IMG_20200327_144137_1.jpg	&5c6
#
# data_cropped/&5e3-sj4_2019-10-26 115226_0.jpg	&5e3-sj4
#
# data_cropped/&5e3-sj4_2019-10-26 115231_0.jpg	&5e3-sj4
#
# data_cropped/&5e3-szk_IMG_20200327_141437_1.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_141437_3.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_141446_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_141451_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_143137_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_143149_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_143156_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_143204_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_143214_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_143227_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_143232_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_143246_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_143514_0.jpg	&5e3-szk
#
# data_cropped/&5e3-szk_IMG_20200327_143522_0.jpg	&5e3-szk
#
# data_cropped/&5e3a-szc_2019-10-26 115329_0.jpg	&5e3a-szc
#
# data_cropped/&6_IMG_2857_2.jpg	&6
#
# data_cropped/&8_IMG_2857_3.jpg	&8
#
# data_cropped/&8_IMG_2858_2.jpg	&8
#
# data_cropped/&9_2019-10-26 120135_2.jpg	&9
#
# data_cropped/&a_2019-10-26 114711_2.jpg	&a
#
# data_cropped/&a_2019-10-26 114827_2.jpg	&a
#
# data_cropped/&a_2019-10-26 114907_2.jpg	&a
#
# data_cropped/&b25a-jc1_IMG_20200327_143954_0.jpg	&b25a-jc1
#
# data_cropped/&bk-7a5a-zbc3_IMG_20200327_144857_0.jpg	&bk-7a5a-zbc3
#
# data_cropped/&b_IMG_2477_2.jpg	&b
#
# data_cropped/&b_IMG_2544_1.jpg	&b
#
# data_cropped/&b_20191026_110413_2.jpg	&b
#
# data_cropped/&b_IMG_2587_2.jpg	&b
#
# data_cropped/&b_IMG_2492_2.jpg	&b
#
# data_cropped/&b_IMG_2603_2.jpg	&b
#
# data_cropped/&b_2019-10-26 110931_2.jpg	&b
#
# data_cropped/&b_IMG_2500_2.jpg	&b
#
# data_cropped/&b_IMG_20200327_140700_2.jpg	&b
#
# data_cropped/&b_IMG_2499_2.jpg	&b
#
# data_cropped/&b_IMG_2489_2.jpg	&b
#
# data_cropped/&b_20191026_110401_2.jpg	&b
#
# data_cropped/&b_2019-10-26 103719_2.jpg	&b
#
# data_cropped/&b_IMG_2584_2.jpg	&b
#
# data_cropped/&b_IMG_2579_2.jpg	&b
#
# data_cropped/&b_2019-10-26 122407_2.jpg	&b
#
# data_cropped/&b_IMG_2496_2.jpg	&b
#
# data_cropped/&b_20191026_110255_2.jpg	&b
#
# data_cropped/&b_20191026_110320_2.jpg	&b
#
# data_cropped/&b_IMG_2545_2.jpg	&b
#
# data_cropped/&b_2019-10-26 110911_2.jpg	&b
#
# data_cropped/&b_2019-10-26 122402_2.jpg	&b
#
# data_cropped/&b_IMG_2479_2.jpg	&b
#
# data_cropped/&b_IMG_2562_2.jpg	&b
#
# data_cropped/&b_IMG_2516_2.jpg	&b
#
# data_cropped/&b_IMG_2595_2.jpg	&b
#
# data_cropped/&b_IMG_2546_2.jpg	&b
#
# data_cropped/&b_IMG_2530_2.jpg	&b
#
# data_cropped/&b_IMG_2556_2.jpg	&b
#
# data_cropped/&b_2019-10-26 110630_2.jpg	&b
#
# data_cropped/&b_IMG_2513_2.jpg	&b
#
# data_cropped/&b_IMG_2467_2.jpg	&b
#
# data_cropped/&b_IMG_2606_2.jpg	&b
#
# data_cropped/&b_IMG_2574_2.jpg	&b
#
# data_cropped/&b_IMG_2610_2.jpg	&b
#
# data_cropped/&b_IMG_2512_2.jpg	&b
#
# data_cropped/&b_IMG_2532_2.jpg	&b
#
# data_cropped/&b_IMG_2538_2.jpg	&b
#
# data_cropped/&b_IMG_2608_2.jpg	&b
#
# data_cropped/&b_20191026_110448_2.jpg	&b
#
# data_cropped/&b_IMG_2488_2.jpg	&b
#
# data_cropped/&b_IMG_2551_2.jpg	&b
#
# data_cropped/&b_IMG_2475_2.jpg	&b
#
# data_cropped/&b_IMG_2596_2.jpg	&b
#
# data_cropped/&b_IMG_2613_2.jpg	&b
#
# data_cropped/&b_IMG_2498_2.jpg	&b
#
# data_cropped/&b_IMG_2565_2.jpg	&b
#
# data_cropped/&b_IMG_2557_2.jpg	&b
#
# data_cropped/&b_IMG_2591_2.jpg	&b
#
# data_cropped/&b_2019-10-26 122439_1.jpg	&b
#
# data_cropped/&b_IMG_2537_2.jpg	&b
#
# data_cropped/&b_2019-10-26 110834_2.jpg	&b
#
# data_cropped/&b_IMG_2494_2.jpg	&b
# data_cropped/&b_IMG_2561_2.jpg	&b
#
# data_cropped/&b_20191026_110309_2.jpg	&b
#
# data_cropped/&b_IMG_2514_2.jpg	&b
#
# data_cropped/&b_IMG_2607_2.jpg	&b
#
# data_cropped/&b_IMG_2566_2.jpg	&b
#
# data_cropped/&b_IMG_2597_2.jpg	&b
#
# data_cropped/&b_IMG_2508_3.jpg	&b
#
# data_cropped/&b_IMG_2585_2.jpg	&b
#
# data_cropped/&b_IMG_2580_2.jpg	&b
#
# data_cropped/&b_IMG_2571_2.jpg	&b
#
# data_cropped/&b_IMG_2559_2.jpg	&b
#
# data_cropped/&b_IMG_2484_2.jpg	&b
#
# data_cropped/&b_IMG_2541_2.jpg	&b
#
# data_cropped/&b_IMG_2553_2.jpg	&b
#
# data_cropped/&b_IMG_2497_2.jpg	&b
#
# data_cropped/&b_IMG_2466_2.jpg	&b
#
# data_cropped/&b_2019-10-26 110744_2.jpg	&b
#
# data_cropped/&b_IMG_2502_2.jpg	&b
#
# data_cropped/&b_IMG_2586_2.jpg	&b
#
# data_cropped/&b_IMG_2583_2.jpg	&b
#
# data_cropped/&b_IMG_2517_2.jpg	&b
#
# data_cropped/&b_IMG_20200327_140707_2.jpg	&b
#
# data_cropped/&b_IMG_2483_2.jpg	&b
#
# data_cropped/&b_IMG_2528_2.jpg	&b
#
# data_cropped/&b_IMG_2474_2.jpg	&b
#
# data_cropped/&b_IMG_2521_2.jpg	&b
#
# data_cropped/&b_IMG_2491_2.jpg	&b
#
# data_cropped/&b_IMG_2504_2.jpg	&b
#
# data_cropped/&b_IMG_2590_2.jpg	&b
#
# data_cropped/&b_IMG_2529_2.jpg	&b
#
# data_cropped/&b_IMG_2564_2.jpg	&b
#
# data_cropped/&b_IMG_2569_2.jpg	&b
#
# data_cropped/&b_IMG_2511_2.jpg	&b
#
# data_cropped/&b_IMG_2567_2.jpg	&b
#
# data_cropped/&b_IMG_2515_2.jpg	&b
#
# data_cropped/&b_IMG_2525_2.jpg	&b
#
# data_cropped/&b_IMG_2509_2.jpg	&b
#
# data_cropped/&b_IMG_2604_2.jpg	&b
#
# data_cropped/&b_IMG_2503_2.jpg	&b
#
# data_cropped/&b_IMG_20200327_140218_2.jpg	&b
#
# data_cropped/&b_IMG_2487_2.jpg	&b
#
# data_cropped/&b_IMG_2505_2.jpg	&b
#
# data_cropped/&b_IMG_2609_2.jpg	&b
#
# data_cropped/&b_IMG_2602_2.jpg	&b
#
# data_cropped/&b_IMG_2552_2.jpg	&b
#
# data_cropped/&b_IMG_2575_2.jpg	&b
#
# data_cropped/&b_IMG_2473_2.jpg	&b
#
# data_cropped/&b_IMG_2612_2.jpg	&b
#
# data_cropped/&b_20191026_110338_2.jpg	&b
#
# data_cropped/&b_20191026_110350_2.jpg	&b
#
# data_cropped/&b_IMG_2577_2.jpg	&b
#
# data_cropped/&b_IMG_2486_2.jpg	&b
#
# data_cropped/&b_20191026_110431_2.jpg	&b
#
# data_cropped/&b_IMG_2554_2.jpg	&b
#
# data_cropped/&b_IMG_2555_2.jpg	&b
#
# data_cropped/&b_IMG_2520_2.jpg	&b
#
# data_cropped/&b_IMG_2476_2.jpg	&b
#
# data_cropped/&b_IMG_2598_2.jpg	&b
#
# data_cropped/&b_20191026_110517_2.jpg	&b
#
# data_cropped/&b_IMG_2534_2.jpg	&b
#
# data_cropped/&b_IMG_2572_2.jpg	&b
#
# data_cropped/&b_IMG_2549_2.jpg	&b
#
# data_cropped/&b_2019-10-26 103605_2.jpg	&b
#
# data_cropped/&b_IMG_2493_2.jpg	&b
#
# data_cropped/&b_IMG_2531_2.jpg	&b
#
# data_cropped/&b_IMG_2510_2.jpg	&b
#
# data_cropped/&b_2019-10-26 122443_1.jpg	&b
#
# data_cropped/&b_2019-10-26 110643_2.jpg	&b
#
# data_cropped/&b_IMG_2539_2.jpg	&b
#
# data_cropped/&b_IMG_2587_5.jpg	&b
#
# data_cropped/&b_IMG_2573_2.jpg	&b
#
# data_cropped/&b_IMG_2568_2.jpg	&b
#
# data_cropped/&b_2019-10-26 103539_2.jpg	&b
#
# data_cropped/&b_IMG_2519_2.jpg	&b
#
# data_cropped/&b_IMG_20200327_140408_0.jpg	&b
#
# data_cropped/&b_IMG_2480_2.jpg	&b
#
# data_cropped/&b_IMG_2563_2.jpg	&b
#
# data_cropped/&b_IMG_2506_2.jpg	&b
#
# data_cropped/&b_IMG_2535_2.jpg	&b
#
# data_cropped/&b_IMG_2524_2.jpg	&b
#
# data_cropped/&b_IMG_2481_2.jpg	&b
#
# data_cropped/&b_IMG_20200327_140651_2.jpg	&b
#
# data_cropped/&b_IMG_2550_2.jpg	&b
#
# data_cropped/&b_IMG_2526_2.jpg	&b
#
# data_cropped/&b_IMG_2536_2.jpg	&b
#
# data_cropped/&b_IMG_2522_2.jpg	&b
#
# data_cropped/&b_IMG_2570_2.jpg	&b
#
# data_cropped/&b_IMG_2599_2.jpg	&b
#
# data_cropped/&b_IMG_20200327_140645_2.jpg	&b
#
# data_cropped/&b_IMG_2578_2.jpg	&b
#
# data_cropped/&b_IMG_2558_2.jpg	&b
#
# data_cropped/&b_IMG_2495_2.jpg	&b
#
# data_cropped/&b_IMG_20200327_140155_2.jpg	&b
#
# data_cropped/&b_IMG_2518_2.jpg	&b
#
# data_cropped/&b_IMG_2478_2.jpg	&b
#
# data_cropped/&b_2019-10-26 103802_1.jpg	&b
#
# data_cropped/&b_IMG_20200327_140446_0.jpg	&b
#
# data_cropped/&b_IMG_2540_2.jpg	&b
#
# data_cropped/&b_IMG_2501_2.jpg	&b
#
# data_cropped/&b_IMG_2548_2.jpg	&b
#
# data_cropped/&b_IMG_2490_2.jpg	&b
#
# data_cropped/&b_IMG_2482_2.jpg	&b
#
# data_cropped/&b_IMG_2523_2.jpg	&b
#
# data_cropped/&b_IMG_2588_2.jpg	&b
#
# data_cropped/&b_IMG_2582_2.jpg	&b
#
# data_cropped/&b_20191026_110505_2.jpg	&b
#
# data_cropped/&b_IMG_2533_2.jpg	&b
#
# data_cropped/&b_IMG_2611_2.jpg	&b
#
# data_cropped/&c_IMG_20200327_140204_2.jpg	&c
#
# data_cropped/&c_IMG_20200327_142300_2.jpg	&c
#
# data_cropped/&c_IMG_20200327_142313_2.jpg	&c
#
# data_cropped/&c_IMG_20200327_142359_2.jpg	&c
#
# data_cropped/&dm_IMG_20200327_144250_1.jpg	&dm
#
# data_cropped/&e_2019-10-26 120445_3.jpg	&e
#
# data_cropped/&f_2019-10-26 114122_3.jpg	&f
#
# data_cropped/&f_IMG_20200327_142903_2.jpg	&f
#
# data_cropped/&f_IMG_20200327_142903_6.jpg	&f
#
# data_cropped/&g_IMG_20200327_142411_2.jpg	&g
#
# data_cropped/&g_IMG_2842_2.jpg	&g
#
# data_cropped/&g_IMG_2843_2.jpg	&g
#
# data_cropped/&g_IMG_2846_2.jpg	&g
#
# data_cropped/&g_IMG_2847_2.jpg	&g
#
# data_cropped/&g_IMG_2856_2.jpg	&g
#
# data_cropped/&g_IMG_2859_2.jpg	&g
#
# data_cropped/&g_IMG_2866_2.jpg	&g
#
# data_cropped/&g_IMG_2867_2.jpg	&g
#
# data_cropped/&g_IMG_2868_2.jpg	&g
#
# data_cropped/&g_IMG_2869_2.jpg	&g
#
# data_cropped/&g_IMG_2870_2.jpg	&g
#
# data_cropped/&g_IMG_2871_2.jpg	&g
#
# data_cropped/&g_IMG_2872_2.jpg	&g
#
# data_cropped/&g_IMG_2873_2.jpg	&g
#
# data_cropped/&g_IMG_2875_2.jpg	&g
#
# data_cropped/&g_IMG_2876_2.jpg	&g
#
# data_cropped/&g_IMG_2877_2.jpg	&g
#
# data_cropped/&g_IMG_2878_2.jpg	&g
#
# data_cropped/&g_IMG_2879_2.jpg	&g
#
# data_cropped/&g_IMG_2880_2.jpg	&g
#
# data_cropped/&g_IMG_2881_2.jpg	&g
#
# data_cropped/&g_IMG_2882_2.jpg	&g
#
# data_cropped/&g_IMG_2883_4.jpg	&g
#
# data_cropped/&g_IMG_2903_4.jpg	&g
#
# data_cropped/&g_IMG_2928_2.jpg	&g
#
# data_cropped/&hl-hvdc-je1_IMG_20200327_143731_0.jpg	&hl-hvdc-je1
#
# data_cropped/&hl-hvdc-je1_IMG_20200327_143748_0.jpg	&hl-hvdc-je1
#
# data_cropped/&i_2019-10-26 103940_2.jpg	&i
#
# data_cropped/&i_2019-10-26 103949_2.jpg	&i
#
# data_cropped/&i_2019-10-26 103955_2.jpg	&i
#
# data_cropped/&i_2019-10-26 104006_2.jpg	&i
#
# data_cropped/&i_2019-10-26 104027_2.jpg	&i
#
# data_cropped/&i_2019-10-26 104058_2.jpg	&i
#
# data_cropped/&i_2019-10-26 104058_4.jpg	&i
#
# data_cropped/&i_2019-10-26 104144_2.jpg	&i
#
# data_cropped/&i_2019-10-26 104148_2.jpg	&i
#
# data_cropped/&i_2019-10-26 104157_2.jpg	&i
#
# data_cropped/&i_2019-10-26 104212_2.jpg	&i
#
# data_cropped/&i_2019-10-26 104223_2.jpg	&i
#
# data_cropped/&i_IMG_20200327_142839_3.jpg	&i
#
# data_cropped/&i_IMG_20200327_142846_2.jpg	&i
#
# data_cropped/&i_IMG_2468_2.jpg	&i
#
# data_cropped/&i_IMG_2470_2.jpg	&i
#
# data_cropped/&j_2019-10-26 121851_2.jpg	&j
#
# data_cropped/&j_2019-10-26 121858_2.jpg	&j
#
# data_cropped/&j_2019-10-26 121906_2.jpg	&j
#
# data_cropped/&j_2019-10-26 121916_1.jpg	&j
#
# data_cropped/&j_2019-10-26 121928_2.jpg	&j
#
# data_cropped/&j_2019-10-26 121935_2.jpg	&j
#
# data_cropped/&j_2019-10-26 122010_1.jpg	&j
#
# data_cropped/&j_2019-10-26 122024_2.jpg	&j
#
# data_cropped/&j_2019-10-26 122038_2.jpg	&j
#
# data_cropped/&j_2019-10-26 122045_2.jpg	&j
#
# data_cropped/&j_2019-10-26 122352_2.jpg	&j
#
# data_cropped/&j_IMG_2614_2.jpg	&j
#
# data_cropped/&j_IMG_2615_2.jpg	&j
#
# data_cropped/&ml-hvcd_IMG_20200327_143001_0.jpg	&ml-hvcd
#
# data_cropped/&ml-hvd-jp2_IMG_20200327_142107_0.jpg	&ml-hvd-jp2
#
# data_cropped/&ml-hvd-jp2_IMG_20200327_142129_0.jpg	&ml-hvd-jp2
#
# data_cropped/&ml-hvd-jp2_IMG_20200327_142138_0.jpg	&ml-hvd-jp2
#
# data_cropped/&ml-hvd-jp2_IMG_20200327_142143_0.jpg	&ml-hvd-jp2
#
# data_cropped/&ml-hvd-jp2_IMG_20200327_142151_0.jpg	&ml-hvd-jp2
#
# data_cropped/&ml-hvd-jp2_IMG_20200327_142154_0.jpg	&ml-hvd-jp2
#
# data_cropped/&ml-hvd-jp2_IMG_20200327_142159_0.jpg	&ml-hvd-jp2
#
# data_cropped/&ml-hvdc-3p2_IMG_20200327_143925_0.jpg	&ml-hvdc-3p2
#
# data_cropped/&ml-hvdc-je1_IMG_20200327_143735_0.jpg	&ml-hvdc-je1
#
# data_cropped/&ml-hvdc-je1_IMG_20200327_143755_0.jpg	&ml-hvdc-je1
#
# data_cropped/&ml-hvdc-je1_IMG_20200327_143804_0.jpg	&ml-hvdc-je1
#
# data_cropped/&ml-hvdc-je1_IMG_20200327_143808_0.jpg	&ml-hvdc-je1
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_140952_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141010_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141157_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141209_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141230_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141236_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141244_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141300_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141315_1.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141317_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141344_1.jpg	&ml-hvdc-jp2
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141348_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141355_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141500_1.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141506_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141623_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141658_1.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141715_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_141738_1.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142204_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142214_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142218_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142230_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142240_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142250_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142258_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142304_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142325_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142403_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142409_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142431_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_142441_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_143123_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_143213_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_144015_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_144107_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp2_IMG_20200327_144708_0.jpg	&ml-hvdc-jp2
#
# data_cropped/&ml-hvdc-jp3_IMG_20200327_143116_0.jpg	&ml-hvdc-jp3
#
# data_cropped/&ml-hvdc-jp3_IMG_20200327_143647_0.jpg	&ml-hvdc-jp3
#
# data_cropped/&ml-hvdc-jp3_IMG_20200327_144654_0.jpg	&ml-hvdc-jp3
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143008_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143021_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143100_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143131_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143145_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143209_1.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143235_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143306_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143308_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143323_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143430_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143455_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-ze2_IMG_20200327_143523_0.jpg	&ml-hvdc-ze2
#
# data_cropped/&ml-hvdc-zl2_IMG_20200327_143843_0.jpg	&ml-hvdc-zl2
#
# data_cropped/&ml-hvdc_2019-10-26 115436_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_2019-10-26 115443_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_140704_2.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_141211_2.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_141228_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_141246_2.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_141327_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_141334_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_141340_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_141356_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_141418_2.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_141435_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142158_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142209_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142223_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142247_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142252_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142534_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142609_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142627_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142629_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142632_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142636_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142644_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142647_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142715_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142738_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142748_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142856_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142900_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142904_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_142957_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_143020_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_143029_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_143034_2.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_143046_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_143229_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_143425_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_143447_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_143515_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_143915_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_143933_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_144050_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvdc_IMG_20200327_144054_0.jpg	&ml-hvdc
#
# data_cropped/&ml-hvd_IMG_20200327_140820_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_140907_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_140914_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141017_2.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141115_2.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141239_2.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141253_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141301_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141423_2.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141443_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141519_2.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141523_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141532_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141642_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141805_1.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141816_2.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141822_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_141950_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142008_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142013_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142017_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142041_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142046_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142101_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142105_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142135_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142152_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142546_0.jpg	&ml-hvd
#
# data_cropped/&ml-hvd_IMG_20200327_142615_0.jpg	&ml-hvd
#
# data_cropped/&ml-_IMG_20200327_141650_0.jpg	&ml-
#
# data_cropped/&ml-_IMG_20200327_143743_0.jpg	&ml-
#
# data_cropped/&ml_2019-10-26 115014_0.jpg	&ml
#
# data_cropped/&ml_2019-10-26 115023_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142544_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142548_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142558_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142601_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142617_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142623_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142633_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142638_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142643_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142653_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142701_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142711_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142719_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142725_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142734_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142742_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142750_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142915_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142919_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142926_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142930_0.jpg	&ml
# data_cropped/&ml_IMG_20200327_142936_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142939_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_142945_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143000_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143015_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143028_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143203_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143209_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143218_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143248_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143253_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143300_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143340_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143402_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143418_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143422_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143442_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143502_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143509_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_143529_0.jpg	&ml
#
# data_cropped/&ml_IMG_20200327_145002_0.jpg	&ml
#
# data_cropped/&n_2019-10-26 122238_2.jpg	&n
#
# data_cropped/&n_2019-10-26 122246_2.jpg	&n
#
# data_cropped/&n_2019-10-26 122250_2.jpg	&n
#
# data_cropped/&n_2019-10-26 122256_2.jpg	&n
#
# data_cropped/&n_IMG_20200327_142326_3.jpg	&n
#
# data_cropped/&q_2019-10-26 120545_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120713_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120749_1.jpg	&q
#
# data_cropped/&q_2019-10-26 120759_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120812_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120821_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120830_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120843_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120911_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120920_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120932_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120941_2.jpg	&q
#
# data_cropped/&q_2019-10-26 120950_2.jpg	&q
#
# data_cropped/&q_2019-10-26 121000_2.jpg	&q
#
# data_cropped/&q_2019-10-26 121010_2.jpg	&q
#
# data_cropped/&q_2019-10-26 121019_2.jpg	&q
#
# data_cropped/&q_2019-10-26 121029_2.jpg	&q
#
# data_cropped/&q_2019-10-26 121037_2.jpg	&q
#
# data_cropped/&q_2019-10-26 121045_2.jpg	&q
#
# data_cropped/&q_2019-10-26 121054_2.jpg	&q
#
# data_cropped/&q_2019-10-26 121101_2.jpg	&q
#
# data_cropped/&q_IMG_2862_2.jpg	&q
#
# data_cropped/&q_IMG_2863_2.jpg	&q
#
# data_cropped/&q_IMG_2864_2.jpg	&q
#
# data_cropped/&r_2019-10-26 114635_2.jpg	&r
#
# data_cropped/&r_2019-10-26 114719_2.jpg	&r
#
# data_cropped/&r_2019-10-26 114737_2.jpg	&r
#
# data_cropped/&r_2019-10-26 114846_2.jpg	&r
#
# data_cropped/&r_2019-10-26 120112_0.jpg	&r
#
# data_cropped/&r_2019-10-26 120121_2.jpg	&r
#
# data_cropped/&r_IMG_20200327_141849_3.jpg	&r
#
# data_cropped/&r_IMG_20200327_142238_3.jpg	&r
#
# data_cropped/&r_IMG_20200327_142243_3.jpg	&r
#
# data_cropped/&r_IMG_20200327_142255_3.jpg	&r
#
# data_cropped/&r_IMG_20200327_142452_3.jpg	&r
#
# data_cropped/&r_IMG_20200327_142503_3.jpg	&r
#
# data_cropped/&r_IMG_20200327_142509_3.jpg	&r
#
# data_cropped/&s_2019-10-26 114733_2.jpg	&s
#
# data_cropped/&s_2019-10-26 114833_2.jpg	&s
#
# data_cropped/&s_2019-10-26 114924_2.jpg	&s
#
# data_cropped/&t_2019-10-26 114157_2.jpg	&t
#
# data_cropped/&v_2019-10-26 111857_2.jpg	&v
#
# data_cropped/&v_20191026_111232_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111755_2.jpg	&v
#
# data_cropped/&v_20191026_111416_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111907_2.jpg	&v
#
# data_cropped/&v_20191026_111637_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111636_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111352_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111722_2.jpg	&v
#
# data_cropped/&v_20191026_111552_2.jpg	&v
#
# data_cropped/&v_20191026_111239_2.jpg	&v
#
# data_cropped/&v_20191026_111750_2.jpg	&v
#
# data_cropped/&v_20191026_111338_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111546_4.jpg	&v
#
# data_cropped/&v_2019-10-26 111429_2.jpg	&v
#
# data_cropped/&v_IMG_20200327_140924_2.jpg	&v
#
# data_cropped/&v_20191026_111513_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111608_2.jpg	&v
#
# data_cropped/&v_20191026_111446_2.jpg	&v
#
# data_cropped/&v_20191026_111257_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111519_2.jpg	&v
#
# data_cropped/&v_20191026_111329_2.jpg	&v
#
# data_cropped/&v_IMG_2469_2.jpg	&v
#
# data_cropped/&v_20191026_111319_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111519_4.jpg	&v
#
# data_cropped/&v_20191026_111714_2.jpg	&v
#
# data_cropped/&v_20191026_111627_2.jpg	&v
#
# data_cropped/&v_20191026_111724_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111457_4.jpg	&v
#
# data_cropped/&v_2019-10-26 111546_2.jpg	&v
#
# data_cropped/&v_20191026_111700_2.jpg	&v
#
# data_cropped/&v_20191026_111347_2.jpg	&v
#
# data_cropped/&v_20191026_111434_2.jpg	&v
#
# data_cropped/&v_20191026_111406_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111339_2.jpg	&v
#
# data_cropped/&v_IMG_20200327_141016_0.jpg	&v
#
# data_cropped/&v_2019-10-26 111247_2.jpg	&v
#
# data_cropped/&v_20191026_111738_2.jpg	&v
#
# data_cropped/&v_20191026_111310_2.jpg	&v
#
# data_cropped/&v_20191026_111531_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111618_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111322_2.jpg	&v
#
# data_cropped/&v_20191026_111648_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111403_2.jpg	&v
#
# data_cropped/&v_IMG_20200327_141011_2.jpg	&v
#
# data_cropped/&v_20191026_111612_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111446_2.jpg	&v
#
# data_cropped/&v_20191026_111504_2.jpg	&v
#
# data_cropped/&v_20191026_111215_2.jpg	&v
#
# data_cropped/&v_IMG_20200327_140929_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111509_2.jpg	&v
#
# data_cropped/&v_IMG_20200327_140955_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111418_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111848_2.jpg	&v
#
# data_cropped/&v_20191026_111248_2.jpg	&v
#
# data_cropped/&v_20191026_111522_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111704_2.jpg	&v
#
# data_cropped/&v_20191026_120025_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111918_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111457_2.jpg	&v
#
# data_cropped/&v_20191026_111601_2.jpg	&v
#
# data_cropped/&yj-jc27151a_IMG_20200327_142819_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144758_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144552_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144933_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144141_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_145040_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144825_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_143632_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_143551_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_142841_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_143609_1.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144937_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144424_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144751_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144455_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_142821_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_143638_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_145009_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144346_1.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_142806_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144638_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144359_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_145026_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144730_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_143616_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144946_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144122_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144558_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144831_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144740_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_143501_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_142800_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144549_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_145059_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144326_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_143624_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_142906_1.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_145049_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144834_0.jpg	&yj-jc27151a
# data_cropped/&yj-jc27151a_IMG_20200327_144322_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144408_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_142808_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_142844_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_143620_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_142812_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144336_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144659_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144715_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144034_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc2_IMG_20200327_143540_0.jpg	&yj-jc2
#
# data_cropped/&yj-jc2_IMG_20200327_143544_0.jpg	&yj-jc2
#
# data_cropped/&yj-jc2_IMG_20200327_144431_0.jpg	&yj-jc2
#
# data_cropped/&yj_IMG_20200327_143656_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_143702_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_143707_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_144355_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_144733_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_144812_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_144837_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145111_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145115_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145125_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145137_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145146_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145149_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145220_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145223_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145231_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145234_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145238_0.jpg	&yj
#
# data_cropped/&yj_IMG_20200327_145245_0.jpg	&yj
#
# data_cropped/&y_IMG_2833_2.jpg	&y
#
# data_cropped/&y_IMG_2834_2.jpg	&y
#
# data_cropped/&y_IMG_2836_2.jpg	&y
#
# data_cropped/&y_IMG_2837_2.jpg	&y
#
# data_cropped/&y_IMG_2838_2.jpg	&y
#
# data_cropped/&y_IMG_2839_2.jpg	&y
#
# data_cropped/&y_IMG_2883_5.jpg	&y
#
# data_cropped/&y_IMG_2884_2.jpg	&y
#
# data_cropped/&y_IMG_2885_2.jpg	&y
#
# data_cropped/&y_IMG_2886_2.jpg	&y
#
# data_cropped/&y_IMG_2888_2.jpg	&y
#
# data_cropped/&y_IMG_2889_2.jpg	&y
#
# data_cropped/&y_IMG_2895_2.jpg	&y
#
# data_cropped/&y_IMG_2897_2.jpg	&y
#
# data_cropped/&y_IMG_2898_2.jpg	&y
#
# data_cropped/&y_IMG_2899_2.jpg	&y
#
# data_cropped/&y_IMG_2900_2.jpg	&y
#
# data_cropped/&y_IMG_2901_2.jpg	&y
#
# data_cropped/&y_IMG_2904_2.jpg	&y
#
# data_cropped/&y_IMG_2906_2.jpg	&y
#
# data_cropped/&y_IMG_2907_2.jpg	&y
#
# data_cropped/&y_IMG_2908_2.jpg	&y
#
# data_cropped/&y_IMG_2910_2.jpg	&y
#
# data_cropped/&y_IMG_2911_2.jpg	&y
#
# data_cropped/&y_IMG_2912_2.jpg	&y
#
# data_cropped/&y_IMG_2914_2.jpg	&y
#
# data_cropped/&y_IMG_2915_2.jpg	&y
#
# data_cropped/&y_IMG_2916_2.jpg	&y
#
# data_cropped/&y_IMG_2919_2.jpg	&y
#
# data_cropped/&y_IMG_2926_2.jpg	&y
#
# data_cropped/&y_IMG_2927_2.jpg	&y
#
# data_cropped/&_IMG_20200327_144141_0.jpg	&
#
# data_cropped/&_IMG_2514_15.jpg	&
#
# data_cropped/&_IMG_20200327_143300_0.jpg	&
#
# data_cropped/&_IMG_20200327_141354_1.jpg	&
#
# data_cropped/&_IMG_20200327_142633_0.jpg	&
#
# data_cropped/&_IMG_20200327_143743_0.jpg	&
#
# data_cropped/&_20191026_114230_14.jpg	&
#
# data_cropped/&_IMG_20200327_141929_1.jpg	&
#
# data_cropped/&_2019-10-26 111457_11.jpg	&
#
# data_cropped/&_20191026_113400_15.jpg	&
#
# data_cropped/&_IMG_20200327_142240_0.jpg	&
#
# data_cropped/&_2019-10-26 114255_15.jpg	&
#
# data_cropped/&_20191026_105545_3.jpg	&
#
# data_cropped/&_IMG_20200327_142756_1.jpg	&
#
# data_cropped/&_IMG_20200327_142159_0.jpg	&
#
# data_cropped/&_IMG_20200327_141249_1.jpg	&
#
# data_cropped/&_IMG_2495_15.jpg	&
#
# data_cropped/&_IMG_20200327_143647_0.jpg	&
#
# data_cropped/&_IMG_2608_13.jpg	&
#
# data_cropped/&_IMG_2637_2.jpg	&
#
# data_cropped/&_IMG_2599_13.jpg	&
#
# data_cropped/&_IMG_20200327_142503_14.jpg	&
#
# data_cropped/&_IMG_20200327_141418_7.jpg	&
#
# data_cropped/&_IMG_20200327_141246_7.jpg	&
#
# data_cropped/&_20191026_120258_15.jpg	&
#
# data_cropped/&_IMG_2661_2.jpg	&
#
# data_cropped/&_IMG_2521_16.jpg	&
#
# data_cropped/&_IMG_20200327_140531_1.jpg	&
#
# data_cropped/&_IMG_20200327_143034_8.jpg	&
#
# data_cropped/&_20191026_111522_11.jpg	&
#
# data_cropped/&_20191026_110239_3.jpg	&
#
# data_cropped/&_IMG_2587_12.jpg	&
#
# data_cropped/&_IMG_2542_4.jpg	&
#
# data_cropped/&_IMG_2647_0.jpg	&
#
# data_cropped/&_IMG_2474_12.jpg	&
#
# data_cropped/&_20191026_122123_15.jpg	&
#
# data_cropped/&_20191026_111239_11.jpg	&
#
# data_cropped/&_2019-10-26 120503_11.jpg	&
#
# data_cropped/&_2019-10-26 121906_14.jpg	&
#
# data_cropped/&_IMG_2627_0.jpg	&
#
# data_cropped/&_20191026_113055_14.jpg	&
#
# data_cropped/&_2019-10-26 121820_14.jpg	&
#
# data_cropped/&_IMG_20200327_142638_0.jpg	&
#
# data_cropped/&_IMG_20200327_141639_1.jpg	&
#
# data_cropped/&_20191026_114414_17.jpg	&
#
# data_cropped/&_IMG_2481_15.jpg	&
#
# data_cropped/&_2019-10-26 104157_10.jpg	&
#
# data_cropped/&_IMG_2554_4.jpg	&
#
# data_cropped/&_IMG_2615_14.jpg	&
#
# data_cropped/&_IMG_2641_0.jpg	&
#
# data_cropped/&_20191026_121546_16.jpg	&
#
# data_cropped/&_IMG_20200327_140218_15.jpg	&
#
# data_cropped/&_IMG_20200327_142426_0.jpg	&
#
# data_cropped/&_2019-10-26 120941_12.jpg	&
#
# data_cropped/&_2019-10-26 111704_11.jpg	&
#
# data_cropped/&_IMG_2697_0.jpg	&
#
# data_cropped/&_IMG_20200327_142325_0.jpg	&
#
# data_cropped/&_IMG_2526_13.jpg	&
#
# data_cropped/&_IMG_20200327_140955_12.jpg	&
#
# data_cropped/&_20191026_120219_15.jpg	&
#
# data_cropped/&_2019-10-26 110643_12.jpg	&
#
# data_cropped/&_2019-10-26 111509_11.jpg	&
#
# data_cropped/&_IMG_2686_0.jpg	&
#
# data_cropped/&_IMG_2685_0.jpg	&
#
# data_cropped/&_2019-10-26 115648_0.jpg	&
#
# data_cropped/&_IMG_2531_13.jpg	&
#
# data_cropped/&_IMG_2701_0.jpg	&
#
# data_cropped/&_20191026_122055_15.jpg	&
#
# data_cropped/&_IMG_2665_0.jpg	&
#
# data_cropped/&_IMG_2673_1.jpg	&
#
# data_cropped/&_2019-10-26 121010_12.jpg	&
#
# data_cropped/&_IMG_20200327_141446_0.jpg	&
#
# data_cropped/&_2019-10-26 114318_10.jpg	&
#
# data_cropped/&_2019-10-26 111429_11.jpg	&
#
# data_cropped/&_IMG_20200327_142238_14.jpg	&
#
# data_cropped/&_IMG_2658_2.jpg	&
#
# data_cropped/&_IMG_2560_15.jpg	&
#
# data_cropped/&_IMG_2666_1.jpg	&
#
# Written 1000 / 26706
# data_cropped/&_IMG_2484_12.jpg	&
#
# data_cropped/&_IMG_20200327_142844_0.jpg	&
#
# data_cropped/&_IMG_20200327_142856_0.jpg	&
#
# data_cropped/&_IMG_2527_13.jpg	&
#
# data_cropped/&_20191026_121704_15.jpg	&
#
# data_cropped/&_IMG_20200327_140312_1.jpg	&
#
# data_cropped/&_IMG_2541_3.jpg	&
#
# data_cropped/&_2019-10-26 104223_10.jpg	&
#
# data_cropped/&_2019-10-26 104148_10.jpg	&
#
# data_cropped/&_IMG_2475_15.jpg	&
#
# data_cropped/&_IMG_2663_1.jpg	&
#
# data_cropped/&_IMG_20200327_141729_1.jpg	&
#
# data_cropped/&_20191026_120821_15.jpg	&
#
# data_cropped/&_IMG_20200327_143501_0.jpg	&
#
# data_cropped/&_IMG_20200327_141348_0.jpg	&
#
# data_cropped/&_IMG_20200327_142114_1.jpg	&
#
# data_cropped/&_IMG_20200327_144122_0.jpg	&
#
# data_cropped/&_20191026_111612_11.jpg	&
#
# data_cropped/&_20191026_105923_3.jpg	&
#
# data_cropped/&_IMG_20200327_141023_12.jpg	&
#
# data_cropped/&_IMG_20200327_143001_0.jpg	&
#
# data_cropped/&_IMG_20200327_142653_0.jpg	&
#
# data_cropped/&_IMG_2666_4.jpg	&
#
# data_cropped/&_IMG_20200327_140508_1.jpg	&
#
# ...
#
# data_cropped/z_IMG_20200327_140458_10.jpg	z
#
# data_cropped/z_20191026_114230_6.jpg	z
#
# data_cropped/z_IMG_20200327_143442_8.jpg	z
#
# data_cropped/z_IMG_2842_3.jpg	z
#
# data_cropped/z_IMG_2759_6.jpg	z
#
# data_cropped/z_IMG_2662_8.jpg	z
#
# data_cropped/z_IMG_2816_6.jpg	z
#
# data_cropped/z_IMG_20200327_142705_8.jpg	z
#
# data_cropped/z_IMG_2896_5.jpg	z
#
# data_cropped/z_IMG_2519_1.jpg	z
#
# data_cropped/z_IMG_2548_0.jpg	z
#
# data_cropped/z_IMG_2754_6.jpg	z
#
# data_cropped/z_20191026_114000_8.jpg	z
#
# data_cropped/z_20191026_105657_14.jpg	z
#
# data_cropped/z_IMG_2495_6.jpg	z
#
# data_cropped/z_IMG_20200327_142734_8.jpg	z
#
# data_cropped/z_IMG_2480_6.jpg	z
#
# data_cropped/z_IMG_2505_5.jpg	z
#
# data_cropped/z_IMG_2764_6.jpg	z
#
# data_cropped/z_IMG_2596_0.jpg	z
#
# data_cropped/z_20191026_111700_5.jpg	z
#
# data_cropped/z_2019-10-26 104058_3.jpg	z
#
# data_cropped/z_IMG_2523_5.jpg	z
#
# data_cropped/z_IMG_2629_7.jpg	z
# data_cropped/z_20191026_122037_8.jpg	z
#
# data_cropped/z_20191026_110041_15.jpg	z
#
# data_cropped/z_IMG_20200327_143430_9.jpg	z
#
# data_cropped/z_IMG_2618_7.jpg	z
#
# data_cropped/z_IMG_20200327_140411_10.jpg	z
#
# data_cropped/z_IMG_2581_0.jpg	z
#
# data_cropped/z_IMG_2818_6.jpg	z
#
# data_cropped/z_IMG_2681_7.jpg	z
#
# data_cropped/z_IMG_2564_0.jpg	z
#
# data_cropped/z_IMG_2849_6.jpg	z
#
# data_cropped/z_20191026_122048_7.jpg	z
#
# data_cropped/z_IMG_2784_6.jpg	z
#
# data_cropped/z_IMG_2530_0.jpg	z
#
# data_cropped/z_IMG_2658_7.jpg	z
#
# data_cropped/z_IMG_2906_5.jpg	z
#
# data_cropped/z_IMG_2856_6.jpg	z
#
# data_cropped/z_20191026_110131_15.jpg	z
#
# data_cropped/z_IMG_20200327_140523_10.jpg	z
#
# data_cropped/z_IMG_2528_9.jpg	z
#
# data_cropped/z_2019-10-26 114114_5.jpg	z
#
# data_cropped/z_IMG_2872_5.jpg	z
#
# data_cropped/z_IMG_2914_5.jpg	z
#
# data_cropped/z_IMG_2661_7.jpg	z
#
# data_cropped/z_IMG_2704_7.jpg	z
#
# data_cropped/z_IMG_2498_6.jpg	z
#
# data_cropped/z_IMG_2833_3.jpg	z
#
# data_cropped/z_2019-10-26 104223_3.jpg	z
#
# data_cropped/z_IMG_20200327_140139_10.jpg	z
#
# data_cropped/z_IMG_2890_5.jpg	z
#
# data_cropped/z_20191026_113739_8.jpg	z
#
# data_cropped/z_2019-10-26 115359_7.jpg	z
#
# data_cropped/z_IMG_2787_6.jpg	z
#
# data_cropped/z_20191026_111540_5.jpg	z
#
# data_cropped/z_IMG_2660_9.jpg	z
#
# data_cropped/z_IMG_2560_1.jpg	z
#
# data_cropped/z_20191026_122218_7.jpg	z
#
# data_cropped/z_20191026_113552_8.jpg	z
#
# data_cropped/z_IMG_2628_9.jpg	z
#
# data_cropped/z_IMG_20200327_141620_8.jpg	z
#
# data_cropped/z_IMG_2473_6.jpg	z
#
# data_cropped/z_20191026_111257_5.jpg	z
#
# data_cropped/z_IMG_2512_6.jpg	z
#
# data_cropped/z_IMG_2541_0.jpg	z
#
# data_cropped/z_IMG_2875_5.jpg	z
#
# data_cropped/z_IMG_2799_6.jpg	z
#
# data_cropped/z_IMG_2729_7.jpg	z
#
# data_cropped/z_IMG_2688_7.jpg	z
#
# data_cropped/z_IMG_2507_5.jpg	z
#
# data_cropped/z_20191026_121814_8.jpg	z
#
# data_cropped/z_20191026_121647_8.jpg	z
#
# data_cropped/z_IMG_2578_0.jpg	z
#
# data_cropped/z_IMG_20200327_144130_6.jpg	z
#
# data_cropped/z_IMG_20200327_143425_8.jpg	z
#
# data_cropped/z_20191026_103707_14.jpg	z
#
# data_cropped/z_IMG_2587_14.jpg	z
#
# data_cropped/z_IMG_2484_6.jpg	z
#
# data_cropped/z_IMG_20200327_143455_9.jpg	z
#
# data_cropped/z_IMG_20200327_143927_4.jpg	z
#
# data_cropped/z_IMG_2770_6.jpg	z
#
# data_cropped/z_IMG_2823_6.jpg	z
#
# data_cropped/z_2019-10-26 104058_20.jpg	z
#
# data_cropped/z_2019-10-26 122024_6.jpg	z
#
# data_cropped/z_20191026_105634_15.jpg	z
#
# data_cropped/z_IMG_20200327_140407_10.jpg	z
#
# data_cropped/z_20191026_105810_15.jpg	z
#
# data_cropped/z_20191026_113139_8.jpg	z
#
# data_cropped/z_20191026_112815_3.jpg	z
#
# data_cropped/z_IMG_2731_7.jpg	z
#
# data_cropped/z_20191026_114241_6.jpg	z
#
# data_cropped/z_20191026_103739_10.jpg	z
#
# data_cropped/z_IMG_2585_14.jpg	z
#
# data_cropped/z_2019-10-26 122038_6.jpg	z
#
# data_cropped/z_IMG_2837_3.jpg	z
#
# data_cropped/z_IMG_20200327_141046_7.jpg	z
#
# data_cropped/z_IMG_2509_5.jpg	z
#
# data_cropped/z_IMG_2602_0.jpg	z
#
# data_cropped/z_IMG_2610_0.jpg	z
#
# data_cropped/z_IMG_2746_9.jpg	z
#
# data_cropped/z_IMG_2796_14.jpg	z
#
# data_cropped/z_IMG_2579_0.jpg	z
#
# data_cropped/z_2019-10-26 121757_6.jpg	z
#
# data_cropped/z_IMG_20200327_143437_5.jpg	z
#
# data_cropped/z_IMG_20200327_141446_6.jpg	z
#
# data_cropped/z_IMG_2756_6.jpg	z
#
# data_cropped/z_IMG_2549_0.jpg	z
#
# data_cropped/z_IMG_2663_9.jpg	z
#
# data_cropped/z_IMG_2811_6.jpg	z
#
# data_cropped/z_IMG_20200327_143300_8.jpg	z
#
# data_cropped/z_IMG_20200327_141635_0.jpg	z
#
# data_cropped/z_IMG_20200327_141615_0.jpg	z
#
# data_cropped/z_IMG_2498_5.jpg	z
#
# data_cropped/z_IMG_20200327_142701_8.jpg	z
#
# data_cropped/z_2019-10-26 114318_3.jpg	z
#
# data_cropped/z_IMG_2657_9.jpg	z
#
# data_cropped/z_20191026_113221_8.jpg	z
#
# data_cropped/z_2019-10-26 114142_5.jpg	z
#
# data_cropped/z_IMG_2480_5.jpg	z
#
# data_cropped/z_IMG_2532_5.jpg	z
#
# data_cropped/z_IMG_20200327_143939_3.jpg	z
#
# data_cropped/z_IMG_2584_0.jpg	z
#
# data_cropped/z_2019-10-26 115310_7.jpg	z
#
# data_cropped/z_IMG_2745_6.jpg	z
#
# data_cropped/z_IMG_2545_0.jpg	z
#
# data_cropped/z_20191026_113643_8.jpg	z
#
# data_cropped/z_IMG_2827_6.jpg	z
#
# data_cropped/z_20191026_113808_8.jpg	z
#
# data_cropped/z_20191026_113953_8.jpg	z
#
# data_cropped/z_IMG_2659_9.jpg	z
#
# data_cropped/z_IMG_2565_1.jpg	z
#
# data_cropped/z_IMG_2803_6.jpg	z
#
# data_cropped/z_IMG_2582_0.jpg	z
#
# data_cropped/z_IMG_2795_6.jpg	z
#
# data_cropped/z_2019-10-26 103955_3.jpg	z
#
# data_cropped/z_IMG_2595_0.jpg	z
#
# data_cropped/z_IMG_20200327_140644_7.jpg	z
#
# data_cropped/z_IMG_2685_7.jpg	z
#
# data_cropped/z_IMG_20200327_140413_0.jpg	z
#
# data_cropped/z_IMG_20200327_142930_8.jpg	z
#
# data_cropped/z_IMG_2725_7.jpg	z
#
# data_cropped/z_20191026_121656_14.jpg	z
#
# data_cropped/z_20191026_113349_8.jpg	z
#
# data_cropped/z_20191026_105832_15.jpg	z
#
# data_cropped/z_IMG_2740_7.jpg	z
#
# data_cropped/z_IMG_20200327_142647_8.jpg	z
#
# data_cropped/z_IMG_2730_7.jpg	z
#
# data_cropped/z_IMG_2531_0.jpg	z
#
# data_cropped/z_20191026_110239_15.jpg	z
#
# data_cropped/z_IMG_2824_6.jpg	z
#
# data_cropped/z_IMG_20200327_142742_8.jpg	z
#
# data_cropped/z_IMG_20200327_142725_8.jpg	z
#
# data_cropped/z_20191026_111648_5.jpg	z
#
# data_cropped/z_2019-10-26 122352_6.jpg	z
#
# data_cropped/z_IMG_20200327_142623_8.jpg	z
#
# data_cropped/z_20191026_121807_8.jpg	z
#
# data_cropped/z_20191026_121927_8.jpg	z
#
# data_cropped/z_IMG_2601_0.jpg	z
#
# data_cropped/z_IMG_20200327_144250_2.jpg	z
#
# data_cropped/z_IMG_2508_6.jpg	z
#
# data_cropped/z_IMG_2488_6.jpg	z
#
# data_cropped/z_IMG_2514_6.jpg	z
#
# data_cropped/z_IMG_2492_5.jpg	z
#
# data_cropped/z_IMG_20200327_141610_8.jpg	z
#
# data_cropped/z_IMG_2636_9.jpg	z
#
# data_cropped/z_IMG_2547_0.jpg	z
#
# data_cropped/z_IMG_2774_6.jpg	z
#
# data_cropped/z_20191026_105726_15.jpg	z
#
# data_cropped/z_2019-10-26 115340_7.jpg	z
#
# data_cropped/z_IMG_2537_0.jpg	z
#
# data_cropped/z_2019-10-26 114607_3.jpg	z
#
# data_cropped/z_IMG_2617_6.jpg	z
#
# data_cropped/z_IMG_2704_8.jpg	z
#
# data_cropped/z_IMG_2925_5.jpg	z
#
# data_cropped/z_IMG_2575_0.jpg	z
#
# data_cropped/z_IMG_20200327_143209_12.jpg	z
#
# data_cropped/z_IMG_20200327_143030_6.jpg	z
#
# data_cropped/z_IMG_2484_5.jpg	z
#
# data_cropped/z_IMG_20200327_143515_8.jpg	z
#
# data_cropped/z_IMG_20200327_141555_8.jpg	z
#
# data_cropped/z_IMG_2792_6.jpg	z
#
# data_cropped/z_IMG_2499_5.jpg	z
#
# data_cropped/z_20191026_110017_15.jpg	z
#
# data_cropped/z_IMG_2894_5.jpg	z
#
# data_cropped/z_2019-10-26 103719_0.jpg	z
#
# data_cropped/z_IMG_2706_7.jpg	z
#
# data_cropped/z_2019-10-26 103949_3.jpg	z
#
# data_cropped/z_IMG_2659_7.jpg	z
#
# data_cropped/z_20191026_111513_5.jpg	z
#
# data_cropped/z_IMG_2499_6.jpg	z
#
# data_cropped/z_IMG_2494_5.jpg	z
#
# data_cropped/z_2019-10-26 122105_6.jpg	z
#
# data_cropped/z_20191026_122303_5.jpg	z
#
# data_cropped/z_20191026_103512_13.jpg	z
#
# data_cropped/z_IMG_2665_8.jpg	z
#
# data_cropped/z_2019-10-26 103605_0.jpg	z
#
# data_cropped/z_2019-10-26 114550_3.jpg	z
#
# data_cropped/z_20191026_111627_5.jpg	z
#
# data_cropped/z_IMG_2546_5.jpg	z
#
# data_cropped/z_IMG_2883_5.jpg	z
#
# data_cropped/z_IMG_2668_13.jpg	z
#
# data_cropped/z_20191026_113425_8.jpg	z
#
# data_cropped/z_IMG_2647_7.jpg	z
#
# data_cropped/z_IMG_20200327_142936_8.jpg	z
#
# data_cropped/z_20191026_103122_8.jpg	z
#
# data_cropped/z_IMG_20200327_140346_10.jpg	z
#
# data_cropped/z_IMG_2664_8.jpg	z
#
# data_cropped/z_IMG_2556_5.jpg	z
#
# data_cropped/z_IMG_20200327_140336_10.jpg	z
#
# data_cropped/z_20191026_110338_5.jpg	z
#
# data_cropped/z_IMG_2657_7.jpg	z
#
# data_cropped/z_IMG_2902_5.jpg	z
#
# data_cropped/z_IMG_2670_7.jpg	z
#
# data_cropped/z_IMG_2883_13.jpg	z
#
# data_cropped/z_IMG_2560_0.jpg	z
#
# data_cropped/z_IMG_2575_3.jpg	z
#
# data_cropped/z_20191026_113331_8.jpg	z
#
# data_cropped/z_IMG_2567_1.jpg	z
#
# data_cropped/z_IMG_20200327_143523_9.jpg	z
#
# data_cropped/z_IMG_2820_6.jpg	z
#
# data_cropped/z_IMG_2530_5.jpg	z
#
# data_cropped/z_IMG_20200327_143323_9.jpg	z
#
# data_cropped/z_IMG_2680_7.jpg	z
#
# data_cropped/z_20191026_122021_7.jpg	z
#
# data_cropped/z_IMG_20200327_141511_4.jpg	z
#
# data_cropped/z_IMG_20200327_143149_6.jpg	z
#
# data_cropped/z_2019-10-26 115338_7.jpg	z
#
# data_cropped/z_IMG_2836_3.jpg	z
#
# data_cropped/z_IMG_2591_3.jpg	z
#
# data_cropped/z_IMG_20200327_141639_0.jpg	z
#
# data_cropped/z_IMG_2663_8.jpg	z
#
# data_cropped/z_IMG_2703_9.jpg	z
#
# data_cropped/z_IMG_2497_5.jpg	z
#
# data_cropped/z_IMG_2469_6.jpg	z
#
# data_cropped/z_IMG_2715_6.jpg	z
#
# data_cropped/z_IMG_20200327_142601_8.jpg	z
#
# data_cropped/z_20191026_113111_5.jpg	z
#
# data_cropped/z_20191026_111531_5.jpg	z
#
# data_cropped/z_IMG_2493_6.jpg	z
#
# data_cropped/z_IMG_2588_0.jpg	z
#
# data_cropped/z_20191026_105642_15.jpg	z
#
# data_cropped/z_IMG_2521_1.jpg	z
# data_cropped/z_20191026_111310_5.jpg	z
#
# data_cropped/z_IMG_2703_7.jpg	z
#
# data_cropped/z_2019-10-26 121947_6.jpg	z
#
# data_cropped/z_IMG_2563_1.jpg	z
#
# data_cropped/z_IMG_2472_4.jpg	z
#
# data_cropped/z_IMG_2501_5.jpg	z
#
# data_cropped/z_IMG_2570_0.jpg	z
#
# data_cropped/z_IMG_20200327_140453_10.jpg	z
#
# data_cropped/z_20191026_110203_15.jpg	z
#
# data_cropped/z_IMG_20200327_143514_6.jpg	z
#
# data_cropped/z_IMG_2528_0.jpg	z
#
# data_cropped/z_IMG_2712_8.jpg	z
#
# data_cropped/z_IMG_20200327_141914_5.jpg	z
#
# data_cropped/z_IMG_2481_5.jpg	z
#
# data_cropped/z_2019-10-26 110911_5.jpg	z
#
# data_cropped/z_20191026_113716_8.jpg	z
#
# data_cropped/z_IMG_2670_13.jpg	z
#
# data_cropped/z_2019-10-26 122156_3.jpg	z
#
# data_cropped/z_IMG_2535_9.jpg	z
#
# data_cropped/z_IMG_2687_7.jpg	z
#
# data_cropped/z_IMG_2750_6.jpg	z
#
# data_cropped/z_IMG_20200327_140531_10.jpg	z
#
# data_cropped/z_IMG_2496_6.jpg	z
#
# data_cropped/z_IMG_2502_6.jpg	z
#
# data_cropped/z_20191026_121704_8.jpg	z
#
# data_cropped/z_IMG_2693_7.jpg	z
#
# data_cropped/z_2019-10-26 110630_5.jpg	z
#
# data_cropped/z_IMG_2650_9.jpg	z
#
# data_cropped/z_IMG_2678_7.jpg	z
#
# data_cropped/z_IMG_20200327_140908_5.jpg	z
#
# data_cropped/z_IMG_20200327_140119_10.jpg	z
#
# data_cropped/z_20191026_111522_5.jpg	z
#
# data_cropped/z_IMG_2555_0.jpg	z
#
# data_cropped/z_IMG_20200327_142612_5.jpg	z
#
# data_cropped/z_IMG_2572_0.jpg	z
#
# data_cropped/z_IMG_2848_6.jpg	z
#
# data_cropped/z_20191026_111357_5.jpg	z
#
# data_cropped/z_20191026_113920_8.jpg	z
#
# data_cropped/z_2019-10-26 114506_3.jpg	z
#
# data_cropped/z_IMG_2500_5.jpg	z
#
# data_cropped/z_20191026_122151_8.jpg	z
#
# data_cropped/z_IMG_2538_5.jpg	z
#
# data_cropped/z_20191026_110309_5.jpg	z
#
# data_cropped/z_IMG_2647_9.jpg	z
#
# data_cropped/z_20191026_111215_5.jpg	z
#
# data_cropped/z_20191026_105745_15.jpg	z
#
# data_cropped/z_IMG_2730_6.jpg	z
#
# data_cropped/z_IMG_2493_5.jpg	z
#
# data_cropped/z_IMG_2553_5.jpg	z
#
# data_cropped/z_20191026_105545_15.jpg	z
#
# data_cropped/z_IMG_2828_6.jpg	z
#
# data_cropped/z_2019-10-26 103940_3.jpg	z
#
# data_cropped/z_IMG_2589_3.jpg	z
#
# data_cropped/z_IMG_2472_3.jpg	z
#
# data_cropped/z_IMG_2785_6.jpg	z
#
# data_cropped/z_IMG_2661_9.jpg	z
#
# data_cropped/z_20191026_121536_6.jpg	z
#
# data_cropped/z_IMG_2471_4.jpg	z
#
# data_cropped/z_IMG_2564_1.jpg	z
#
# data_cropped/z_20191026_113650_8.jpg	z
#
# data_cropped/z_IMG_2771_6.jpg	z
#
# data_cropped/z_IMG_2658_9.jpg	z
#
# data_cropped/z_IMG_20200327_144204_3.jpg	z
#
# data_cropped/z_2019-10-26 115404_7.jpg	z
#
# data_cropped/z_20191026_112802_2.jpg	z
#
# data_cropped/z_IMG_2783_6.jpg	z
#
# data_cropped/z_IMG_2719_6.jpg	z
#
# data_cropped/z_IMG_2489_6.jpg	z
#
# data_cropped/z_IMG_2651_9.jpg	z
#
# data_cropped/z_IMG_2907_5.jpg	z
#
# data_cropped/z_IMG_2586_0.jpg	z
#
# data_cropped/z_20191026_110229_15.jpg	z
#
# data_cropped/z_IMG_2507_6.jpg	z
#
# data_cropped/z_20191026_122003_8.jpg	z
#
# data_cropped/z_IMG_2892_5.jpg	z
#
# data_cropped/z_20191026_114203_6.jpg	z
#
# data_cropped/z_IMG_2539_5.jpg	z
#
# data_cropped/z_IMG_2778_6.jpg	z
#
# data_cropped/z_IMG_2615_6.jpg	z
#
# data_cropped/z_2019-10-26 104148_15.jpg	z
#
# data_cropped/z_IMG_2832_6.jpg	z
#
# data_cropped/z_IMG_2779_6.jpg	z
#
# data_cropped/z_IMG_2557_0.jpg	z
#
# data_cropped/z_IMG_2523_0.jpg	z
#
# data_cropped/z_IMG_2917_5.jpg	z
#
# data_cropped/z_IMG_2551_0.jpg	z
#
# data_cropped/z_IMG_2529_5.jpg	z
#
# data_cropped/z_IMG_2911_5.jpg	z
#
# data_cropped/z_20191026_113933_8.jpg	z
#
# data_cropped/z_IMG_2527_9.jpg	z
#
# data_cropped/z_20191026_111222_5.jpg	z
#
# data_cropped/z_IMG_2713_6.jpg	z
#
# data_cropped/z_IMG_2897_5.jpg	z
#
# data_cropped/z_20191026_111612_5.jpg	z
#
# data_cropped/z_IMG_2791_6.jpg	z
#
# data_cropped/z_IMG_2801_6.jpg	z
#
# data_cropped/z_IMG_2711_7.jpg	z
#
# data_cropped/z_IMG_2524_5.jpg	z
#
# data_cropped/z_20191026_105717_15.jpg	z
#
# data_cropped/z_20191026_113237_8.jpg	z
#
# data_cropped/z_2019-10-26 122211_3.jpg	z
#
# data_cropped/z_IMG_2540_5.jpg	z
#
# data_cropped/z_IMG_20200327_141057_7.jpg	z
#
# data_cropped/z_IMG_2481_6.jpg	z
#
# data_cropped/z_IMG_2869_5.jpg	z
#
# data_cropped/z_20191026_111347_5.jpg	z
#
# data_cropped/z_2019-10-26 121838_6.jpg	z
#
# data_cropped/z_IMG_2655_9.jpg	z
#
# data_cropped/z_IMG_20200327_142945_8.jpg	z
#
# data_cropped/z_IMG_2625_7.jpg	z
#
# data_cropped/z_IMG_20200327_144106_6.jpg	z
#
# data_cropped/z_20191026_110143_15.jpg	z
#
# data_cropped/z_2019-10-26 121719_6.jpg	z
#
# data_cropped/z_IMG_20200327_143843_9.jpg	z
#
# data_cropped/z_IMG_20200327_143131_9.jpg	z
#
# data_cropped/z_IMG_2831_6.jpg	z
#
# data_cropped/z_IMG_2626_7.jpg	z
#
# data_cropped/z_IMG_2928_5.jpg	z
#
# data_cropped/z_20191026_114248_6.jpg	z
#
# data_cropped/z_20191026_122237_8.jpg	z
#
# data_cropped/z_IMG_2509_6.jpg	z
#
# data_cropped/z_IMG_2574_3.jpg	z
#
# data_cropped/z_20191026_113200_8.jpg	z
#
# data_cropped/z_IMG_2705_7.jpg	z
#
# data_cropped/z_IMG_2646_9.jpg	z
#
# data_cropped/z_20191026_111601_5.jpg	z
#
# data_cropped/z_IMG_2643_7.jpg	z
#
# data_cropped/z_20191026_105903_15.jpg	z
#
# data_cropped/z_IMG_20200327_143943_4.jpg	z
#
# data_cropped/z_IMG_2819_6.jpg	z
#
# data_cropped/z_20191026_110350_5.jpg	z
#
# data_cropped/z_IMG_2476_5.jpg	z
#
# data_cropped/z_IMG_2513_6.jpg	z
#
# data_cropped/z_20191026_103526_12.jpg	z
#
# data_cropped/z_IMG_2485_5.jpg	z
#
# data_cropped/z_20191026_111434_5.jpg	z
#
# data_cropped/z_20191026_105913_15.jpg	z
#
# data_cropped/z_2019-10-26 121659_6.jpg	z
#
# data_cropped/z_IMG_2489_5.jpg	z
#
# data_cropped/z_IMG_2563_0.jpg	z
#
# data_cropped/z_IMG_2482_5.jpg	z
#
# data_cropped/z_IMG_2691_7.jpg	z
#
# data_cropped/z_2019-10-26 103539_0.jpg	z
#
# data_cropped/z_20191026_122104_7.jpg	z
#
# data_cropped/z_IMG_2558_1.jpg	z
#
# data_cropped/z_20191026_105843_15.jpg	z
#
# data_cropped/z_20191026_114056_6.jpg	z
#
# data_cropped/z_IMG_2880_5.jpg	z
#
# data_cropped/z_IMG_2780_6.jpg	z
#
# data_cropped/z_IMG_2707_7.jpg	z
#
# data_cropped/z_IMG_2679_7.jpg	z
#
# data_cropped/z_IMG_2698_7.jpg	z
#
# data_cropped/z_IMG_20200327_144103_5.jpg	z
#
# data_cropped/z_20191026_113912_6.jpg	z
#
# data_cropped/z_IMG_2716_6.jpg	z
#
# data_cropped/z_2019-10-26 121830_6.jpg	z
#
# data_cropped/z_IMG_2534_0.jpg	z
#
# data_cropped/z_IMG_20200327_140049_10.jpg	z
#
# data_cropped/z_20191026_110007_15.jpg	z
#
# data_cropped/z_IMG_2583_1.jpg	z
#
# data_cropped/z_IMG_2543_1.jpg	z
#
# data_cropped/z_IMG_2555_5.jpg	z
#
# data_cropped/z_20191026_114833_3.jpg	z
#
# data_cropped/z_2019-10-26 121751_6.jpg	z
#
# data_cropped/z_IMG_2788_6.jpg	z
#
# data_cropped/z_IMG_20200327_140515_10.jpg	z
#
# data_cropped/z_20191026_113607_8.jpg	z
#
# data_cropped/z_IMG_2876_5.jpg	z
#
# data_cropped/z_IMG_2775_6.jpg	z
#
# data_cropped/z_2019-10-26 114827_5.jpg	z
#
# data_cropped/z_IMG_2533_5.jpg	z
#
# data_cropped/z_IMG_2886_5.jpg	z
#
# data_cropped/z_IMG_20200327_143008_9.jpg	z
#
# data_cropped/z_IMG_2471_3.jpg	z
#
# data_cropped/z_20191026_111248_5.jpg	z
#
# data_cropped/z_IMG_2777_6.jpg	z
#
# data_cropped/z_2019-10-26 122114_6.jpg	z
#
# data_cropped/z_20191026_113302_5.jpg	z
#
# data_cropped/z_2019-10-26 114122_6.jpg	z
#
# data_cropped/z_2019-10-26 110931_5.jpg	z
#
# data_cropped/z_2019-10-26 104157_3.jpg	z
#
# data_cropped/z_20191026_103517_13.jpg	z
#
# data_cropped/z_IMG_2711_10.jpg	z
#
# data_cropped/z_IMG_2664_11.jpg	z
#
# data_cropped/z_IMG_2578_3.jpg	z
#
# data_cropped/z_IMG_20200327_142629_8.jpg	z
#
# Created dataset with 26706 samples

# %% [markdown]
# 生成测试集的lmdb文件。将map_size设置为训练集的0.1倍即可。

# %%
gtFile_val = 'gt_val.txt'
outputPath_valset = 'Lmdb_valset/'
if not os.path.exists(outputPath_valset):
    os.mkdir(outputPath_valset)
    
map_size = 0.1 * map_size#空间大约是训练集的0.1倍
createDataset(inputPath, gtFile_val, outputPath_valset, checkValid=True, map_size=map_size)
# Out:
# data_cropped/%_IMG_20200327_143948_0.jpg	%
#
# data_cropped/%_IMG_20200327_144638_16.jpg	%
#
# data_cropped/%_IMG_20200327_140725_2.jpg	%
#
# data_cropped/%_IMG_20200327_144638_17.jpg	%
#
# data_cropped/%_IMG_20200327_144010_1.jpg	%
#
# data_cropped/&2e3a-sz_IMG_2639_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2641_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2691_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2674_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2634_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2702_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2706_0.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_IMG_2664_1.jpg	&2e3a-sz
#
# data_cropped/&2e3a-sz_2019-10-26 115310_0.jpg	&2e3a-sz
#
# data_cropped/&b_IMG_2576_2.jpg	&b
#
# data_cropped/&b_IMG_2542_2.jpg	&b
#
# data_cropped/&b_2019-10-26 110851_2.jpg	&b
#
# data_cropped/&b_IMG_2547_2.jpg	&b
#
# data_cropped/&b_IMG_2600_2.jpg	&b
#
# data_cropped/&b_IMG_2601_2.jpg	&b
#
# data_cropped/&b_IMG_2527_2.jpg	&b
#
# data_cropped/&b_2019-10-26 103744_2.jpg	&b
#
# data_cropped/&b_IMG_2560_2.jpg	&b
#
# data_cropped/&b_IMG_2605_2.jpg	&b
#
# data_cropped/&b_2019-10-26 111020_2.jpg	&b
#
# data_cropped/&b_IMG_20200327_140453_1.jpg	&b
#
# data_cropped/&b_IMG_2589_2.jpg	&b
#
# data_cropped/&b_IMG_2507_2.jpg	&b
#
# data_cropped/&v_20191026_111540_2.jpg	&v
#
# data_cropped/&v_2019-10-26 111727_2.jpg	&v
#
# data_cropped/&v_20191026_111222_2.jpg	&v
#
# data_cropped/&v_20191026_111357_2.jpg	&v
#
# data_cropped/&v_20191026_111453_2.jpg	&v
#
# data_cropped/&v_20191026_120040_3.jpg	&v
#
# data_cropped/&yj-jc27151a_IMG_20200327_145018_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144828_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_143601_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_143721_0.jpg	&yj-jc27151a
#
# data_cropped/&yj-jc27151a_IMG_20200327_144151_0.jpg	&yj-jc27151a
#
# data_cropped/&_20191026_113302_14.jpg	&
#
# data_cropped/&_IMG_2530_13.jpg	&
#
# data_cropped/&_IMG_2700_1.jpg	&
#
# data_cropped/&_IMG_20200327_141849_14.jpg	&
#
# data_cropped/&_IMG_20200327_143422_0.jpg	&
#
# data_cropped/&_20191026_115035_2.jpg	&
#
# data_cropped/&_2019-10-26 110744_12.jpg	&
#
# data_cropped/&_2019-10-26 115014_0.jpg	&
#
# data_cropped/&_2019-10-26 122352_14.jpg	&
#
# data_cropped/&_IMG_20200327_142149_1.jpg	&
#
# data_cropped/&_IMG_20200327_142644_0.jpg	&
#
# data_cropped/&_IMG_2479_12.jpg	&
#
# data_cropped/&_IMG_20200327_144834_0.jpg	&
#
# data_cropped/&_IMG_20200327_141334_0.jpg	&
#
# data_cropped/&_IMG_2504_15.jpg	&
#
# data_cropped/&_IMG_2503_12.jpg	&
#
# data_cropped/&_20191026_121732_15.jpg	&
#
# data_cropped/&_20191026_110007_3.jpg	&
#
# data_cropped/&_IMG_2525_13.jpg	&
#
# data_cropped/&_IMG_2539_13.jpg	&
#
# data_cropped/&_20191026_103734_3.jpg	&
#
# data_cropped/&_20191026_105852_3.jpg	&
#
# data_cropped/&_IMG_20200327_142636_0.jpg	&
#
# data_cropped/&_20191026_110131_3.jpg	&
#
# data_cropped/&_IMG_2627_2.jpg	&
#
# data_cropped/&_20191026_120143_15.jpg	&
#
# data_cropped/&_IMG_20200327_141129_1.jpg	&
#
# data_cropped/&_IMG_2502_15.jpg	&
#
# data_cropped/&_20191026_121901_15.jpg	&
#
# data_cropped/&_IMG_2537_13.jpg	&
#
# data_cropped/&_IMG_20200327_140945_1.jpg	&
#
# data_cropped/&_20191026_113708_15.jpg	&
#
# data_cropped/&_2019-10-26 111546_11.jpg	&
#
# data_cropped/&_IMG_2634_0.jpg	&
#
# data_cropped/&_IMG_20200327_141705_1.jpg	&
#
# data_cropped/&_20191026_113246_17.jpg	&
#
# data_cropped/&_IMG_2653_2.jpg	&
#
# data_cropped/&_IMG_2700_0.jpg	&
#
# data_cropped/&_2019-10-26 110931_11.jpg	&
#
# data_cropped/&_IMG_20200327_141157_0.jpg	&
#
# data_cropped/&_IMG_20200327_140748_1.jpg	&
#
# data_cropped/&_2019-10-26 114611_10.jpg	&
#
# data_cropped/&_IMG_2544_2.jpg	&
#
# data_cropped/&_IMG_2601_13.jpg	&
#
# data_cropped/&_IMG_2671_0.jpg	&
#
# data_cropped/&_IMG_20200327_142403_0.jpg	&
#
# data_cropped/&_IMG_2468_11.jpg	&
#
# data_cropped/&_IMG_20200327_140638_0.jpg	&
#
# data_cropped/&_2019-10-26 103539_13.jpg	&
#
# data_cropped/&_20191026_111338_11.jpg	&
#
# data_cropped/&_IMG_2553_3.jpg	&
#
# data_cropped/&_2019-10-26 111618_11.jpg	&
#
# data_cropped/&_20191026_111714_11.jpg	&
#
# data_cropped/&_IMG_2489_12.jpg	&
#
# data_cropped/&_IMG_20200327_140631_0.jpg	&
#
# data_cropped/&_IMG_20200327_141115_9.jpg	&
#
# data_cropped/&_2019-10-26 120135_14.jpg	&
#
# data_cropped/&_IMG_20200327_141552_1.jpg	&
#
# data_cropped/&_IMG_20200327_140730_1.jpg	&
#
# data_cropped/&_20191026_105650_3.jpg	&
#
# data_cropped/&_20191026_120311_15.jpg	&
#
# data_cropped/&_IMG_2881_12.jpg	&
#
# data_cropped/&_20191026_113134_17.jpg	&
#
# data_cropped/&_2019-10-26 114543_11.jpg	&
#
# data_cropped/&_IMG_20200327_142204_0.jpg	&
#
# data_cropped/&_2019-10-26 122329_13.jpg	&
#
# data_cropped/&_IMG_2835_2.jpg	&
#
# data_cropped/&_20191026_110053_3.jpg	&
#
# data_cropped/&_IMG_2579_13.jpg	&
#
# data_cropped/&_2019-10-26 122307_13.jpg	&
#
# data_cropped/&_IMG_2588_15.jpg	&
#
# data_cropped/&_IMG_2619_0.jpg	&
#
# data_cropped/&_IMG_20200327_142615_0.jpg	&
#
# data_cropped/&_IMG_20200327_143340_0.jpg	&
#
# data_cropped/&_IMG_20200327_142808_0.jpg	&
#
# data_cropped/&_IMG_20200327_143707_0.jpg	&
#
# data_cropped/&_20191026_120250_15.jpg	&
#
# data_cropped/&_IMG_2684_0.jpg	&
#
# data_cropped/&_IMG_20200327_140904_5.jpg	&
#
# data_cropped/&_IMG_2505_15.jpg	&
#
# data_cropped/&_20191026_105903_3.jpg	&
#
# data_cropped/&_IMG_2528_13.jpg	&
#
# data_cropped/&_IMG_20200327_143523_0.jpg	&
#
# data_cropped/&_20191026_113418_15.jpg	&
#
# data_cropped/&_IMG_20200327_142715_0.jpg	&
#
# data_cropped/&_IMG_20200327_142017_0.jpg	&
#
# data_cropped/&_20191026_113037_13.jpg	&
#
# data_cropped/&_IMG_2696_0.jpg	&
#
# data_cropped/&_20191026_114248_15.jpg	&
#
# data_cropped/&_2019-10-26 104144_10.jpg	&
#
# data_cropped/&_2019-10-26 121101_12.jpg	&
#
# data_cropped/&_IMG_2517_12.jpg	&
#
# data_cropped/&_IMG_20200327_141012_1.jpg	&
#
# data_cropped/&_IMG_2602_14.jpg	&
#
# data_cropped/&_IMG_20200327_143214_0.jpg	&
#
# data_cropped/&_IMG_20200327_143028_0.jpg	&
#
# data_cropped/&_IMG_20200327_143418_0.jpg	&
#
# data_cropped/&_IMG_2636_2.jpg	&
#
# data_cropped/&_20191026_113221_17.jpg	&
#
# data_cropped/&_IMG_2587_27.jpg	&
#
# data_cropped/&_2019-10-26 122010_3.jpg	&
#
# data_cropped/&_IMG_2910_12.jpg	&
#
# data_cropped/&_20191026_110115_3.jpg	&
#
# data_cropped/&_IMG_20200327_144638_0.jpg	&
#
# data_cropped/&_IMG_2660_0.jpg	&
#
# data_cropped/&_20191026_121712_15.jpg	&
#
# data_cropped/&_IMG_2520_16.jpg	&
#
# data_cropped/&_20191026_113129_17.jpg	&
#
# data_cropped/&_IMG_2549_3.jpg	&
#
# data_cropped/&_IMG_20200327_143837_BURST001_COVER_1.jpg	&
#
# data_cropped/&_20191026_120211_16.jpg	&
#
# data_cropped/&_2019-10-26 104006_10.jpg	&
#
# data_cropped/&_2019-10-26 110851_12.jpg	&
#
# data_cropped/&_IMG_2579_16.jpg	&
#
# data_cropped/&_IMG_20200327_141950_0.jpg	&
#
# data_cropped/&_IMG_20200327_140327_5.jpg	&
#
# data_cropped/&_IMG_2507_15.jpg	&
#
# data_cropped/&_IMG_20200327_143000_0.jpg	&
#
# data_cropped/&_IMG_2509_12.jpg	&
#
# data_cropped/&_IMG_20200327_142725_0.jpg	&
#
# data_cropped/&_IMG_20200327_143509_0.jpg	&
#
# data_cropped/&_IMG_2524_4.jpg	&
#
# data_cropped/-_IMG_20200327_143808_8.jpg	-
#
# data_cropped/-_IMG_20200327_141315_12.jpg	-
#
# data_cropped/-_IMG_20200327_142808_3.jpg	-
#
# data_cropped/-_IMG_20200327_143131_8.jpg	-
#
# data_cropped/-_IMG_20200327_140736_16.jpg	-
#
# data_cropped/-_2019-10-26 111519_3.jpg	-
#
# data_cropped/-_IMG_20200327_143253_7.jpg	-
#
# data_cropped/-_20191026_111248_3.jpg	-
#
# data_cropped/-_20191026_121753_6.jpg	-
#
# data_cropped/-_IMG_20200327_144708_3.jpg	-
#
# data_cropped/-_IMG_20200327_140942_4.jpg	-
#
# data_cropped/-_IMG_2862_5.jpg	-
#
# data_cropped/-_IMG_2630_7.jpg	-
#
# data_cropped/-_IMG_2807_4.jpg	-
#
# data_cropped/-_20191026_122037_6.jpg	-
#
# data_cropped/-_IMG_20200327_140715_9.jpg	-
#
# data_cropped/-_IMG_20200327_142325_3.jpg	-
#
# data_cropped/-_20191026_114421_8.jpg	-
#
# data_cropped/-_IMG_2810_4.jpg	-
#
# data_cropped/-_2019-10-26 122105_3.jpg	-
#
# data_cropped/-_2019-10-26 111704_3.jpg	-
#
# data_cropped/-_IMG_20200327_142409_8.jpg	-
#
# data_cropped/-_IMG_20200327_143632_3.jpg	-
#
# data_cropped/-_IMG_20200327_144336_3.jpg	-
#
# data_cropped/-_IMG_2865_5.jpg	-
#
# data_cropped/-_IMG_20200327_143235_8.jpg	-
#
# data_cropped/-_IMG_20200327_140802_7.jpg	-
#
# data_cropped/-_2019-10-26 114107_3.jpg	-
#
# data_cropped/-_IMG_20200327_140651_7.jpg	-
#
# data_cropped/-_IMG_2619_5.jpg	-
#
# data_cropped/-_IMG_20200327_144424_3.jpg	-
#
# data_cropped/-_IMG_20200327_143308_3.jpg	-
#
# data_cropped/-_IMG_20200327_144015_8.jpg	-
#
# data_cropped/-_IMG_2702_5.jpg	-
#
# data_cropped/-_20191026_120130_6.jpg	-
#
# data_cropped/-_20191026_120107_6.jpg	-
#
# data_cropped/-_IMG_20200327_141840_4.jpg	-
#
# data_cropped/-_IMG_2809_4.jpg	-
#
# data_cropped/-_IMG_20200327_143838_4.jpg	-
# data_cropped/-_20191026_113521_6.jpg	-
#
# data_cropped/-_20191026_113037_5.jpg	-
#
# data_cropped/-_IMG_2795_4.jpg	-
#
# data_cropped/-_IMG_2892_3.jpg	-
#
# data_cropped/-_IMG_2649_7.jpg	-
#
# data_cropped/-_2019-10-26 122323_5.jpg	-
#
# data_cropped/-_20191026_121550_5.jpg	-
#
# data_cropped/-_IMG_2875_3.jpg	-
#
# data_cropped/-_IMG_2657_7.jpg	-
#
# data_cropped/-_20191026_110413_3.jpg	-
#
# data_cropped/-_20191026_111222_3.jpg	-
#
# data_cropped/-_IMG_20200327_140511_9.jpg	-
#
# data_cropped/-_2019-10-26 103940_2.jpg	-
#
# data_cropped/-_IMG_2797_4.jpg	-
#
# data_cropped/-_20191026_113139_12.jpg	-
#
# data_cropped/-_IMG_2834_2.jpg	-
#
# data_cropped/-_IMG_2681_5.jpg	-
#
# data_cropped/-_2019-10-26 114518_2.jpg	-
#
# data_cropped/-_20191026_112929_5.jpg	-
#
# data_cropped/-_IMG_20200327_140204_7.jpg	-
#
# data_cropped/-_IMG_2849_10.jpg	-
#
# data_cropped/-_IMG_20200327_142138_7.jpg	-
#
# data_cropped/-_IMG_20200327_142218_8.jpg	-
#
# data_cropped/-_IMG_20200327_140508_2.jpg	-
#
# data_cropped/-_20191026_120219_6.jpg	-
#
# data_cropped/-_IMG_20200327_143638_3.jpg	-
#
# data_cropped/-_IMG_20200327_140612_7.jpg	-
#
# data_cropped/-_IMG_20200327_143915_3.jpg	-
#
# data_cropped/-_IMG_2646_7.jpg	-
#
# data_cropped/-_20191026_110143_13.jpg	-
#
# data_cropped/-_IMG_2514_4.jpg	-
#
# data_cropped/-_IMG_20200327_142304_3.jpg	-
#
# data_cropped/-_20191026_111310_3.jpg	-
#
# data_cropped/-_IMG_20200327_140407_4.jpg	-
#
# data_cropped/-_IMG_20200327_140139_4.jpg	-
#
# data_cropped/-_20191026_110320_3.jpg	-
#
# data_cropped/-_20191026_113322_12.jpg	-
#
# data_cropped/-_20191026_110041_13.jpg	-
#
# data_cropped/-_IMG_2679_5.jpg	-
#
# data_cropped/-_IMG_20200327_141230_3.jpg	-
#
# data_cropped/-_20191026_122003_6.jpg	-
#
# data_cropped/-_IMG_2517_3.jpg	-
#
# data_cropped/-_20191026_111434_3.jpg	-
#
# data_cropped/-_IMG_2748_4.jpg	-
#
# data_cropped/-_20191026_111612_3.jpg	-
#
# data_cropped/-_IMG_20200327_142017_3.jpg	-
#
# data_cropped/-_IMG_20200327_142344_2.jpg	-
#
# data_cropped/-_IMG_20200327_143123_8.jpg	-
#
# data_cropped/-_20191026_113643_6.jpg	-
#
# data_cropped/-_IMG_2472_2.jpg	-
#
# data_cropped/-_IMG_2470_6.jpg	-
#
# data_cropped/-_IMG_2755_4.jpg	-
#
# data_cropped/-_2019-10-26 120628_3.jpg	-
#
# data_cropped/-_IMG_2620_5.jpg	-
#
# data_cropped/-_IMG_2868_3.jpg	-
#
# data_cropped/-_20191026_113933_6.jpg	-
#
# data_cropped/-_IMG_20200327_140327_8.jpg	-
#
# data_cropped/-_IMG_20200327_142350_2.jpg	-
#
# data_cropped/-_IMG_20200327_141705_7.jpg	-
#
# data_cropped/-_IMG_20200327_141027_5.jpg	-
#
# data_cropped/-_IMG_20200327_144738_4.jpg	-
#
# data_cropped/-_IMG_20200327_142903_7.jpg	-
#
# data_cropped/-_20191026_111513_3.jpg	-
#
# data_cropped/-_IMG_2863_5.jpg	-
#
# data_cropped/-_IMG_20200327_142359_2.jpg	-
#
# data_cropped/-_IMG_20200327_145040_3.jpg	-
#
# data_cropped/-_IMG_2685_5.jpg	-
#
# data_cropped/-_IMG_20200327_141259_8.jpg	-
#
# data_cropped/-_IMG_20200327_141230_8.jpg	-
#
# data_cropped/-_IMG_2623_5.jpg	-
#
# data_cropped/-_IMG_20200327_142844_3.jpg	-
#
# data_cropped/-_IMG_20200327_141319_4.jpg	-
#
# data_cropped/-_IMG_20200327_140336_9.jpg	-
#
# data_cropped/-_IMG_20200327_142258_3.jpg	-
#
# data_cropped/-_IMG_20200327_141348_3.jpg	-
#
# data_cropped/-_IMG_2759_4.jpg	-
#
# data_cropped/-_IMG_2469_5.jpg	-
#
# data_cropped/-_IMG_2895_3.jpg	-
#
# data_cropped/-_IMG_20200327_143522_4.jpg	-
#
# data_cropped/-_2019-10-26 121858_4.jpg	-
#
# data_cropped/-_2019-10-26 120415_3.jpg	-
#
# data_cropped/-_20191026_113754_6.jpg	-
#
# data_cropped/-_IMG_2655_5.jpg	-
#
# data_cropped/-_IMG_20200327_142135_3.jpg	-
#
# data_cropped/-_IMG_20200327_140131_4.jpg	-
#
# data_cropped/-_IMG_2683_5.jpg	-
#
# data_cropped/-_20191026_121009_6.jpg	-
#
# data_cropped/-_2019-10-26 121820_4.jpg	-
#
# data_cropped/-_IMG_2852_5.jpg	-
#
# data_cropped/-_IMG_20200327_142748_3.jpg	-
#
# data_cropped/-_IMG_20200327_142134_2.jpg	-
#
# data_cropped/-_IMG_20200327_140523_4.jpg	-
#
# data_cropped/-_IMG_20200327_143137_4.jpg	-
#
# data_cropped/-_20191026_120821_6.jpg	-
#
# data_cropped/-_20191026_113134_12.jpg	-
#
# data_cropped/-_20191026_105947_13.jpg	-
#
# data_cropped/-_IMG_20200327_145026_3.jpg	-
#
# data_cropped/-_IMG_20200327_144341_3.jpg	-
#
# data_cropped/-_IMG_20200327_142615_8.jpg	-
#
# data_cropped/-_20191026_114338_8.jpg	-
#
# data_cropped/-_IMG_20200327_140907_3.jpg	-
#
# data_cropped/-_IMG_20200327_144740_3.jpg	-
#
# data_cropped/0_2019-10-26 104223_9.jpg	0
#
# data_cropped/0_IMG_2546_5.jpg	0
#
# data_cropped/0_20191026_115612_8.jpg	0
#
# data_cropped/0_20191026_114315_13.jpg	0
#
# data_cropped/0_2019-10-26 121838_15.jpg	0
#
# data_cropped/0_IMG_2551_10.jpg	0
#
# data_cropped/0_IMG_2528_7.jpg	0
#
# data_cropped/0_IMG_2522_15.jpg	0
#
# data_cropped/0_IMG_20200327_141154_1.jpg	0
#
# data_cropped/0_IMG_2566_6.jpg	0
#
# data_cropped/0_IMG_2591_8.jpg	0
#
# data_cropped/0_IMG_2532_16.jpg	0
#
# data_cropped/0_IMG_20200327_141715_13.jpg	0
#
# data_cropped/0_2019-10-26 114114_10.jpg	0
#
# data_cropped/0_IMG_20200327_140626_12.jpg	0
#
# data_cropped/0_2019-10-26 114833_9.jpg	0
#
# data_cropped/0_IMG_20200327_140628_12.jpg	0
#
# data_cropped/0_IMG_2524_10.jpg	0
#
# data_cropped/0_IMG_2519_12.jpg	0
#
# data_cropped/0_IMG_2683_12.jpg	0
#
# data_cropped/0_IMG_2571_8.jpg	0
#
# data_cropped/0_IMG_2530_5.jpg	0
#
# data_cropped/0_IMG_2577_8.jpg	0
#
# data_cropped/0_IMG_20200327_141355_15.jpg	0
#
# data_cropped/0_IMG_2736_10.jpg	0
#
# data_cropped/0_IMG_20200327_142503_11.jpg	0
#
# data_cropped/0_IMG_2676_12.jpg	0
#
# data_cropped/0_IMG_2531_15.jpg	0
#
# data_cropped/0_IMG_2682_12.jpg	0
#
# data_cropped/0_IMG_20200327_142622_7.jpg	0
#
# data_cropped/0_IMG_2563_6.jpg	0
#
# data_cropped/0_2019-10-26 110744_11.jpg	0
#
# data_cropped/0_IMG_2575_5.jpg	0
#
# data_cropped/0_IMG_2590_5.jpg	0
#
# data_cropped/0_IMG_2572_8.jpg	0
#
# data_cropped/0_20191026_103734_12.jpg	0
#
# data_cropped/0_IMG_2560_5.jpg	0
#
# data_cropped/0_IMG_20200327_141226_13.jpg	0
#
# data_cropped/0_IMG_2589_8.jpg	0
#
# data_cropped/0_IMG_2551_5.jpg	0
#
# data_cropped/0_20191026_103728_12.jpg	0
#
# data_cropped/0_IMG_2527_7.jpg	0
#
# data_cropped/0_IMG_2527_14.jpg	0
#
# data_cropped/0_IMG_2532_15.jpg	0
#
# data_cropped/0_2019-10-26 115023_12.jpg	0
#
# data_cropped/0_IMG_2602_5.jpg	0
#
# data_cropped/0_IMG_2536_11.jpg	0
#
# data_cropped/0_IMG_20200327_141206_13.jpg	0
#
# data_cropped/0_2019-10-26 114243_12.jpg	0
#
# data_cropped/0_IMG_20200327_140809_14.jpg	0
#
# data_cropped/1_IMG_2577_11.jpg	1
#
# data_cropped/1_IMG_2576_7.jpg	1
#
# data_cropped/1_20191026_111750_10.jpg	1
#
# data_cropped/1_20191026_121732_10.jpg	1
#
# data_cropped/1_IMG_2515_7.jpg	1
#
# data_cropped/1_IMG_20200327_145234_7.jpg	1
#
# data_cropped/1_IMG_2558_4.jpg	1
#
# data_cropped/1_20191026_113246_14.jpg	1
#
# data_cropped/1_20191026_105726_6.jpg	1
#
# data_cropped/1_IMG_20200327_142326_11.jpg	1
#
# data_cropped/1_20191026_110007_5.jpg	1
#
# data_cropped/1_IMG_2654_11.jpg	1
#
# data_cropped/1_2019-10-26 115642_10.jpg	1
#
# data_cropped/1_IMG_2579_12.jpg	1
#
# data_cropped/1_20191026_120748_9.jpg	1
#
# data_cropped/1_IMG_20200327_140651_10.jpg	1
#
# data_cropped/1_20191026_120702_13.jpg	1
#
# data_cropped/1_IMG_2643_9.jpg	1
#
# data_cropped/1_20191026_120311_13.jpg	1
#
# data_cropped/1_IMG_2483_11.jpg	1
#
# data_cropped/1_IMG_20200327_141244_12.jpg	1
#
# data_cropped/1_IMG_2520_4.jpg	1
#
# data_cropped/1_IMG_2752_1.jpg	1
#
# data_cropped/1_20191026_114000_11.jpg	1
#
# data_cropped/1_20191026_113028_9.jpg	1
#
# data_cropped/1_IMG_2506_10.jpg	1
#
# data_cropped/1_20191026_122115_10.jpg	1
#
# data_cropped/1_IMG_2487_12.jpg	1
#
# data_cropped/1_2019-10-26 111446_6.jpg	1
#
# data_cropped/1_IMG_2525_9.jpg	1
#
# data_cropped/1_IMG_20200327_145238_9.jpg	1
#
# data_cropped/1_IMG_20200327_140445_13.jpg	1
#
# data_cropped/1_IMG_2500_11.jpg	1
#
# data_cropped/1_20191026_113635_10.jpg	1
#
# data_cropped/1_2019-10-26 120503_10.jpg	1
#
# data_cropped/1_2019-10-26 120415_10.jpg	1
#
# data_cropped/1_IMG_2635_12.jpg	1
#
# data_cropped/1_IMG_2545_4.jpg	1
#
# data_cropped/1_2019-10-26 114733_12.jpg	1
#
# data_cropped/1_IMG_2481_11.jpg	1
#
# data_cropped/1_IMG_2584_15.jpg	1
#
# data_cropped/1_20191026_111601_10.jpg	1
#
# data_cropped/1_20191026_111215_10.jpg	1
#
# data_cropped/1_20191026_110007_7.jpg	1
#
# data_cropped/1_2019-10-26 115119_9.jpg	1
#
# data_cropped/1_IMG_2652_11.jpg	1
#
# data_cropped/1_20191026_110239_5.jpg	1
#
# data_cropped/1_20191026_121704_10.jpg	1
#
# data_cropped/1_20191026_121820_10.jpg	1
#
# data_cropped/1_2019-10-26 103802_10.jpg	1
#
# data_cropped/1_20191026_120815_12.jpg	1
#
# data_cropped/1_IMG_2586_11.jpg	1
#
# data_cropped/1_20191026_105832_7.jpg	1
#
# data_cropped/1_20191026_105650_5.jpg	1
#
# data_cropped/1_IMG_20200327_142139_9.jpg	1
#
# data_cropped/1_IMG_2501_13.jpg	1
#
# data_cropped/1_IMG_20200327_140707_13.jpg	1
#
# data_cropped/1_20191026_120702_9.jpg	1
# data_cropped/1_IMG_20200327_142313_10.jpg	1
#
# data_cropped/1_2019-10-26 110630_7.jpg	1
#
# data_cropped/1_20191026_120640_13.jpg	1
#
# data_cropped/1_IMG_20200327_144828_10.jpg	1
#
# data_cropped/1_IMG_2898_7.jpg	1
#
# data_cropped/1_20191026_120311_12.jpg	1
#
# data_cropped/1_2019-10-26 120830_9.jpg	1
#
# data_cropped/1_IMG_2575_9.jpg	1
#
# data_cropped/1_20191026_113534_10.jpg	1
#
# data_cropped/1_20191026_115035_11.jpg	1
#
# data_cropped/1_20191026_122303_7.jpg	1
#
# data_cropped/1_IMG_2841_9.jpg	1
#
# data_cropped/1_IMG_2576_15.jpg	1
#
# data_cropped/1_IMG_2710_12.jpg	1
#
# data_cropped/1_IMG_2506_13.jpg	1
#
# data_cropped/1_IMG_20200327_144034_8.jpg	1
#
# data_cropped/1_IMG_2554_15.jpg	1
#
# data_cropped/1_20191026_113732_10.jpg	1
#
# data_cropped/1_IMG_20200327_140122_14.jpg	1
#
# data_cropped/1_20191026_111648_10.jpg	1
#
# data_cropped/1_IMG_20200327_144733_7.jpg	1
#
# data_cropped/1_IMG_20200327_144355_7.jpg	1
#
# data_cropped/1_IMG_20200327_142945_12.jpg	1
#
# data_cropped/1_IMG_20200327_144359_13.jpg	1
#
# data_cropped/1_20191026_122055_10.jpg	1
#
# data_cropped/1_20191026_120536_13.jpg	1
#
# data_cropped/1_IMG_2562_4.jpg	1
#
# data_cropped/1_20191026_115020_11.jpg	1
#
# data_cropped/1_IMG_2635_11.jpg	1
#
# data_cropped/1_2019-10-26 114506_7.jpg	1
#
# data_cropped/1_2019-10-26 111247_6.jpg	1
#
# data_cropped/1_20191026_113302_10.jpg	1
#
# data_cropped/1_2019-10-26 120415_6.jpg	1
#
# data_cropped/1_IMG_20200327_145040_10.jpg	1
#
# data_cropped/1_20191026_111347_7.jpg	1
#
# data_cropped/1_2019-10-26 110834_10.jpg	1
#
# data_cropped/1_IMG_20200327_142839_13.jpg	1
#
# data_cropped/1_IMG_2517_7.jpg	1
#
# data_cropped/1_20191026_113255_11.jpg	1
#
# data_cropped/1_IMG_2652_12.jpg	1
#
# data_cropped/1_2019-10-26 122256_9.jpg	1
#
# data_cropped/1_20191026_113200_14.jpg	1
#
# data_cropped/1_20191026_105745_7.jpg	1
#
# data_cropped/1_IMG_2926_7.jpg	1
#
# data_cropped/1_IMG_2639_9.jpg	1
#
# data_cropped/1_IMG_20200327_140304_12.jpg	1
#
# data_cropped/1_IMG_2879_7.jpg	1
#
# data_cropped/1_IMG_2905_7.jpg	1
#
# data_cropped/1_IMG_20200327_144647_11.jpg	1
#
# data_cropped/1_IMG_2919_7.jpg	1
#
# data_cropped/1_2019-10-26 115443_10.jpg	1
#
# data_cropped/1_IMG_20200327_143656_7.jpg	1
#
# data_cropped/1_IMG_2514_7.jpg	1
#
# data_cropped/1_2019-10-26 120323_12.jpg	1
#
# data_cropped/1_IMG_2478_7.jpg	1
#
# data_cropped/1_20191026_105707_6.jpg	1
#
# data_cropped/1_20191026_110152_6.jpg	1
#
# data_cropped/1_IMG_20200327_144933_10.jpg	1
#
# data_cropped/1_20191026_120143_13.jpg	1
#
# data_cropped/1_20191026_111248_10.jpg	1
#
# data_cropped/1_2019-10-26 111618_10.jpg	1
#
# data_cropped/1_IMG_2584_4.jpg	1
#
# data_cropped/1_IMG_20200327_143808_13.jpg	1
#
# data_cropped/1_20191026_105603_7.jpg	1
#
# data_cropped/1_2019-10-26 111247_10.jpg	1
#
# data_cropped/1_20191026_120821_12.jpg	1
#
# data_cropped/1_20191026_121807_10.jpg	1
#
# data_cropped/1_IMG_20200327_142919_12.jpg	1
#
# data_cropped/1_2019-10-26 104157_7.jpg	1
#
# data_cropped/1_IMG_20200327_140600_12.jpg	1
#
# data_cropped/1_IMG_20200327_140304_11.jpg	1
#
# data_cropped/1_IMG_2550_15.jpg	1
#
# data_cropped/1_20191026_111637_10.jpg	1
#
# data_cropped/1_IMG_2476_7.jpg	1
#
# data_cropped/1_IMG_2731_9.jpg	1
#
# data_cropped/1_IMG_2469_14.jpg	1
#
# data_cropped/1_IMG_20200327_143000_12.jpg	1
#
# data_cropped/1_IMG_2727_10.jpg	1
#
# data_cropped/1_IMG_2484_12.jpg	1
#
# data_cropped/1_20191026_103739_5.jpg	1
#
# data_cropped/1_IMG_2691_9.jpg	1
#
# data_cropped/1_IMG_20200327_140610_11.jpg	1
#
# data_cropped/1_IMG_2515_11.jpg	1
#
# data_cropped/1_20191026_114248_12.jpg	1
#
# data_cropped/1_IMG_2568_4.jpg	1
#
# data_cropped/1_IMG_2638_11.jpg	1
#
# data_cropped/1_IMG_2705_9.jpg	1
#
# data_cropped/1_IMG_20200327_140942_7.jpg	1
#
# data_cropped/1_IMG_20200327_141555_11.jpg	1
#
# data_cropped/1_IMG_2485_7.jpg	1
#
# data_cropped/1_IMG_20200327_142915_12.jpg	1
#
# data_cropped/1_IMG_2507_12.jpg	1
#
# data_cropped/1_IMG_2645_11.jpg	1
#
# data_cropped/1_IMG_2578_7.jpg	1
#
# data_cropped/1_20191026_103545_7.jpg	1
#
# data_cropped/1_IMG_2488_8.jpg	1
#
# data_cropped/1_IMG_2512_11.jpg	1
#
# data_cropped/1_20191026_113837_10.jpg	1
#
# data_cropped/1_IMG_2895_7.jpg	1
#
# data_cropped/1_2019-10-26 120445_10.jpg	1
#
# data_cropped/1_20191026_115035_5.jpg	1
#
# data_cropped/1_20191026_103707_6.jpg	1
#
# data_cropped/1_IMG_2492_8.jpg	1
#
# data_cropped/1_IMG_20200327_143016_5.jpg	1
#
# data_cropped/1_IMG_2598_9.jpg	1
#
# data_cropped/1_IMG_2646_11.jpg	1
#
# data_cropped/1_IMG_20200327_143028_12.jpg	1
#
# data_cropped/1_IMG_2739_1.jpg	1
#
# data_cropped/1_2019-10-26 111722_6.jpg	1
#
# data_cropped/1_20191026_110053_5.jpg	1
#
# data_cropped/1_2019-10-26 120651_9.jpg	1
#
# data_cropped/1_20191026_110255_7.jpg	1
#
# data_cropped/1_IMG_2528_13.jpg	1
#
# data_cropped/1_IMG_2883_15.jpg	1
#
# data_cropped/1_20191026_103808_6.jpg	1
#
# data_cropped/1_IMG_2498_7.jpg	1
#
# data_cropped/1_2019-10-26 111546_10.jpg	1
#
# data_cropped/1_2019-10-26 120336_8.jpg	1
#
# data_cropped/1_IMG_20200327_144250_8.jpg	1
#
# data_cropped/1_20191026_121934_10.jpg	1
#
# data_cropped/1_2019-10-26 120821_6.jpg	1
#
# data_cropped/1_IMG_20200327_144122_10.jpg	1
#
# data_cropped/1_20191026_105657_7.jpg	1
#
# data_cropped/1_IMG_20200327_141042_11.jpg	1
#
# data_cropped/1_IMG_2918_7.jpg	1
#
# data_cropped/1_20191026_113311_14.jpg	1
#
# data_cropped/1_20191026_103734_5.jpg	1
#
# data_cropped/1_20191026_105939_5.jpg	1
#
# data_cropped/1_IMG_20200327_140644_9.jpg	1
#
# data_cropped/1_20191026_105745_6.jpg	1
#
# data_cropped/1_IMG_20200327_144424_8.jpg	1
#
# data_cropped/1_IMG_2806_1.jpg	1
#
# data_cropped/1_2019-10-26 114325_8.jpg	1
#
# data_cropped/1_20191026_110041_7.jpg	1
#
# data_cropped/1_20191026_111531_10.jpg	1
#
# data_cropped/1_2019-10-26 114318_7.jpg	1
#
# data_cropped/1_IMG_20200327_143620_10.jpg	1
#
# data_cropped/1_20191026_110517_10.jpg	1
#
# data_cropped/1_IMG_20200327_142806_8.jpg	1
#
# data_cropped/1_2019-10-26 120135_12.jpg	1
#
# data_cropped/1_IMG_20200327_140858_13.jpg	1
#
# data_cropped/1_20191026_112802_6.jpg	1
#
# data_cropped/1_20191026_113650_10.jpg	1
#
# data_cropped/1_IMG_2677_9.jpg	1
#
# data_cropped/1_20191026_113134_14.jpg	1
#
# data_cropped/1_IMG_20200327_144455_14.jpg	1
#
# data_cropped/1_2019-10-26 103744_4.jpg	1
#
# data_cropped/1_2019-10-26 115053_1.jpg	1
#
# data_cropped/1_20191026_120917_12.jpg	1
#
# data_cropped/1_IMG_20200327_142326_10.jpg	1
#
# data_cropped/1_20191026_113450_10.jpg	1
#
# data_cropped/1_IMG_2665_9.jpg	1
#
# data_cropped/1_IMG_2584_14.jpg	1
#
# data_cropped/1_IMG_2565_12.jpg	1
#
# data_cropped/1_20191026_113200_10.jpg	1
#
# data_cropped/1_20191026_110024_5.jpg	1
#
# data_cropped/1_IMG_2903_19.jpg	1
#
# data_cropped/1_2019-10-26 115645_11.jpg	1
#
# data_cropped/1_20191026_113409_10.jpg	1
#
# data_cropped/2c2-jc1a_2019-10-26 114107_0.jpg	2c2-jc1a
#
# data_cropped/2c2-jc1a_2019-10-26 120440_0.jpg	2c2-jc1a
#
# data_cropped/2c2-jc1a_2019-10-26 111519_0.jpg	2c2-jc1a
#
# data_cropped/2c2-jc1a_2019-10-26 111247_0.jpg	2c2-jc1a
#
# data_cropped/2c2-jc1a_2019-10-26 122402_0.jpg	2c2-jc1a
#
# data_cropped/2c2-jc1a_2019-10-26 120950_0.jpg	2c2-jc1a
#
# data_cropped/2e3a-szc_IMG_2798_0.jpg	2e3a-szc
#
# data_cropped/2e3a-szc_IMG_2745_0.jpg	2e3a-szc
#
# data_cropped/2e3a-szc_IMG_2808_0.jpg	2e3a-szc
#
# data_cropped/2e3a-szc_IMG_2735_0.jpg	2e3a-szc
#
# data_cropped/2e3a-szc_IMG_2717_0.jpg	2e3a-szc
#
# data_cropped/2e3a-szc_IMG_2817_0.jpg	2e3a-szc
#
# data_cropped/2e3a-szc_IMG_2747_0.jpg	2e3a-szc
#
# data_cropped/2e3a-szc_IMG_2818_0.jpg	2e3a-szc
#
# data_cropped/2e3a-szc_IMG_2810_0.jpg	2e3a-szc
#
# data_cropped/2f8-szc1_IMG_2878_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_IMG_2873_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_20191026_110255_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_IMG_2892_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_20191026_111612_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_IMG_2875_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_IMG_2921_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_20191026_111446_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_IMG_2889_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_2019-10-26 114827_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_2019-10-26 111020_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_IMG_2925_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_IMG_2910_0.jpg	2f8-szc1
#
# data_cropped/2f8-szc1_20191026_111357_0.jpg	2f8-szc1
#
# data_cropped/2_IMG_20200327_140602_15.jpg	2
#
# data_cropped/2_IMG_20200327_142252_10.jpg	2
#
# data_cropped/2_2019-10-26 115231_9.jpg	2
#
# data_cropped/2_2019-10-26 115645_1.jpg	2
#
# data_cropped/2_2019-10-26 115319_11.jpg	2
#
# data_cropped/2_IMG_2880_0.jpg	2
#
# data_cropped/2_IMG_2526_6.jpg	2
#
# data_cropped/2_20191026_113322_18.jpg	2
#
# data_cropped/2_IMG_2620_1.jpg	2
#
# data_cropped/2_20191026_115012_13.jpg	2
#
# data_cropped/2_IMG_20200327_140017_12.jpg	2
#
# data_cropped/2_20191026_120557_16.jpg	2
# data_cropped/2_2019-10-26 111618_2.jpg	2
#
# data_cropped/2_2019-10-26 122238_0.jpg	2
#
# data_cropped/2_IMG_2830_9.jpg	2
#
# data_cropped/2_IMG_2522_6.jpg	2
#
# data_cropped/2_2019-10-26 120415_12.jpg	2
#
# data_cropped/2_IMG_2924_0.jpg	2
#
# data_cropped/2_20191026_113635_16.jpg	2
#
# data_cropped/2_IMG_20200327_141157_13.jpg	2
#
# data_cropped/2_IMG_2506_0.jpg	2
#
# data_cropped/2_IMG_2553_6.jpg	2
#
# data_cropped/2_IMG_20200327_144346_9.jpg	2
#
# data_cropped/2_IMG_20200327_142742_11.jpg	2
#
# data_cropped/2_IMG_2798_0.jpg	2
#
# data_cropped/2_2019-10-26 114624_6.jpg	2
#
# data_cropped/2_2019-10-26 111403_2.jpg	2
#
# data_cropped/2_20191026_113311_18.jpg	2
#
# data_cropped/2_IMG_20200327_141418_2.jpg	2
#
# data_cropped/2_IMG_20200327_141523_11.jpg	2
#
# data_cropped/2_IMG_20200327_144355_5.jpg	2
#
# data_cropped/2_IMG_2808_0.jpg	2
#
# data_cropped/2_20191026_103526_7.jpg	2
#
# data_cropped/2_20191026_120706_5.jpg	2
#
# data_cropped/2_IMG_2529_6.jpg	2
#
# data_cropped/2_IMG_20200327_140644_3.jpg	2
#
# data_cropped/2_20191026_121532_13.jpg	2
#
# data_cropped/2_IMG_20200327_140336_12.jpg	2
#
# data_cropped/2_20191026_105931_9.jpg	2
#
# data_cropped/2_2019-10-26 121757_9.jpg	2
#
# data_cropped/2_IMG_2549_6.jpg	2
#
# data_cropped/2_20191026_121801_3.jpg	2
#
# data_cropped/2_20191026_103517_7.jpg	2
#
# data_cropped/2_IMG_20200327_144050_11.jpg	2
#
# data_cropped/2_20191026_120706_16.jpg	2
#
# data_cropped/2_IMG_2754_0.jpg	2
#
# data_cropped/2_IMG_2708_14.jpg	2
#
# data_cropped/2_IMG_2627_3.jpg	2
#
# data_cropped/2_IMG_2488_1.jpg	2
#
# data_cropped/2_IMG_20200327_140249_14.jpg	2
#
# data_cropped/2_IMG_20200327_142930_11.jpg	2
#
# data_cropped/2_IMG_2531_11.jpg	2
#
# data_cropped/2_20191026_113400_16.jpg	2
#
# data_cropped/2_IMG_2661_3.jpg	2
#
# data_cropped/2_IMG_2549_16.jpg	2
#
# data_cropped/2_IMG_2583_11.jpg	2
#
# data_cropped/2_2019-10-26 103719_6.jpg	2
#
# data_cropped/2_2019-10-26 121000_1.jpg	2
#
# data_cropped/2_20191026_113515_3.jpg	2
#
# data_cropped/2_IMG_20200327_140508_10.jpg	2
#
# data_cropped/2_IMG_2606_11.jpg	2
#
# data_cropped/2_IMG_20200327_142633_10.jpg	2
#
# data_cropped/2_IMG_20200327_143335_7.jpg	2
#
# data_cropped/2_2019-10-26 121838_9.jpg	2
#
# data_cropped/2_IMG_2537_6.jpg	2
#
# data_cropped/2_IMG_20200327_142139_13.jpg	2
#
# data_cropped/2_IMG_20200327_141658_3.jpg	2
#
# data_cropped/2_IMG_2827_8.jpg	2
#
# data_cropped/2_20191026_120059_16.jpg	2
#
# data_cropped/2_IMG_2564_11.jpg	2
#
# data_cropped/2_IMG_2670_11.jpg	2
#
# data_cropped/2_IMG_2509_10.jpg	2
#
# data_cropped/2_IMG_2705_11.jpg	2
#
# data_cropped/2_2019-10-26 114250_0.jpg	2
#
# data_cropped/2_IMG_2869_0.jpg	2
#
# data_cropped/2_20191026_120742_4.jpg	2
#
# data_cropped/2_2019-10-26 114325_11.jpg	2
#
# data_cropped/2_IMG_20200327_140600_5.jpg	2
#
# data_cropped/2_IMG_2547_11.jpg	2
#
# data_cropped/2_IMG_2820_9.jpg	2
#
# data_cropped/2_20191026_113544_3.jpg	2
#
# data_cropped/2_2019-10-26 114733_0.jpg	2
#
# data_cropped/2_IMG_2660_11.jpg	2
#
# data_cropped/2_2019-10-26 115421_9.jpg	2
#
# data_cropped/2_20191026_111310_0.jpg	2
#
# data_cropped/2_IMG_20200327_141435_12.jpg	2
#
# data_cropped/2_IMG_2525_11.jpg	2
#
# data_cropped/2_IMG_2711_1.jpg	2
#
# data_cropped/2_20191026_120211_3.jpg	2
#
# data_cropped/2_IMG_20200327_143306_11.jpg	2
#
# data_cropped/2_IMG_20200327_140501_12.jpg	2
#
# data_cropped/2_20191026_120706_3.jpg	2
#
# data_cropped/2_IMG_2823_0.jpg	2
#
# data_cropped/2_IMG_20200327_141209_15.jpg	2
#
# data_cropped/2_IMG_20200327_142734_11.jpg	2
#
# data_cropped/2_20191026_113129_3.jpg	2
#
# data_cropped/2_IMG_2593_12.jpg	2
#
# data_cropped/2_20191026_121745_3.jpg	2
#
# data_cropped/2_IMG_2825_9.jpg	2
#
# data_cropped/2_IMG_20200327_140119_12.jpg	2
#
# data_cropped/2_20191026_113833_3.jpg	2
#
# data_cropped/2_20191026_121058_5.jpg	2
#
# data_cropped/2_IMG_2755_0.jpg	2
#
# data_cropped/2_IMG_20200327_140942_10.jpg	2
#
# data_cropped/2_20191026_115012_3.jpg	2
#
# data_cropped/2_IMG_20200327_145220_5.jpg	2
#
# data_cropped/2_IMG_20200327_140748_15.jpg	2
#
# data_cropped/2_IMG_2695_11.jpg	2
#
# data_cropped/2_2019-10-26 103539_6.jpg	2
#
# data_cropped/2_2019-10-26 114222_15.jpg	2
#
# data_cropped/2_20191026_113521_16.jpg	2
#
# data_cropped/2_2019-10-26 115642_1.jpg	2
#
# data_cropped/2_20191026_103512_7.jpg	2
#
# data_cropped/2_IMG_2811_8.jpg	2
#
# data_cropped/2_IMG_20200327_142926_10.jpg	2
#
# data_cropped/2_IMG_20200327_144933_16.jpg	2
#
# data_cropped/2_IMG_2811_0.jpg	2
#
# data_cropped/2_20191026_120839_5.jpg	2
#
# data_cropped/2_IMG_20200327_142508_8.jpg	2
#
# data_cropped/2_IMG_2640_11.jpg	2
#
# data_cropped/2_IMG_20200327_141943_5.jpg	2
#
# data_cropped/2_IMG_20200327_141715_11.jpg	2
#
# data_cropped/2_IMG_2851_0.jpg	2
#
# data_cropped/2_IMG_2726_0.jpg	2
#
# data_cropped/2_IMG_2524_6.jpg	2
#
# data_cropped/2_20191026_114113_17.jpg	2
#
# data_cropped/2_2019-10-26 115131_11.jpg	2
#
# data_cropped/2_2019-10-26 111722_0.jpg	2
#
# data_cropped/2_IMG_2536_11.jpg	2
#
# data_cropped/2_IMG_2683_2.jpg	2
#
# data_cropped/2_IMG_2577_9.jpg	2
#
# data_cropped/2_IMG_20200327_140312_12.jpg	2
#
# data_cropped/2_20191026_110007_8.jpg	2
#
# data_cropped/2_20191026_120557_5.jpg	2
#
# data_cropped/2_IMG_2477_0.jpg	2
#
# data_cropped/2_2019-10-26 121045_2.jpg	2
#
# data_cropped/2_IMG_2909_0.jpg	2
#
# data_cropped/2_IMG_2508_10.jpg	2
#
# data_cropped/2_2019-10-26 110643_8.jpg	2
#
# data_cropped/2_20191026_120250_5.jpg	2
#
# data_cropped/2_IMG_2469_5.jpg	2
#
# data_cropped/2_IMG_20200327_142919_11.jpg	2
#
# data_cropped/2_IMG_2580_6.jpg	2
#
# data_cropped/2_IMG_20200327_141638_10.jpg	2
#
# data_cropped/2_20191026_121919_3.jpg	2
#
# data_cropped/2_IMG_2908_0.jpg	2
#
# data_cropped/2_IMG_20200327_140814_13.jpg	2
#
# data_cropped/2_IMG_20200327_144341_13.jpg	2
#
# data_cropped/2_IMG_2506_10.jpg	2
#
# data_cropped/2_IMG_2619_1.jpg	2
#
# data_cropped/2_2019-10-26 115648_2.jpg	2
#
# data_cropped/2_IMG_2496_10.jpg	2
#
# data_cropped/2_20191026_103941_9.jpg	2
#
# data_cropped/2_IMG_20200327_143418_11.jpg	2
#
# data_cropped/2_IMG_2474_0.jpg	2
#
# data_cropped/2_2019-10-26 120759_0.jpg	2
#
# data_cropped/2_IMG_2862_0.jpg	2
#
# data_cropped/2_IMG_2507_0.jpg	2
#
# data_cropped/2_20191026_121704_3.jpg	2
#
# data_cropped/2_IMG_20200327_143551_13.jpg	2
#
# data_cropped/2_IMG_2667_3.jpg	2
#
# data_cropped/2_2019-10-26 121928_9.jpg	2
#
# data_cropped/2_2019-10-26 115645_2.jpg	2
#
# data_cropped/2_IMG_20200327_140411_12.jpg	2
#
# data_cropped/2_IMG_2751_0.jpg	2
#
# data_cropped/2_IMG_20200327_145026_6.jpg	2
#
# data_cropped/2_IMG_20200327_143544_13.jpg	2
#
# data_cropped/2_IMG_2583_7.jpg	2
#
# data_cropped/2_20191026_120656_3.jpg	2
#
# data_cropped/2_IMG_20200327_142121_5.jpg	2
#
# data_cropped/2_IMG_2582_14.jpg	2
#
# data_cropped/2_20191026_120219_3.jpg	2
#
# data_cropped/2_IMG_2658_11.jpg	2
#
# data_cropped/2_IMG_20200327_140304_10.jpg	2
#
# data_cropped/2_2019-10-26 111247_0.jpg	2
#
# data_cropped/2_20191026_120607_3.jpg	2
#
# data_cropped/2_IMG_2903_4.jpg	2
#
# data_cropped/2_IMG_2662_2.jpg	2
#
# data_cropped/2_2019-10-26 111446_9.jpg	2
#
# data_cropped/2_20191026_105947_8.jpg	2
#
# data_cropped/2_20191026_105603_8.jpg	2
#
# data_cropped/2_IMG_2710_14.jpg	2
#
# data_cropped/2_IMG_20200327_140303_12.jpg	2
#
# data_cropped/2_2019-10-26 115155_1.jpg	2
#
# data_cropped/2_IMG_2584_6.jpg	2
#
# data_cropped/2_IMG_2797_0.jpg	2
#
# data_cropped/2_IMG_2685_11.jpg	2
#
# data_cropped/2_IMG_2516_0.jpg	2
#
# data_cropped/2_IMG_20200327_142800_6.jpg	2
#
# data_cropped/2_2019-10-26 120640_0.jpg	2
#
# data_cropped/2_20191026_113946_3.jpg	2
#
# data_cropped/2_IMG_2845_1.jpg	2
#
# data_cropped/2_2019-10-26 114833_0.jpg	2
#
# data_cropped/2_20191026_113627_16.jpg	2
#
# data_cropped/2_IMG_2546_16.jpg	2
#
# data_cropped/2_IMG_2616_9.jpg	2
#
# data_cropped/2_IMG_20200327_142154_10.jpg	2
#
# data_cropped/2_IMG_2580_11.jpg	2
#
# data_cropped/2_IMG_2852_0.jpg	2
#
# data_cropped/2_2019-10-26 114807_0.jpg	2
#
# data_cropped/2_IMG_20200327_142209_10.jpg	2
#
# data_cropped/2_IMG_2638_3.jpg	2
#
# data_cropped/2_IMG_20200327_144431_14.jpg	2
#
# data_cropped/2_IMG_2697_4.jpg	2
#
# data_cropped/2_IMG_2654_13.jpg	2
#
# data_cropped/2_2019-10-26 114301_0.jpg	2
#
# data_cropped/2_20191026_110152_8.jpg	2
#
# data_cropped/2_IMG_2477_10.jpg	2
#
# data_cropped/2_2019-10-26 115238_3.jpg	2
#
# data_cropped/2_20191026_110239_9.jpg	2
#
# data_cropped/2_2019-10-26 120440_12.jpg	2
#
# data_cropped/2_IMG_2641_1.jpg	2
#
# data_cropped/2_IMG_20200327_140535_7.jpg	2
#
# data_cropped/2_IMG_2514_8.jpg	2
#
# data_cropped/2_20191026_121024_3.jpg	2
#
# data_cropped/2_IMG_2699_13.jpg	2
#
# data_cropped/2_IMG_2721_3.jpg	2
#
# data_cropped/2_IMG_2533_14.jpg	2
#
# data_cropped/2_IMG_20200327_142223_10.jpg	2
#
# data_cropped/2_IMG_2519_11.jpg	2
#
# data_cropped/2_IMG_20200327_142218_11.jpg	2
#
# data_cropped/2_IMG_2720_0.jpg	2
#
# data_cropped/2_IMG_2540_9.jpg	2
# data_cropped/2_IMG_20200327_145238_5.jpg	2
#
# data_cropped/2_IMG_2704_14.jpg	2
#
# data_cropped/2_20191026_120805_16.jpg	2
#
# data_cropped/2_IMG_2763_0.jpg	2
#
# data_cropped/2_IMG_2503_1.jpg	2
#
# data_cropped/2_IMG_20200327_141211_1.jpg	2
#
# data_cropped/2_20191026_113614_16.jpg	2
#
# data_cropped/2_IMG_20200327_141822_11.jpg	2
#
# data_cropped/3_IMG_2688_4.jpg	3
#
# data_cropped/3_IMG_2720_5.jpg	3
#
# data_cropped/3_20191026_114833_14.jpg	3
#
# data_cropped/3_IMG_2525_7.jpg	3
#
# data_cropped/3_IMG_2583_3.jpg	3
#
# data_cropped/3_IMG_20200327_140751_5.jpg	3
#
# data_cropped/3_IMG_20200327_140707_11.jpg	3
#
# data_cropped/3_IMG_2469_10.jpg	3
#
# data_cropped/3_20191026_121546_9.jpg	3
#
# data_cropped/3_IMG_20200327_141614_11.jpg	3
#
# data_cropped/3_IMG_2709_3.jpg	3
#
# data_cropped/3_IMG_20200327_144715_14.jpg	3
#
# data_cropped/3_IMG_2600_2.jpg	3
#
# data_cropped/3_IMG_2634_5.jpg	3
#
# data_cropped/3_2019-10-26 115119_3.jpg	3
#
# data_cropped/3_IMG_2558_3.jpg	3
#
# data_cropped/3_IMG_20200327_143447_13.jpg	3
#
# data_cropped/3_IMG_2804_2.jpg	3
#
# data_cropped/3_IMG_2898_9.jpg	3
#
# data_cropped/3_IMG_20200327_141423_1.jpg	3
#
# data_cropped/3_IMG_20200327_143808_14.jpg	3
#
# data_cropped/3_IMG_20200327_140736_10.jpg	3
#
# data_cropped/3_IMG_20200327_143501_14.jpg	3
#
# data_cropped/3_IMG_2554_7.jpg	3
#
# data_cropped/3_2019-10-26 114531_6.jpg	3
#
# data_cropped/3_IMG_2920_9.jpg	3
#
# data_cropped/3_IMG_2605_2.jpg	3
#
# data_cropped/3_20191026_120040_13.jpg	3
#
# data_cropped/3_20191026_103734_8.jpg	3
#
# data_cropped/3_IMG_20200327_144558_15.jpg	3
#
# data_cropped/3_IMG_2717_2.jpg	3
#
# data_cropped/3_20191026_111612_9.jpg	3
#
# data_cropped/3_IMG_2676_4.jpg	3
#
# data_cropped/3_IMG_20200327_141348_14.jpg	3
#
# data_cropped/3_IMG_2625_3.jpg	3
#
# data_cropped/3_IMG_20200327_142258_12.jpg	3
#
# data_cropped/3_IMG_2518_3.jpg	3
#
# data_cropped/3_IMG_2568_3.jpg	3
#
# data_cropped/3_2019-10-26 121906_11.jpg	3
#
# data_cropped/3_IMG_2552_8.jpg	3
#
# data_cropped/3_IMG_2820_10.jpg	3
#
# data_cropped/3_IMG_2604_2.jpg	3
#
# data_cropped/3_2019-10-26 115226_3.jpg	3
#
# data_cropped/3_IMG_20200327_141556_0.jpg	3
#
# data_cropped/3_IMG_2584_2.jpg	3
#
# data_cropped/3_20191026_121901_12.jpg	3
#
# data_cropped/3_IMG_2703_3.jpg	3
#
# data_cropped/3_IMG_2882_9.jpg	3
#
# data_cropped/3_IMG_20200327_141715_12.jpg	3
#
# data_cropped/3_IMG_20200327_141437_7.jpg	3
#
# data_cropped/3_IMG_20200327_141929_11.jpg	3
#
# data_cropped/3_IMG_20200327_140445_16.jpg	3
#
# data_cropped/3_IMG_2545_7.jpg	3
#
# data_cropped/3_IMG_20200327_140645_13.jpg	3
#
# data_cropped/3_IMG_2832_10.jpg	3
#
# data_cropped/3_IMG_20200327_141635_13.jpg	3
#
# data_cropped/3_IMG_2583_11.jpg	3
#
# data_cropped/3_IMG_20200327_143515_13.jpg	3
#
# data_cropped/3_2019-10-26 115231_10.jpg	3
#
# data_cropped/3_2019-10-26 121947_2.jpg	3
#
# data_cropped/3_IMG_2521_4.jpg	3
#
# data_cropped/3_IMG_2831_10.jpg	3
#
# data_cropped/3_IMG_20200327_140315_14.jpg	3
#
# data_cropped/3_IMG_2667_4.jpg	3
#
# data_cropped/3_2019-10-26 122211_7.jpg	3
#
# data_cropped/3_IMG_2864_11.jpg	3
#
# data_cropped/3_IMG_2627_3.jpg	3
#
# data_cropped/3_IMG_2723_2.jpg	3
#
# data_cropped/3_IMG_20200327_145223_11.jpg	3
#
# data_cropped/3_IMG_2759_2.jpg	3
#
# data_cropped/3_IMG_20200327_144549_12.jpg	3
#
# data_cropped/3_IMG_2644_3.jpg	3
#
# data_cropped/3_IMG_2820_2.jpg	3
#
# data_cropped/3_IMG_2731_3.jpg	3
#
# data_cropped/3_20191026_114852_7.jpg	3
#
# data_cropped/3_IMG_2818_2.jpg	3
#
# data_cropped/3_IMG_2636_3.jpg	3
#
# data_cropped/3_IMG_2833_7.jpg	3
#
# data_cropped/3_IMG_20200327_140700_11.jpg	3
#
# data_cropped/3_20191026_111504_9.jpg	3
#
# data_cropped/3_IMG_2534_8.jpg	3
#
# data_cropped/3_IMG_2640_5.jpg	3
#
# data_cropped/3_IMG_2587_17.jpg	3
#
# data_cropped/3_IMG_2652_3.jpg	3
#
# data_cropped/3_IMG_20200327_143001_14.jpg	3
#
# data_cropped/3_2019-10-26 115340_3.jpg	3
#
# data_cropped/3_IMG_2796_10.jpg	3
#
# data_cropped/3_IMG_2695_4.jpg	3
#
# data_cropped/3_IMG_2580_5.jpg	3
#
# data_cropped/3_IMG_20200327_145002_11.jpg	3
#
# data_cropped/3_IMG_2471_6.jpg	3
#
# data_cropped/3_20191026_121550_9.jpg	3
#
# data_cropped/3_IMG_2887_9.jpg	3
#
# data_cropped/3_20191026_121919_12.jpg	3
#
# data_cropped/3_IMG_2685_3.jpg	3
#
# data_cropped/3_IMG_2468_7.jpg	3
#
# data_cropped/3_IMG_2765_7.jpg	3
#
# data_cropped/3_IMG_2760_2.jpg	3
#
# data_cropped/3_2019-10-26 114550_6.jpg	3
#
# data_cropped/3_IMG_20200327_143020_13.jpg	3
#
# data_cropped/3_IMG_2923_9.jpg	3
#
# data_cropped/3_IMG_2587_2.jpg	3
#
# data_cropped/3_IMG_2665_4.jpg	3
#
# data_cropped/3_IMG_2574_2.jpg	3
#
# data_cropped/3_IMG_20200327_144647_3.jpg	3
#
# data_cropped/3_2019-10-26 122315_12.jpg	3
#
# data_cropped/3_IMG_2543_4.jpg	3
#
# data_cropped/3_IMG_2731_2.jpg	3
#
# data_cropped/3_IMG_2546_2.jpg	3
#
# data_cropped/3_IMG_2553_2.jpg	3
#
# data_cropped/3_20191026_103122_11.jpg	3
#
# data_cropped/421h_IMG_2646_2.jpg	421h
#
# data_cropped/421h_IMG_2642_2.jpg	421h
#
# data_cropped/421h_IMG_2654_2.jpg	421h
#
# data_cropped/421h_IMG_2648_2.jpg	421h
#
# data_cropped/421h_IMG_2644_2.jpg	421h
#
# data_cropped/4_IMG_20200327_145146_11.jpg	4
#
# data_cropped/4_IMG_2758_9.jpg	4
#
# data_cropped/4_20191026_113650_11.jpg	4
#
# data_cropped/4_IMG_20200327_141623_13.jpg	4
#
# data_cropped/4_20191026_110143_10.jpg	4
#
# data_cropped/4_2019-10-26 115705_3.jpg	4
#
# data_cropped/4_IMG_20200327_141244_15.jpg	4
#
# data_cropped/4_IMG_20200327_141801_13.jpg	4
#
# data_cropped/4_IMG_2695_10.jpg	4
#
# data_cropped/4_IMG_2717_9.jpg	4
#
# data_cropped/4_IMG_2652_12.jpg	4
#
# data_cropped/4_20191026_113833_12.jpg	4
#
# data_cropped/4_IMG_2636_10.jpg	4
#
# data_cropped/4_2019-10-26 111339_8.jpg	4
#
# data_cropped/4_IMG_2924_10.jpg	4
#
# data_cropped/4_IMG_20200327_142252_12.jpg	4
#
# data_cropped/4_IMG_2698_12.jpg	4
#
# data_cropped/4_IMG_2722_9.jpg	4
#
# data_cropped/4_2019-10-26 114550_7.jpg	4
#
# data_cropped/4_IMG_2842_9.jpg	4
#
# data_cropped/4_IMG_2806_9.jpg	4
#
# data_cropped/4_IMG_2654_10.jpg	4
#
# data_cropped/4_20191026_111434_8.jpg	4
#
# data_cropped/4_2019-10-26 111322_8.jpg	4
#
# data_cropped/4_20191026_105959_10.jpg	4
#
# data_cropped/4_IMG_20200327_141748_1.jpg	4
#
# data_cropped/4_20191026_111357_8.jpg	4
#
# data_cropped/4_20191026_111329_8.jpg	4
#
# data_cropped/4_20191026_113635_12.jpg	4
#
# data_cropped/4_IMG_2685_10.jpg	4
#
# data_cropped/4_20191026_114718_16.jpg	4
#
# data_cropped/4_20191026_110007_10.jpg	4
#
# data_cropped/4_IMG_20200327_141830_13.jpg	4
#
# data_cropped/4_20191026_113801_12.jpg	4
#
# data_cropped/4_IMG_20200327_140610_14.jpg	4
#
# data_cropped/4_2019-10-26 121935_13.jpg	4
#
# data_cropped/4_20191026_113528_12.jpg	4
#
# data_cropped/4_IMG_2656_10.jpg	4
#
# data_cropped/4_2019-10-26 115340_10.jpg	4
#
# data_cropped/4_20191026_113837_11.jpg	4
#
# data_cropped/4_20191026_113409_12.jpg	4
#
# data_cropped/4_IMG_20200327_143021_12.jpg	4
#
# data_cropped/4_20191026_112947_11.jpg	4
#
# data_cropped/4_2019-10-26 115338_10.jpg	4
#
# data_cropped/4_IMG_20200327_144336_13.jpg	4
#
# data_cropped/4_IMG_2665_10.jpg	4
#
# data_cropped/4_IMG_2757_9.jpg	4
#
# data_cropped/4_IMG_20200327_142342_11.jpg	4
#
# data_cropped/4_IMG_2791_9.jpg	4
#
# data_cropped/4_IMG_2847_9.jpg	4
#
# data_cropped/4_20191026_113515_11.jpg	4
#
# data_cropped/4_IMG_20200327_140445_14.jpg	4
#
# data_cropped/4_IMG_2629_12.jpg	4
#
# data_cropped/4_IMG_20200327_140751_7.jpg	4
#
# data_cropped/4_IMG_2784_9.jpg	4
#
# Written 1000 / 2129
# data_cropped/4_IMG_2795_9.jpg	4
#
# data_cropped/4_20191026_113635_11.jpg	4
#
# data_cropped/5_2019-10-26 115103_10.jpg	5
#
# data_cropped/5_IMG_20200327_140621_10.jpg	5
#
# data_cropped/5_IMG_20200327_143117_8.jpg	5
#
# data_cropped/5_IMG_2866_8.jpg	5
#
# data_cropped/5_IMG_20200327_143837_BURST001_COVER_15.jpg	5
#
# data_cropped/5_IMG_2808_10.jpg	5
#
# data_cropped/5_IMG_20200327_142051_11.jpg	5
#
# data_cropped/5_IMG_20200327_144558_9.jpg	5
#
# data_cropped/5_IMG_20200327_144034_9.jpg	5
#
# data_cropped/5_IMG_2774_10.jpg	5
#
# data_cropped/5_IMG_20200327_142701_13.jpg	5
#
# data_cropped/5_IMG_20200327_142800_12.jpg	5
#
# data_cropped/5_IMG_2739_11.jpg	5
#
# data_cropped/5_IMG_20200327_142139_12.jpg	5
#
# data_cropped/5_IMG_2483_9.jpg	5
#
# data_cropped/5_IMG_20200327_144654_14.jpg	5
#
# data_cropped/5_20191026_122134_10.jpg	5
#
# data_cropped/5_IMG_20200327_143856_13.jpg	5
#
# data_cropped/5_IMG_2725_15.jpg	5
#
# data_cropped/5_20191026_120219_11.jpg	5
#
# data_cropped/5_20191026_121820_11.jpg	5
#
# data_cropped/5_IMG_2490_11.jpg	5
#
# data_cropped/5_20191026_120211_14.jpg	5
#
# data_cropped/5_IMG_2902_8.jpg	5
#
# data_cropped/5_IMG_20200327_141805_1.jpg	5
#
# data_cropped/5_IMG_20200327_141035_2.jpg	5
#
# data_cropped/5_IMG_2797_10.jpg	5
#
# data_cropped/5_IMG_2871_8.jpg	5
#
# data_cropped/5_IMG_20200327_144346_12.jpg	5
#
# data_cropped/5_IMG_20200327_143522_1.jpg	5
#
# data_cropped/5_IMG_20200327_142508_9.jpg	5
# data_cropped/5_IMG_20200327_140439_4.jpg	5
#
# data_cropped/5_20191026_121945_10.jpg	5
#
# data_cropped/5_2019-10-26 122443_0.jpg	5
#
# data_cropped/5_IMG_2786_10.jpg	5
#
# data_cropped/5_IMG_20200327_142844_9.jpg	5
#
# data_cropped/5_20191026_105852_10.jpg	5
#
# data_cropped/5_IMG_20200327_141754_2.jpg	5
#
# data_cropped/5_IMG_2483_11.jpg	5
#
# data_cropped/5_20191026_103916_10.jpg	5
#
# data_cropped/5_2019-10-26 115226_1.jpg	5
#
# data_cropped/5_IMG_2904_8.jpg	5
#
# data_cropped/5_IMG_20200327_145149_11.jpg	5
#
# data_cropped/5_2019-10-26 115231_11.jpg	5
#
# data_cropped/5_IMG_20200327_141519_0.jpg	5
#
# data_cropped/5_2019-10-26 121719_0.jpg	5
#
# data_cropped/5_IMG_2849_0.jpg	5
#
# data_cropped/5_2019-10-26 110834_9.jpg	5
#
# data_cropped/5_IMG_2493_11.jpg	5
#
# data_cropped/5_20191026_105650_10.jpg	5
#
# data_cropped/5_IMG_2500_9.jpg	5
#
# data_cropped/5_IMG_20200327_143030_1.jpg	5
#
# data_cropped/5_2019-10-26 121935_0.jpg	5
#
# data_cropped/5_IMG_2770_10.jpg	5
#
# data_cropped/5_IMG_20200327_142644_13.jpg	5
#
# data_cropped/5_IMG_20200327_141451_1.jpg	5
#
# data_cropped/5_IMG_2489_9.jpg	5
#
# data_cropped/5_IMG_20200327_143551_15.jpg	5
#
# data_cropped/5_IMG_20200327_144151_9.jpg	5
#
# data_cropped/5_IMG_20200327_142134_12.jpg	5
#
# data_cropped/5_IMG_2882_8.jpg	5
#
# data_cropped/5_20191026_122011_11.jpg	5
#
# data_cropped/5_2019-10-26 120415_8.jpg	5
#
# data_cropped/5_IMG_2886_10.jpg	5
#
# data_cropped/6_20191026_121704_16.jpg	6
#
# data_cropped/6_IMG_2778_8.jpg	6
#
# data_cropped/6_IMG_2567_9.jpg	6
#
# data_cropped/6_IMG_20200327_144106_3.jpg	6
#
# data_cropped/6_IMG_20200327_140420_2.jpg	6
#
# data_cropped/6_IMG_20200327_142900_13.jpg	6
#
# data_cropped/6_IMG_2769_8.jpg	6
#
# data_cropped/6_IMG_20200327_141115_2.jpg	6
#
# data_cropped/6_IMG_20200327_143954_18.jpg	6
#
# data_cropped/6_IMG_2859_14.jpg	6
#
# data_cropped/6_2019-10-26 120735_8.jpg	6
#
# data_cropped/6_IMG_20200327_141301_12.jpg	6
#
# data_cropped/6_IMG_2743_11.jpg	6
#
# data_cropped/6_IMG_2768_2.jpg	6
#
# data_cropped/6_IMG_20200327_141129_4.jpg	6
#
# data_cropped/6_IMG_2776_8.jpg	6
#
# data_cropped/6_2019-10-26 114737_2.jpg	6
#
# data_cropped/6_IMG_20200327_140710_13.jpg	6
#
# data_cropped/6_IMG_2572_9.jpg	6
#
# data_cropped/6_IMG_2808_8.jpg	6
#
# data_cropped/6_IMG_2721_12.jpg	6
#
# data_cropped/6_IMG_20200327_140427_11.jpg	6
#
# data_cropped/6_IMG_2544_4.jpg	6
#
# data_cropped/6_IMG_2470_3.jpg	6
#
# data_cropped/6_IMG_2860_2.jpg	6
#
# data_cropped/6_IMG_20200327_143943_10.jpg	6
#
# data_cropped/6_IMG_20200327_144309_2.jpg	6
#
# data_cropped/6_IMG_2758_8.jpg	6
#
# data_cropped/6_IMG_20200327_143707_13.jpg	6
#
# data_cropped/6_IMG_2565_9.jpg	6
#
# data_cropped/6_2019-10-26 121019_8.jpg	6
#
# data_cropped/6_20191026_121919_16.jpg	6
#
# data_cropped/6_20191026_121723_13.jpg	6
#
# data_cropped/6_20191026_120917_11.jpg	6
#
# data_cropped/6_2019-10-26 114719_2.jpg	6
#
# data_cropped/6_IMG_20200327_142145_10.jpg	6
#
# data_cropped/6_IMG_20200327_143335_10.jpg	6
#
# data_cropped/6_IMG_20200327_143437_10.jpg	6
#
# data_cropped/6_IMG_20200327_142653_13.jpg	6
#
# data_cropped/6_2019-10-26 114538_8.jpg	6
#
# data_cropped/6_IMG_20200327_143028_13.jpg	6
#
# data_cropped/6_2019-10-26 122352_11.jpg	6
#
# data_cropped/6_2019-10-26 120135_2.jpg	6
#
# data_cropped/6_IMG_2752_10.jpg	6
#
# data_cropped/6_IMG_20200327_140340_13.jpg	6
#
# data_cropped/7_IMG_20200327_142032_6.jpg	7
#
# data_cropped/7_IMG_20200327_142258_13.jpg	7
#
# data_cropped/7_IMG_2841_12.jpg	7
#
# data_cropped/7_IMG_20200327_144828_7.jpg	7
#
# data_cropped/7_20191026_121042_13.jpg	7
#
# data_cropped/7_IMG_20200327_141943_6.jpg	7
#
# data_cropped/7_2019-10-26 103744_12.jpg	7
#
# data_cropped/7_2019-10-26 120830_10.jpg	7
#
# data_cropped/7_IMG_2601_12.jpg	7
#
# data_cropped/7_2019-10-26 120628_10.jpg	7
#
# data_cropped/7_IMG_2834_10.jpg	7
#
# data_cropped/7_IMG_2733_10.jpg	7
#
# data_cropped/7_IMG_2527_8.jpg	7
#
# data_cropped/7_IMG_20200327_141300_15.jpg	7
#
# data_cropped/7_IMG_20200327_143656_6.jpg	7
#
# data_cropped/7_IMG_2747_10.jpg	7
#
# data_cropped/7_IMG_20200327_144322_14.jpg	7
#
# data_cropped/7_IMG_20200327_144408_7.jpg	7
#
# data_cropped/7_2019-10-26 120932_10.jpg	7
#
# data_cropped/7_IMG_20200327_144751_7.jpg	7
#
# data_cropped/7_20191026_120907_13.jpg	7
#
# data_cropped/7_2019-10-26 120852_10.jpg	7
#
# data_cropped/7_2019-10-26 120545_10.jpg	7
#
# data_cropped/7_IMG_2835_10.jpg	7
#
# data_cropped/7_IMG_20200327_140810_0.jpg	7
#
# data_cropped/7_IMG_20200327_140119_15.jpg	7
#
# data_cropped/7_2019-10-26 115110_10.jpg	7
#
# data_cropped/7_2019-10-26 120651_10.jpg	7
#
# data_cropped/7_IMG_20200327_143721_7.jpg	7
#
# data_cropped/7_IMG_20200327_140820_12.jpg	7
#
# data_cropped/8_IMG_2735_8.jpg	8
#
# data_cropped/8_IMG_2898_2.jpg	8
#
# data_cropped/8_IMG_2614_13.jpg	8
#
# data_cropped/8_20191026_113754_5.jpg	8
#
# data_cropped/8_IMG_20200327_141748_0.jpg	8
#
# data_cropped/8_IMG_2917_2.jpg	8
#
# data_cropped/8_IMG_2868_2.jpg	8
#
# data_cropped/8_IMG_20200327_141443_13.jpg	8
#
# data_cropped/8_IMG_20200327_143721_12.jpg	8
#
# data_cropped/8_20191026_113134_5.jpg	8
#
# data_cropped/8_IMG_20200327_142929_12.jpg	8
#
# data_cropped/8_IMG_20200327_144708_14.jpg	8
#
# data_cropped/8_20191026_121739_5.jpg	8
#
# data_cropped/8_IMG_2481_2.jpg	8
#
# data_cropped/8_20191026_110413_2.jpg	8
#
# data_cropped/8_IMG_20200327_141027_11.jpg	8
#
# data_cropped/8_2019-10-26 114232_12.jpg	8
#
# data_cropped/8_IMG_2857_21.jpg	8
#
# data_cropped/8_IMG_2541_17.jpg	8
#
# data_cropped/8_IMG_2861_12.jpg	8
#
# data_cropped/8_20191026_121807_5.jpg	8
#
# data_cropped/8_IMG_20200327_140622_13.jpg	8
#
# data_cropped/8_IMG_2923_2.jpg	8
#
# data_cropped/8_IMG_20200327_141500_6.jpg	8
#
# data_cropped/8_IMG_2603_10.jpg	8
#
# data_cropped/8_20191026_110229_12.jpg	8
#
# data_cropped/8_IMG_2516_2.jpg	8
#
# data_cropped/8_IMG_2737_9.jpg	8
#
# data_cropped/8_IMG_2867_2.jpg	8
#
# data_cropped/8_20191026_111239_2.jpg	8
#
# data_cropped/8_20191026_113144_5.jpg	8
#
# data_cropped/8_IMG_2502_2.jpg	8
#
# data_cropped/8_IMG_2926_2.jpg	8
#
# data_cropped/8_20191026_111232_2.jpg	8
#
# data_cropped/8_20191026_122115_5.jpg	8
#
# data_cropped/8_20191026_111714_2.jpg	8
#
# data_cropped/8_IMG_20200327_142957_11.jpg	8
#
# data_cropped/8_IMG_2853_12.jpg	8
#
# data_cropped/8_IMG_2727_12.jpg	8
#
# data_cropped/8_20191026_113418_5.jpg	8
#
# data_cropped/8_20191026_114216_12.jpg	8
#
# data_cropped/8_20191026_110041_12.jpg	8
#
# data_cropped/8_20191026_113450_5.jpg	8
#
# data_cropped/8_20191026_121934_5.jpg	8
#
# data_cropped/8_IMG_2506_2.jpg	8
#
# data_cropped/8_20191026_113237_5.jpg	8
#
# data_cropped/8_20191026_111724_2.jpg	8
#
# data_cropped/8_IMG_20200327_140119_13.jpg	8
#
# data_cropped/8_IMG_20200327_142152_12.jpg	8
#
# data_cropped/8_20191026_105603_12.jpg	8
#
# data_cropped/8_20191026_113154_5.jpg	8
#
# data_cropped/8_IMG_2580_13.jpg	8
#
# data_cropped/8_IMG_2872_2.jpg	8
#
# data_cropped/8_IMG_2580_10.jpg	8
#
# data_cropped/8_IMG_2486_2.jpg	8
#
# data_cropped/9_IMG_20200327_143306_14.jpg	9
#
# data_cropped/9_20191026_113833_13.jpg	9
#
# data_cropped/9_IMG_2616_13.jpg	9
#
# data_cropped/9_IMG_20200327_142622_5.jpg	9
#
# data_cropped/9_2019-10-26 122156_8.jpg	9
#
# data_cropped/9_IMG_2575_10.jpg	9
#
# data_cropped/9_IMG_20200327_144828_12.jpg	9
#
# data_cropped/9_IMG_20200327_144015_12.jpg	9
#
# data_cropped/9_IMG_20200327_143046_12.jpg	9
#
# data_cropped/9_IMG_20200327_140439_12.jpg	9
#
# data_cropped/9_IMG_20200327_142145_12.jpg	9
#
# ...
#
# data_cropped/j_IMG_20200327_141157_9.jpg	j
#
# data_cropped/j_IMG_20200327_141348_9.jpg	j
#
# data_cropped/j_IMG_20200327_140309_10.jpg	j
#
# data_cropped/j_IMG_20200327_140628_8.jpg	j
#
# data_cropped/j_IMG_20200327_142906_5.jpg	j
#
# data_cropped/j_IMG_20200327_140622_10.jpg	j
#
# data_cropped/j_IMG_20200327_145234_3.jpg	j
#
# data_cropped/j_IMG_20200327_143501_2.jpg	j
#
# data_cropped/j_IMG_20200327_142128_3.jpg	j
#
# data_cropped/j_2019-10-26 114719_8.jpg	j
#
# data_cropped/j_2019-10-26 121010_4.jpg	j
#
# data_cropped/j_IMG_20200327_142046_9.jpg	j
#
# data_cropped/j_IMG_20200327_142819_4.jpg	j
#
# data_cropped/j_20191026_112906_5.jpg	j
#
# data_cropped/j_2019-10-26 114232_8.jpg	j
#
# data_cropped/j_IMG_20200327_141102_10.jpg	j
#
# data_cropped/j_2019-10-26 114807_8.jpg	j
#
# data_cropped/j_IMG_20200327_141623_9.jpg	j
#
# data_cropped/j_IMG_20200327_140541_10.jpg	j
#
# data_cropped/j_IMG_20200327_141552_8.jpg	j
#
# data_cropped/k_IMG_20200327_144857_2.jpg	k
#
# data_cropped/k_IMG_20200327_141451_7.jpg	k
#
# data_cropped/k_2019-10-26 121906_8.jpg	k
#
# data_cropped/k_IMG_20200327_143246_7.jpg	k
#
# data_cropped/k_IMG_20200327_144113_7.jpg	k
#
# data_cropped/k_IMG_20200327_144516_8.jpg	k
#
# data_cropped/l_IMG_20200327_142041_2.jpg	l
#
# data_cropped/l_IMG_20200327_143131_2.jpg	l
#
# data_cropped/l_IMG_20200327_141023_1.jpg	l
#
# data_cropped/l_IMG_20200327_141901_1.jpg	l
#
# data_cropped/l_IMG_20200327_140814_3.jpg	l
#
# data_cropped/l_IMG_2531_13.jpg	l
#
# data_cropped/l_IMG_2579_11.jpg	l
#
# data_cropped/l_IMG_20200327_144654_2.jpg	l
#
# data_cropped/l_IMG_20200327_142700_1.jpg	l
#
# data_cropped/l_IMG_2574_11.jpg	l
#
# data_cropped/l_IMG_2563_9.jpg	l
#
# data_cropped/l_IMG_20200327_142609_2.jpg	l
#
# data_cropped/l_IMG_20200327_140924_1.jpg	l
#
# data_cropped/l_IMG_20200327_140752_3.jpg	l
#
# data_cropped/l_IMG_20200327_143046_2.jpg	l
#
# data_cropped/l_IMG_20200327_142145_1.jpg	l
#
# data_cropped/l_IMG_20200327_140541_3.jpg	l
#
# data_cropped/l_IMG_20200327_140204_1.jpg	l
#
# data_cropped/l_IMG_20200327_142638_2.jpg	l
#
# data_cropped/l_IMG_20200327_142734_2.jpg	l
#
# data_cropped/l_IMG_20200327_141107_3.jpg	l
#
# data_cropped/l_IMG_20200327_140707_1.jpg	l
#
# data_cropped/l_IMG_20200327_140504_1.jpg	l
#
# data_cropped/l_IMG_20200327_141206_3.jpg	l
#
# data_cropped/l_IMG_20200327_143804_2.jpg	l
#
# data_cropped/l_IMG_20200327_141348_2.jpg	l
#
# data_cropped/l_IMG_20200327_141301_2.jpg	l
#
# data_cropped/l_IMG_20200327_143340_2.jpg	l
#
# data_cropped/l_IMG_2567_9.jpg	l
#
# data_cropped/l_2019-10-26 115443_2.jpg	l
#
# data_cropped/l_IMG_20200327_140659_1.jpg	l
#
# data_cropped/l_IMG_20200327_140155_1.jpg	l
#
# data_cropped/l_IMG_20200327_143235_2.jpg	l
#
# data_cropped/l_IMG_2600_8.jpg	l
#
# data_cropped/l_IMG_20200327_140508_1.jpg	l
#
# data_cropped/l_IMG_20200327_141715_2.jpg	l
#
# data_cropped/l_IMG_20200327_142344_1.jpg	l
#
# data_cropped/l_20191026_120034_5.jpg	l
#
# data_cropped/l_IMG_20200327_142715_2.jpg	l
#
# data_cropped/l_IMG_20200327_144708_2.jpg	l
#
# data_cropped/l_IMG_2605_8.jpg	l
#
# data_cropped/l_IMG_2578_11.jpg	l
#
# data_cropped/l_IMG_20200327_141226_3.jpg	l
#
# data_cropped/l_IMG_20200327_142441_2.jpg	l
#
# data_cropped/l_IMG_20200327_140515_3.jpg	l
#
# data_cropped/l_IMG_2586_8.jpg	l
#
# data_cropped/ml-hvdc-jp2_IMG_20200327_140501_1.jpg	ml-hvdc-jp2
#
# data_cropped/ml-hvdc-jp2_IMG_20200327_140903_1.jpg	ml-hvdc-jp2
#
# data_cropped/ml-hvdc-jp2_IMG_20200327_141729_2.jpg	ml-hvdc-jp2
#
# data_cropped/ml-hvdc-jp2_IMG_20200327_140652_4.jpg	ml-hvdc-jp2
#
# data_cropped/ml-hvdc-jp2_IMG_20200327_140413_1.jpg	ml-hvdc-jp2
#
# data_cropped/m_IMG_20200327_143808_1.jpg	m
#
# data_cropped/m_IMG_20200327_140232_2.jpg	m
#
# data_cropped/m_IMG_20200327_140759_2.jpg	m
#
# data_cropped/m_IMG_20200327_143116_1.jpg	m
#
# data_cropped/m_IMG_20200327_140720_0.jpg	m
#
# data_cropped/m_IMG_20200327_142021_0.jpg	m
#
# data_cropped/m_IMG_20200327_143515_1.jpg	m
#
# data_cropped/m_IMG_20200327_143020_1.jpg	m
#
# data_cropped/m_IMG_20200327_141555_0.jpg	m
#
# data_cropped/m_IMG_20200327_141107_0.jpg	m
#
# data_cropped/m_IMG_20200327_143022_2.jpg	m
#
# data_cropped/m_IMG_20200327_140814_2.jpg	m
#
# data_cropped/m_IMG_20200327_142023_0.jpg	m
#
# data_cropped/m_IMG_20200327_141830_2.jpg	m
#
# data_cropped/m_IMG_20200327_144738_6.jpg	m
#
# data_cropped/m_IMG_20200327_141027_0.jpg	m
#
# data_cropped/m_IMG_20200327_141319_0.jpg	m
#
# data_cropped/m_IMG_20200327_142926_1.jpg	m
#
# data_cropped/m_IMG_20200327_141140_2.jpg	m
#
# data_cropped/m_IMG_20200327_143323_1.jpg	m
#
# data_cropped/m_IMG_20200327_140848_2.jpg	m
#
# data_cropped/m_IMG_20200327_140204_0.jpg	m
#
# data_cropped/m_IMG_20200327_141748_7.jpg	m
#
# data_cropped/m_IMG_20200327_141359_2.jpg	m
#
# data_cropped/m_IMG_2846_4.jpg	m
#
# data_cropped/m_IMG_20200327_143218_1.jpg	m
#
# data_cropped/m_IMG_20200327_140858_2.jpg	m
#
# data_cropped/m_IMG_20200327_141635_0.jpg	m
#
# data_cropped/m_IMG_20200327_142046_1.jpg	m
#
# data_cropped/m_2019-10-26 114711_4.jpg	m
#
# data_cropped/m_2019-10-26 114607_4.jpg	m
#
# data_cropped/m_IMG_20200327_143308_1.jpg	m
#
# data_cropped/m_IMG_20200327_142243_0.jpg	m
#
# data_cropped/m_2019-10-26 104212_4.jpg	m
#
# data_cropped/m_IMG_2836_4.jpg	m
#
# data_cropped/m_IMG_20200327_143015_1.jpg	m
# data_cropped/m_IMG_20200327_142240_1.jpg	m
#
# data_cropped/n_2019-10-26 104058_18.jpg	n
#
# data_cropped/n_2019-10-26 104027_1.jpg	n
#
# data_cropped/n_IMG_2467_13.jpg	n
#
# data_cropped/n_IMG_20200327_140535_0.jpg	n
#
# data_cropped/n_2019-10-26 104144_1.jpg	n
#
# data_cropped/n_20191026_114230_4.jpg	n
#
# data_cropped/n_2019-10-26 122246_15.jpg	n
#
# data_cropped/n_20191026_114241_4.jpg	n
#
# data_cropped/p_IMG_20200327_142335_8.jpg	p
#
# data_cropped/p_IMG_20200327_141901_8.jpg	p
#
# data_cropped/p_IMG_20200327_142300_14.jpg	p
#
# data_cropped/p_IMG_20200327_141418_1.jpg	p
#
# data_cropped/p_IMG_20200327_140511_11.jpg	p
#
# data_cropped/p_IMG_20200327_141847_11.jpg	p
#
# data_cropped/p_IMG_20200327_142223_9.jpg	p
#
# data_cropped/p_IMG_20200327_141356_9.jpg	p
#
# data_cropped/p_IMG_20200327_140858_11.jpg	p
#
# data_cropped/p_IMG_20200327_142135_10.jpg	p
#
# data_cropped/p_IMG_20200327_141754_5.jpg	p
#
# data_cropped/p_IMG_20200327_141226_9.jpg	p
#
# data_cropped/p_IMG_20200327_142411_9.jpg	p
#
# data_cropped/p_IMG_20200327_142342_8.jpg	p
#
# data_cropped/p_IMG_20200327_140652_23.jpg	p
#
# data_cropped/p_IMG_20200327_141348_16.jpg	p
#
# data_cropped/p_IMG_20200327_140748_17.jpg	p
#
# data_cropped/p_IMG_20200327_143029_9.jpg	p
#
# data_cropped/p_IMG_20200327_141003_9.jpg	p
#
# data_cropped/p_IMG_20200327_142129_9.jpg	p
#
# data_cropped/p_IMG_20200327_141038_9.jpg	p
#
# data_cropped/p_IMG_20200327_140445_11.jpg	p
#
# data_cropped/p_IMG_20200327_142856_9.jpg	p
#
# data_cropped/p_IMG_20200327_140218_9.jpg	p
#
# data_cropped/p_IMG_20200327_140451_11.jpg	p
#
# data_cropped/p_IMG_20200327_142101_8.jpg	p
#
# data_cropped/p_IMG_20200327_142359_14.jpg	p
#
# data_cropped/p_IMG_20200327_141115_7.jpg	p
#
# data_cropped/p_IMG_20200327_140725_9.jpg	p
#
# data_cropped/q_20191026_121009_16.jpg	q
#
# data_cropped/q_IMG_2863_15.jpg	q
#
# data_cropped/q_2019-10-26 120941_13.jpg	q
#
# data_cropped/q_IMG_2862_15.jpg	q
#
# data_cropped/q_2019-10-26 120932_13.jpg	q
#
# data_cropped/s_2019-10-26 115648_7.jpg	s
#
# data_cropped/s_IMG_20200327_143227_5.jpg	s
#
# data_cropped/s_IMG_2485_5.jpg	s
#
# data_cropped/s_2019-10-26 110851_4.jpg	s
#
# data_cropped/s_IMG_2781_5.jpg	s
#
# data_cropped/s_IMG_2771_5.jpg	s
#
# data_cropped/s_20191026_121945_6.jpg	s
#
# data_cropped/s_20191026_114718_10.jpg	s
#
# data_cropped/s_IMG_2719_8.jpg	s
#
# data_cropped/s_IMG_2703_8.jpg	s
#
# data_cropped/s_20191026_105545_14.jpg	s
#
# data_cropped/s_IMG_2621_6.jpg	s
#
# data_cropped/s_20191026_121739_7.jpg	s
#
# data_cropped/s_IMG_2745_5.jpg	s
#
# data_cropped/s_IMG_2918_4.jpg	s
#
# data_cropped/s_IMG_2685_6.jpg	s
#
# data_cropped/s_IMG_2707_6.jpg	s
#
# data_cropped/s_IMG_2759_5.jpg	s
#
# data_cropped/s_2019-10-26 115645_6.jpg	s
#
# data_cropped/s_IMG_2761_5.jpg	s
#
# data_cropped/s_20191026_113837_7.jpg	s
#
# data_cropped/s_20191026_114718_9.jpg	s
#
# data_cropped/s_IMG_2819_5.jpg	s
#
# data_cropped/s_20191026_113621_7.jpg	s
#
# data_cropped/s_IMG_2514_5.jpg	s
#
# data_cropped/s_20191026_113607_7.jpg	s
#
# data_cropped/s_IMG_2488_5.jpg	s
#
# data_cropped/s_IMG_2758_5.jpg	s
#
# data_cropped/s_IMG_2861_7.jpg	s
#
# data_cropped/s_IMG_2677_6.jpg	s
#
# data_cropped/s_IMG_2866_4.jpg	s
#
# data_cropped/s_20191026_121704_7.jpg	s
#
# data_cropped/s_IMG_2486_5.jpg	s
#
# data_cropped/s_IMG_2901_4.jpg	s
#
# data_cropped/s_2019-10-26 114250_7.jpg	s
#
# data_cropped/s_IMG_2822_5.jpg	s
#
# data_cropped/s_IMG_2708_9.jpg	s
#
# data_cropped/s_2019-10-26 115155_6.jpg	s
#
# data_cropped/s_20191026_105634_14.jpg	s
#
# data_cropped/s_IMG_2725_9.jpg	s
#
# data_cropped/s_IMG_2507_4.jpg	s
#
# data_cropped/s_2019-10-26 122053_5.jpg	s
#
# data_cropped/s_2019-10-26 121735_5.jpg	s
#
# data_cropped/s_20191026_114844_8.jpg	s
#
# data_cropped/s_2019-10-26 110931_4.jpg	s
#
# data_cropped/s_20191026_122003_7.jpg	s
#
# data_cropped/s_IMG_2658_6.jpg	s
#
# data_cropped/s_IMG_2673_6.jpg	s
#
# data_cropped/s_20191026_110053_14.jpg	s
#
# data_cropped/s_2019-10-26 114201_6.jpg	s
#
# data_cropped/s_IMG_20200327_141502_5.jpg	s
#
# data_cropped/s_IMG_2724_5.jpg	s
#
# data_cropped/s_20191026_105947_14.jpg	s
#
# data_cropped/s_20191026_122200_7.jpg	s
#
# data_cropped/s_2019-10-26 122302_7.jpg	s
#
# data_cropped/s_2019-10-26 122315_7.jpg	s
#
# data_cropped/s_2019-10-26 122250_7.jpg	s
#
# data_cropped/s_IMG_2727_5.jpg	s
#
# data_cropped/s_2019-10-26 122105_4.jpg	s
#
# data_cropped/s_2019-10-26 114222_6.jpg	s
#
# data_cropped/s_20191026_111215_4.jpg	s
#
# data_cropped/s_20191026_105843_14.jpg	s
#
# data_cropped/s_IMG_2753_5.jpg	s
#
# data_cropped/s_20191026_115035_7.jpg	s
#
# data_cropped/s_IMG_2892_4.jpg	s
#
# data_cropped/s_20191026_111540_4.jpg	s
#
# data_cropped/s_IMG_2517_4.jpg	s
#
# data_cropped/s_IMG_2725_6.jpg	s
#
# data_cropped/s_20191026_103517_12.jpg	s
#
# data_cropped/s_IMG_2665_6.jpg	s
#
# data_cropped/s_IMG_2760_5.jpg	s
#
# data_cropped/s_IMG_2803_5.jpg	s
#
# data_cropped/s_20191026_113534_7.jpg	s
#
# data_cropped/v_IMG_20200327_140103_0.jpg	v
#
# data_cropped/v_IMG_20200327_141023_4.jpg	v
#
# data_cropped/v_IMG_20200327_141319_6.jpg	v
#
# data_cropped/v_IMG_20200327_140903_6.jpg	v
#
# data_cropped/v_IMG_20200327_141300_5.jpg	v
#
# data_cropped/v_IMG_20200327_143509_4.jpg	v
#
# data_cropped/v_IMG_20200327_141805_9.jpg	v
#
# data_cropped/v_IMG_20200327_140128_6.jpg	v
#
# data_cropped/v_IMG_20200327_142145_4.jpg	v
#
# data_cropped/v_IMG_20200327_141950_5.jpg	v
#
# data_cropped/v_IMG_20200327_140628_4.jpg	v
#
# data_cropped/v_20191026_111612_12.jpg	v
#
# data_cropped/v_2019-10-26 111322_12.jpg	v
#
# data_cropped/v_IMG_20200327_142623_4.jpg	v
#
# data_cropped/v_IMG_20200327_141615_4.jpg	v
#
# data_cropped/v_IMG_20200327_142632_5.jpg	v
#
# data_cropped/v_IMG_20200327_142238_4.jpg	v
#
# data_cropped/v_IMG_20200327_140330_6.jpg	v
#
# data_cropped/v_IMG_20200327_140225_15.jpg	v
#
# data_cropped/v_2019-10-26 111636_12.jpg	v
#
# data_cropped/v_IMG_20200327_141748_11.jpg	v
#
# data_cropped/v_IMG_20200327_140715_11.jpg	v
#
# data_cropped/v_20191026_111540_12.jpg	v
#
# data_cropped/v_IMG_20200327_142929_4.jpg	v
#
# data_cropped/v_IMG_20200327_140720_4.jpg	v
#
# data_cropped/v_IMG_20200327_141715_5.jpg	v
#
# data_cropped/v_2019-10-26 111755_12.jpg	v
#
# data_cropped/v_IMG_20200327_142617_4.jpg	v
#
# data_cropped/v_IMG_20200327_145002_4.jpg	v
#
# data_cropped/v_IMG_20200327_142441_5.jpg	v
#
# data_cropped/v_IMG_20200327_141334_5.jpg	v
#
# data_cropped/v_IMG_20200327_141317_5.jpg	v
#
# Written 2000 / 2129
# data_cropped/v_IMG_20200327_141840_6.jpg	v
#
# data_cropped/v_20191026_111406_12.jpg	v
#
# data_cropped/v_IMG_20200327_141738_10.jpg	v
#
# data_cropped/v_IMG_20200327_141816_14.jpg	v
#
# data_cropped/v_20191026_111357_12.jpg	v
#
# data_cropped/v_IMG_20200327_140402_6.jpg	v
#
# data_cropped/x_IMG_2834_0.jpg	x
#
# data_cropped/x_IMG_20200327_140659_0.jpg	x
#
# data_cropped/x_2019-10-26 121838_10.jpg	x
#
# data_cropped/x_IMG_20200327_140622_0.jpg	x
#
# data_cropped/x_2019-10-26 103955_0.jpg	x
#
# data_cropped/x_IMG_20200327_144106_9.jpg	x
#
# data_cropped/x_20191026_114220_3.jpg	x
#
# data_cropped/x_IMG_20200327_144137_8.jpg	x
#
# data_cropped/x_2019-10-26 115329_11.jpg	x
#
# data_cropped/x_2019-10-26 103940_0.jpg	x
#
# data_cropped/y_IMG_20200327_145137_1.jpg	y
#
# data_cropped/y_IMG_20200327_142032_0.jpg	y
#
# data_cropped/y_IMG_2912_13.jpg	y
#
# data_cropped/y_20191026_122226_16.jpg	y
#
# data_cropped/y_IMG_2856_11.jpg	y
#
# data_cropped/y_IMG_20200327_144552_1.jpg	y
#
# data_cropped/y_IMG_20200327_142018_0.jpg	y
#
# data_cropped/y_IMG_20200327_144946_1.jpg	y
#
# data_cropped/y_IMG_20200327_144549_1.jpg	y
#
# data_cropped/y_IMG_2914_13.jpg	y
#
# data_cropped/y_IMG_2836_13.jpg	y
#
# data_cropped/y_IMG_20200327_145115_1.jpg	y
#
# data_cropped/y_IMG_2900_13.jpg	y
#
# data_cropped/y_IMG_2908_13.jpg	y
#
# data_cropped/zb33102al_IMG_2543_0.jpg	zb33102al
#
# data_cropped/zb33102al_IMG_2545_0.jpg	zb33102al
#
# data_cropped/zb33102al_IMG_2597_0.jpg	zb33102al
#
# data_cropped/zb33102al_IMG_2607_0.jpg	zb33102al
#
# data_cropped/zb33102al_IMG_2546_0.jpg	zb33102al
#
# data_cropped/zb33102al_IMG_2576_0.jpg	zb33102al
#
# data_cropped/zb33102al_IMG_2531_0.jpg	zb33102al
#
# data_cropped/zb33102al_IMG_2550_0.jpg	zb33102al
#
# data_cropped/zb33102al_IMG_2525_0.jpg	zb33102al
#
# data_cropped/z_IMG_2636_7.jpg	z
#
# data_cropped/z_IMG_2505_6.jpg	z
#
# data_cropped/z_IMG_2590_0.jpg	z
#
# data_cropped/z_20191026_105823_15.jpg	z
#
# data_cropped/z_20191026_113433_8.jpg	z
#
# data_cropped/z_IMG_20200327_142617_8.jpg	z
#
# data_cropped/z_IMG_2504_6.jpg	z
#
# data_cropped/z_IMG_2592_0.jpg	z
#
# data_cropped/z_IMG_2515_6.jpg	z
#
# data_cropped/z_IMG_2501_7.jpg	z
#
# data_cropped/z_IMG_2568_1.jpg	z
#
# data_cropped/z_20191026_113927_8.jpg	z
#
# data_cropped/z_2019-10-26 115329_7.jpg	z
#
# data_cropped/z_IMG_2700_8.jpg	z
#
# data_cropped/z_IMG_2605_0.jpg	z
# data_cropped/z_IMG_20200327_140908_0.jpg	z
#
# data_cropped/z_IMG_2697_9.jpg	z
#
# data_cropped/z_20191026_105923_15.jpg	z
#
# data_cropped/z_IMG_20200327_141625_6.jpg	z
#
# data_cropped/z_IMG_20200327_143447_8.jpg	z
#
# data_cropped/z_2019-10-26 104148_3.jpg	z
#
# data_cropped/z_IMG_2583_0.jpg	z
#
# data_cropped/z_IMG_2640_7.jpg	z
#
# data_cropped/z_IMG_20200327_144647_5.jpg	z
#
# data_cropped/z_IMG_2701_8.jpg	z
#
# data_cropped/z_20191026_114026_8.jpg	z
#
# data_cropped/z_2019-10-26 115155_7.jpg	z
#
# data_cropped/z_IMG_2654_9.jpg	z
#
# data_cropped/z_IMG_20200327_143332_5.jpg	z
#
# data_cropped/z_IMG_2548_5.jpg	z
#
# data_cropped/z_IMG_2834_3.jpg	z
#
# data_cropped/z_20191026_105802_15.jpg	z
#
# data_cropped/z_IMG_2742_10.jpg	z
#
# data_cropped/z_IMG_2503_6.jpg	z
#
# data_cropped/z_IMG_2567_0.jpg	z
#
# data_cropped/z_20191026_105939_15.jpg	z
#
# data_cropped/z_2019-10-26 121726_6.jpg	z
#
# data_cropped/z_20191026_110255_5.jpg	z
#
# data_cropped/z_20191026_110448_5.jpg	z
#
# data_cropped/z_2019-10-26 110851_5.jpg	z
#
# data_cropped/z_IMG_20200327_142643_8.jpg	z
#
# data_cropped/z_2019-10-26 114603_3.jpg	z
#
# data_cropped/z_20191026_110115_15.jpg	z
#
# data_cropped/z_IMG_2710_7.jpg	z
#
# data_cropped/z_IMG_2551_5.jpg	z
#
# data_cropped/z_IMG_2630_7.jpg	z
#
# data_cropped/z_IMG_20200327_143000_8.jpg	z
#
# data_cropped/z_20191026_105852_15.jpg	z
#
# data_cropped/z_IMG_2629_9.jpg	z
#
# data_cropped/z_IMG_2539_0.jpg	z
#
# data_cropped/z_2019-10-26 114538_3.jpg	z
#
# data_cropped/z_IMG_2857_6.jpg	z
#
# data_cropped/z_IMG_2767_11.jpg	z
#
# data_cropped/z_IMG_2781_6.jpg	z
#
# data_cropped/z_20191026_103545_15.jpg	z
#
# data_cropped/z_IMG_20200327_141452_6.jpg	z
#
# data_cropped/z_IMG_20200327_140508_8.jpg	z
#
# data_cropped/z_2019-10-26 114518_3.jpg	z
#
# data_cropped/z_IMG_2632_7.jpg	z
#
# data_cropped/z_IMG_2533_0.jpg	z
#
# data_cropped/z_IMG_2635_7.jpg	z
#
# data_cropped/z_IMG_20200327_143108_5.jpg	z
#
# data_cropped/z_2019-10-26 121820_6.jpg	z
#
# data_cropped/z_IMG_2724_6.jpg	z
#
# data_cropped/z_20191026_111714_5.jpg	z
#
# data_cropped/z_IMG_2758_6.jpg	z
#
# data_cropped/z_IMG_20200327_141920_5.jpg	z
#
# data_cropped/z_IMG_20200327_143246_6.jpg	z
#
# data_cropped/z_IMG_2571_0.jpg	z
#
# data_cropped/z_IMG_2517_6.jpg	z
#
# data_cropped/z_IMG_2522_0.jpg	z
#
# data_cropped/z_IMG_2538_0.jpg	z
#
# data_cropped/z_IMG_2755_6.jpg	z
#
# data_cropped/z_IMG_20200327_143015_8.jpg	z
#
# data_cropped/z_IMG_2633_9.jpg	z
#
# data_cropped/z_IMG_2554_5.jpg	z
#
# data_cropped/z_IMG_2915_5.jpg	z
#
# data_cropped/z_2019-10-26 114341_3.jpg	z
#
# data_cropped/z_IMG_2810_6.jpg	z
#
# data_cropped/z_IMG_2732_6.jpg	z
#
# data_cropped/z_20191026_122029_8.jpg	z
#
# data_cropped/z_IMG_2893_5.jpg	z
#
# data_cropped/z_20191026_111724_5.jpg	z
#
# data_cropped/z_IMG_2651_7.jpg	z
#
# data_cropped/z_IMG_2534_5.jpg	z
#
# data_cropped/z_IMG_2573_4.jpg	z
#
# data_cropped/z_IMG_2576_0.jpg	z
#
# data_cropped/z_IMG_2580_3.jpg	z
#
# data_cropped/z_IMG_2901_5.jpg	z
#
# data_cropped/z_20191026_121846_8.jpg	z
#
# Created dataset with 2129 samples
